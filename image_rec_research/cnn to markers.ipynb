# %%
import os
from os.path import join
import sys
import cv2 as cv
import numpy as np
from numpy.random import RandomState
import pickle
import matplotlib.pyplot as plt

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# c:\users\joear\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def load_labels(specific_video=None):
    """ Loads in image data as numpy arrays """
    sequence = []
    none_count = 0 
    filedir = join(os.getcwd(),"labels")
    for file in os.listdir(filedir):
        ## change current seq when video_id change or marker number changes
        if file.endswith(".jpg"):
            file = file.split(".")[0]
            file = file.split("_")
            if specific_video == None:
                video_id, marker_num, marker_type, frame_num, x_pos, y_pos = file[0], int(file[1]), int(file[2]), int(file[3]), int(file[4]), int(file[5])
                current_seq = [video_id, marker_num, marker_type, frame_num, x_pos, y_pos]
                sequence.append(current_seq)
            else:
                if file[0] == video_id:
                    video_id, marker_num, marker_type, frame_num, x_pos, y_pos = file[0], int(file[1]), int(file[2]), int(file[3]), int(file[4]), int(file[5])
                    current_seq = [video_id, marker_num, marker_type, frame_num, x_pos, y_pos]
                    sequence.append(current_seq)
    return sequence

# %%
def sort_labels(sequence):
    sequence.sort(key=lambda x: x[3]) ## Sort by frame number
    sequence.sort(key=lambda x: x[1]) ## Sort by marker_num
    sequence.sort(key=lambda x: x[0]) ## Sort by video_name
    return sequence

# %%
def assign_labels(sequence):
    ##  ball change or vid change
    prev_vid_id, prev_marker_num = sequence[0][0][0], sequence[0][0][1]
    for idx, seq in enumerate(sequence):
        vid_id, marker_num = seq[0], seq[1]
        if (vid_id != prev_vid_id) or (marker_num != prev_marker_num):
            prev_vid_id, prev_marker_num = vid_id, marker_num
            prev_coords, prev_frame_num = np.array([-1,-1]), -1
        frame_num, x_pos, y_pos = seq[3], seq[4], seq[5]
        current_coords = np.array([x_pos, y_pos])
        if (prev_coords[0] == -1) & (prev_coords[1] == -1):
            dist = -1
        else:
            dist = np.linalg.norm(current_coords - prev_coords)
        if (prev_frame_num == -1):
            frame_diff = -1
        else:
            frame_diff = frame_num - prev_frame_num
        prev_coords = current_coords
        prev_frame_num = frame_num
        sequence[idx].append(dist)
        sequence[idx].append(frame_diff)
    return sequence

# %%
def load_video(video_path, video_name, flip, display = False): ## Convert 3rd element in video name into flip
    width, height = 960, 540
    cap = cv.VideoCapture(join(video_path,video_name))
    ret, frame = cap.read()
    if (flip):
        frame = cv.flip(frame, 0)
    clone = cv.resize(frame, (width,height))
    if (display):
        cv.namedWindow("Video")
    frame_num = 0
    frames = []
    while (ret):
        if (display):
            cv.imshow("Video", clone)
        frames.append( [frame, frame_num] )
        if (display):
            key = cv.waitKey(0)
            if key == 113:
                break
        ret, frame = cap.read()
        if (ret):
            frame_num += 1
            if (flip):
                frame = cv.flip(frame, 0)
            clone = cv.resize(frame, (width, height))
    print("Frames: {}".format(frames[-1][1] + 1))
    cap.release()
    if (display):
        cv.destroyAllWindows()
    return frames

# %%
def load_data_and_labels(sequence, vid_format=".avi"):
    print("Loading videos")
    filedir = join(os.getcwd(),"resources")
    video_recorded = []
    for file in os.listdir(filedir):
        video_id = file.split(".")[0]
        video_recorded.append(video_id)
    video_annotated = list(sorted(set([i[0] for i in sequence])))
    video_data = []
    """ Checking the videos annotated is in the video recorded """
    for rec in video_recorded:
        if rec in video_annotated:
            data = []
            print("#####################################")
            print("Found: {}".format(rec))
            labels = [i for i in sequence if i[0] == rec]
            labels.sort(key=lambda x: x[3]) ## Sort by frame number
            labels = np.asarray(labels)[:,1:].astype('float32')
            print(labels)
            print("#####################################")
            frames = load_video(filedir, rec + vid_format, False)
            frames = np.asarray(frames)
            print(frames.shape)
            prev_frame = 0
            frame_labels = []
            print(len(labels))
            for idx, label in enumerate(labels):
                print("idx: {}, curr_frame = {}".format(idx, int(label[2])))
                curr_frame = int(label[2])
                if (curr_frame != prev_frame):
                    data.append([frames[prev_frame][0], frame_labels])                    
                    frame_labels = [label]
                elif idx == len(labels) - 1:
                    frame_labels.append(label)
                    data.append([frames[curr_frame][0],frame_labels])
                else:
                    frame_labels.append(label)
                prev_frame = int(curr_frame)
            video_data.append(data)
    print("Search Complete")
    return video_data

# %%
def data_to_np(data):
    data_np = np.asarray(data)
    x_values = []
    y_values = []
    
    for i in range(len(data_np)):
        print("Frames in video {}: {}".format(i,len(data_np[i])))            
    
    for vid_pos in range(len(data_np)):
        ##print("vid: {}".format(vid_pos))
        
        ### loop through the number of frames not the points capturedd
        
        for frame_pos in range(len(data_np[vid_pos])):
            ##print("frame num: {}".format(frame_pos))
            x_np = data_np[vid_pos][frame_pos][0]
            x_shape = list(x_np[0].shape)
            x_shape[:0] = [len(x_np)]
            x_np = np.concatenate(x_np).reshape(x_shape)
            x_values.append(x_np)

            y_np = data_np[vid_pos][frame_pos][1]
            y_np = np.asarray(y_np)
            zero_np = np.zeros((16,7))
            if y_np.shape != (0,):
                zero_np[:y_np.shape[0],:y_np.shape[1]] = y_np
            y_values.append(zero_np)
        
    x_img = np.asarray(x_values)
    y_values = np.asarray(y_values)
    x_diff = y_values[:, :, 5:]
    y_cords = y_values[:, :, 3:5]
    print("x_img shape: {}, x_diff shape: {}, y_values shape: {}".format(x_img.shape, x_diff.shape, y_cords.shape))
    return x_img, x_diff, y_cords

# %%
def load_data():
    seq = load_labels()
    seq = sort_labels(seq)
    seq = assign_labels(seq)
    data = load_data_and_labels(seq)
    x_img, x_diff, y = data_to_np(data)
    return x_img, x_diff, y

# %%
x_img, x_diff, y = load_data()
# Out:
# Loading videos
# #####################################
# Found: v0-0
# [[  0.          1.          0.        ... 531.         -1.
#    -1.       ]
#  [  1.          2.          0.        ... 719.         -1.
#    -1.       ]
#  [  2.          1.          0.        ... 883.         -1.
#    -1.       ]
#  ...
#  [  0.          1.        149.        ... 528.          4.
#     1.       ]
#  [  1.          2.        149.        ... 721.          5.3851647
#     1.       ]
#  [  2.          1.        149.        ... 878.          2.
#     1.       ]]
# #####################################
# Frames: 150
# (150, 2)
# 450
# idx: 0, curr_frame = 0
# idx: 1, curr_frame = 0
# idx: 2, curr_frame = 0
# idx: 3, curr_frame = 1
# idx: 4, curr_frame = 1
# idx: 5, curr_frame = 1
# idx: 6, curr_frame = 2
# idx: 7, curr_frame = 2
# idx: 8, curr_frame = 2
# idx: 9, curr_frame = 3
# idx: 10, curr_frame = 3
# idx: 11, curr_frame = 3
# idx: 12, curr_frame = 4
# idx: 13, curr_frame = 4
# idx: 14, curr_frame = 4
# idx: 15, curr_frame = 5
# idx: 16, curr_frame = 5
# idx: 17, curr_frame = 5
# idx: 18, curr_frame = 6
# idx: 19, curr_frame = 6
# idx: 20, curr_frame = 6
# idx: 21, curr_frame = 7
# idx: 22, curr_frame = 7
# idx: 23, curr_frame = 7
# idx: 24, curr_frame = 8
# idx: 25, curr_frame = 8
# idx: 26, curr_frame = 8
# idx: 27, curr_frame = 9
# idx: 28, curr_frame = 9
# idx: 29, curr_frame = 9
# idx: 30, curr_frame = 10
# idx: 31, curr_frame = 10
# idx: 32, curr_frame = 10
# idx: 33, curr_frame = 11
# idx: 34, curr_frame = 11
# idx: 35, curr_frame = 11
# idx: 36, curr_frame = 12
# idx: 37, curr_frame = 12
# idx: 38, curr_frame = 12
# idx: 39, curr_frame = 13
# idx: 40, curr_frame = 13
# idx: 41, curr_frame = 13
# idx: 42, curr_frame = 14
# idx: 43, curr_frame = 14
# idx: 44, curr_frame = 14
# idx: 45, curr_frame = 15
# idx: 46, curr_frame = 15
# idx: 47, curr_frame = 15
# idx: 48, curr_frame = 16
# idx: 49, curr_frame = 16
# idx: 50, curr_frame = 16
# idx: 51, curr_frame = 17
# idx: 52, curr_frame = 17
# idx: 53, curr_frame = 17
# idx: 54, curr_frame = 18
# idx: 55, curr_frame = 18
# idx: 56, curr_frame = 18
# idx: 57, curr_frame = 19
# idx: 58, curr_frame = 19
# idx: 59, curr_frame = 19
# idx: 60, curr_frame = 20
# idx: 61, curr_frame = 20
# idx: 62, curr_frame = 20
# idx: 63, curr_frame = 21
# idx: 64, curr_frame = 21
# idx: 65, curr_frame = 21
# idx: 66, curr_frame = 22
# idx: 67, curr_frame = 22
# idx: 68, curr_frame = 22
# idx: 69, curr_frame = 23
# idx: 70, curr_frame = 23
# idx: 71, curr_frame = 23
# idx: 72, curr_frame = 24
# idx: 73, curr_frame = 24
# idx: 74, curr_frame = 24
# idx: 75, curr_frame = 25
# idx: 76, curr_frame = 25
# idx: 77, curr_frame = 25
# idx: 78, curr_frame = 26
# idx: 79, curr_frame = 26
# idx: 80, curr_frame = 26
# idx: 81, curr_frame = 27
# idx: 82, curr_frame = 27
# idx: 83, curr_frame = 27
# idx: 84, curr_frame = 28
# idx: 85, curr_frame = 28
# idx: 86, curr_frame = 28
# idx: 87, curr_frame = 29
# idx: 88, curr_frame = 29
# idx: 89, curr_frame = 29
# idx: 90, curr_frame = 30
# idx: 91, curr_frame = 30
# idx: 92, curr_frame = 30
# idx: 93, curr_frame = 31
# idx: 94, curr_frame = 31
# idx: 95, curr_frame = 31
# idx: 96, curr_frame = 32
# idx: 97, curr_frame = 32
# idx: 98, curr_frame = 32
# idx: 99, curr_frame = 33
# idx: 100, curr_frame = 33
# idx: 101, curr_frame = 33
# idx: 102, curr_frame = 34
# idx: 103, curr_frame = 34
# idx: 104, curr_frame = 34
# idx: 105, curr_frame = 35
# idx: 106, curr_frame = 35
# idx: 107, curr_frame = 35
# idx: 108, curr_frame = 36
# idx: 109, curr_frame = 36
# idx: 110, curr_frame = 36
# idx: 111, curr_frame = 37
# idx: 112, curr_frame = 37
# idx: 113, curr_frame = 37
# idx: 114, curr_frame = 38
# idx: 115, curr_frame = 38
# idx: 116, curr_frame = 38
# idx: 117, curr_frame = 39
# idx: 118, curr_frame = 39
# idx: 119, curr_frame = 39
# idx: 120, curr_frame = 40
# idx: 121, curr_frame = 40
# idx: 122, curr_frame = 40
# idx: 123, curr_frame = 41
# idx: 124, curr_frame = 41
# idx: 125, curr_frame = 41
# idx: 126, curr_frame = 42
# idx: 127, curr_frame = 42
# idx: 128, curr_frame = 42
# idx: 129, curr_frame = 43
# idx: 130, curr_frame = 43
# idx: 131, curr_frame = 43
# idx: 132, curr_frame = 44
# idx: 133, curr_frame = 44
# idx: 134, curr_frame = 44
# idx: 135, curr_frame = 45
# idx: 136, curr_frame = 45
# idx: 137, curr_frame = 45
# idx: 138, curr_frame = 46
# idx: 139, curr_frame = 46
# idx: 140, curr_frame = 46
# idx: 141, curr_frame = 47
# idx: 142, curr_frame = 47
# idx: 143, curr_frame = 47
# idx: 144, curr_frame = 48
# idx: 145, curr_frame = 48
# idx: 146, curr_frame = 48
# idx: 147, curr_frame = 49
# idx: 148, curr_frame = 49
# idx: 149, curr_frame = 49
# idx: 150, curr_frame = 50
# idx: 151, curr_frame = 50
# idx: 152, curr_frame = 50
# idx: 153, curr_frame = 51
# idx: 154, curr_frame = 51
# idx: 155, curr_frame = 51
# idx: 156, curr_frame = 52
# idx: 157, curr_frame = 52
# idx: 158, curr_frame = 52
# idx: 159, curr_frame = 53
# idx: 160, curr_frame = 53
# idx: 161, curr_frame = 53
# idx: 162, curr_frame = 54
# idx: 163, curr_frame = 54
# idx: 164, curr_frame = 54
# idx: 165, curr_frame = 55
# idx: 166, curr_frame = 55
# idx: 167, curr_frame = 55
# idx: 168, curr_frame = 56
# idx: 169, curr_frame = 56
# idx: 170, curr_frame = 56
# idx: 171, curr_frame = 57
# idx: 172, curr_frame = 57
# idx: 173, curr_frame = 57
# idx: 174, curr_frame = 58
# idx: 175, curr_frame = 58
# idx: 176, curr_frame = 58
# idx: 177, curr_frame = 59
# idx: 178, curr_frame = 59
# idx: 179, curr_frame = 59
# idx: 180, curr_frame = 60
# idx: 181, curr_frame = 60
# idx: 182, curr_frame = 60
# idx: 183, curr_frame = 61
# idx: 184, curr_frame = 61
# idx: 185, curr_frame = 61
# idx: 186, curr_frame = 62
# idx: 187, curr_frame = 62
# idx: 188, curr_frame = 62
# idx: 189, curr_frame = 63
# idx: 190, curr_frame = 63
# idx: 191, curr_frame = 63
# idx: 192, curr_frame = 64
# idx: 193, curr_frame = 64
# idx: 194, curr_frame = 64
# idx: 195, curr_frame = 65
# idx: 196, curr_frame = 65
# idx: 197, curr_frame = 65
# idx: 198, curr_frame = 66
# idx: 199, curr_frame = 66
# idx: 200, curr_frame = 66
# idx: 201, curr_frame = 67
# idx: 202, curr_frame = 67
# idx: 203, curr_frame = 67
# idx: 204, curr_frame = 68
# idx: 205, curr_frame = 68
# idx: 206, curr_frame = 68
# idx: 207, curr_frame = 69
# idx: 208, curr_frame = 69
# idx: 209, curr_frame = 69
# idx: 210, curr_frame = 70
# idx: 211, curr_frame = 70
# idx: 212, curr_frame = 70
# idx: 213, curr_frame = 71
# idx: 214, curr_frame = 71
# idx: 215, curr_frame = 71
# idx: 216, curr_frame = 72
# idx: 217, curr_frame = 72
# idx: 218, curr_frame = 72
# idx: 219, curr_frame = 73
# idx: 220, curr_frame = 73
# idx: 221, curr_frame = 73
# idx: 222, curr_frame = 74
# idx: 223, curr_frame = 74
# idx: 224, curr_frame = 74
# idx: 225, curr_frame = 75
# idx: 226, curr_frame = 75
# idx: 227, curr_frame = 75
# idx: 228, curr_frame = 76
# idx: 229, curr_frame = 76
# idx: 230, curr_frame = 76
# idx: 231, curr_frame = 77
# idx: 232, curr_frame = 77
# idx: 233, curr_frame = 77
# idx: 234, curr_frame = 78
# idx: 235, curr_frame = 78
# idx: 236, curr_frame = 78
# idx: 237, curr_frame = 79
# idx: 238, curr_frame = 79
# idx: 239, curr_frame = 79
# idx: 240, curr_frame = 80
# idx: 241, curr_frame = 80
# idx: 242, curr_frame = 80
# idx: 243, curr_frame = 81
# idx: 244, curr_frame = 81
# idx: 245, curr_frame = 81
# idx: 246, curr_frame = 82
# idx: 247, curr_frame = 82
# idx: 248, curr_frame = 82
# idx: 249, curr_frame = 83
# idx: 250, curr_frame = 83
# idx: 251, curr_frame = 83
# idx: 252, curr_frame = 84
# idx: 253, curr_frame = 84
# idx: 254, curr_frame = 84
# idx: 255, curr_frame = 85
# idx: 256, curr_frame = 85
# idx: 257, curr_frame = 85
# idx: 258, curr_frame = 86
# idx: 259, curr_frame = 86
# idx: 260, curr_frame = 86
# idx: 261, curr_frame = 87
# idx: 262, curr_frame = 87
# idx: 263, curr_frame = 87
# idx: 264, curr_frame = 88
# idx: 265, curr_frame = 88
# idx: 266, curr_frame = 88
# idx: 267, curr_frame = 89
# idx: 268, curr_frame = 89
# idx: 269, curr_frame = 89
# idx: 270, curr_frame = 90
# idx: 271, curr_frame = 90
# idx: 272, curr_frame = 90
# idx: 273, curr_frame = 91
# idx: 274, curr_frame = 91
# idx: 275, curr_frame = 91
# idx: 276, curr_frame = 92
# idx: 277, curr_frame = 92
# idx: 278, curr_frame = 92
# idx: 279, curr_frame = 93
# idx: 280, curr_frame = 93
# idx: 281, curr_frame = 93
# idx: 282, curr_frame = 94
# idx: 283, curr_frame = 94
# idx: 284, curr_frame = 94
# idx: 285, curr_frame = 95
# idx: 286, curr_frame = 95
# idx: 287, curr_frame = 95
# idx: 288, curr_frame = 96
# idx: 289, curr_frame = 96
# idx: 290, curr_frame = 96
# idx: 291, curr_frame = 97
# idx: 292, curr_frame = 97
# idx: 293, curr_frame = 97
# idx: 294, curr_frame = 98
# idx: 295, curr_frame = 98
# idx: 296, curr_frame = 98
# idx: 297, curr_frame = 99
# idx: 298, curr_frame = 99
# idx: 299, curr_frame = 99
# idx: 300, curr_frame = 100
# idx: 301, curr_frame = 100
# idx: 302, curr_frame = 100
# idx: 303, curr_frame = 101
# idx: 304, curr_frame = 101
# idx: 305, curr_frame = 101
# idx: 306, curr_frame = 102
# idx: 307, curr_frame = 102
# idx: 308, curr_frame = 102
# idx: 309, curr_frame = 103
# idx: 310, curr_frame = 103
# idx: 311, curr_frame = 103
# idx: 312, curr_frame = 104
# idx: 313, curr_frame = 104
# idx: 314, curr_frame = 104
# idx: 315, curr_frame = 105
# idx: 316, curr_frame = 105
# idx: 317, curr_frame = 105
# idx: 318, curr_frame = 106
# idx: 319, curr_frame = 106
# idx: 320, curr_frame = 106
# idx: 321, curr_frame = 107
# idx: 322, curr_frame = 107
# idx: 323, curr_frame = 107
# idx: 324, curr_frame = 108
# idx: 325, curr_frame = 108
# idx: 326, curr_frame = 108
# idx: 327, curr_frame = 109
# idx: 328, curr_frame = 109
# idx: 329, curr_frame = 109
# idx: 330, curr_frame = 110
# idx: 331, curr_frame = 110
# idx: 332, curr_frame = 110
# idx: 333, curr_frame = 111
# idx: 334, curr_frame = 111
# idx: 335, curr_frame = 111
# idx: 336, curr_frame = 112
# idx: 337, curr_frame = 112
# idx: 338, curr_frame = 112
# idx: 339, curr_frame = 113
# idx: 340, curr_frame = 113
# idx: 341, curr_frame = 113
# idx: 342, curr_frame = 114
# idx: 343, curr_frame = 114
# idx: 344, curr_frame = 114
# idx: 345, curr_frame = 115
# idx: 346, curr_frame = 115
# idx: 347, curr_frame = 115
# idx: 348, curr_frame = 116
# idx: 349, curr_frame = 116
# idx: 350, curr_frame = 116
# idx: 351, curr_frame = 117
# idx: 352, curr_frame = 117
# idx: 353, curr_frame = 117
# idx: 354, curr_frame = 118
# idx: 355, curr_frame = 118
# idx: 356, curr_frame = 118
# idx: 357, curr_frame = 119
# idx: 358, curr_frame = 119
# idx: 359, curr_frame = 119
# idx: 360, curr_frame = 120
# idx: 361, curr_frame = 120
# idx: 362, curr_frame = 120
# idx: 363, curr_frame = 121
# idx: 364, curr_frame = 121
# idx: 365, curr_frame = 121
# idx: 366, curr_frame = 122
# idx: 367, curr_frame = 122
# idx: 368, curr_frame = 122
# idx: 369, curr_frame = 123
# idx: 370, curr_frame = 123
# idx: 371, curr_frame = 123
# idx: 372, curr_frame = 124
# idx: 373, curr_frame = 124
# idx: 374, curr_frame = 124
# idx: 375, curr_frame = 125
# idx: 376, curr_frame = 125
# idx: 377, curr_frame = 125
# idx: 378, curr_frame = 126
# idx: 379, curr_frame = 126
# idx: 380, curr_frame = 126
# idx: 381, curr_frame = 127
# idx: 382, curr_frame = 127
# idx: 383, curr_frame = 127
# idx: 384, curr_frame = 128
# idx: 385, curr_frame = 128
# idx: 386, curr_frame = 128
# idx: 387, curr_frame = 129
# idx: 388, curr_frame = 129
# idx: 389, curr_frame = 129
# idx: 390, curr_frame = 130
# idx: 391, curr_frame = 130
# idx: 392, curr_frame = 130
# idx: 393, curr_frame = 131
# idx: 394, curr_frame = 131
# idx: 395, curr_frame = 131
# idx: 396, curr_frame = 132
# idx: 397, curr_frame = 132
# idx: 398, curr_frame = 132
# idx: 399, curr_frame = 133
# idx: 400, curr_frame = 133
# idx: 401, curr_frame = 133
# idx: 402, curr_frame = 134
# idx: 403, curr_frame = 134
# idx: 404, curr_frame = 134
# idx: 405, curr_frame = 135
# idx: 406, curr_frame = 135
# idx: 407, curr_frame = 135
# idx: 408, curr_frame = 136
# idx: 409, curr_frame = 136
# idx: 410, curr_frame = 136
# idx: 411, curr_frame = 137
# idx: 412, curr_frame = 137
# idx: 413, curr_frame = 137
# idx: 414, curr_frame = 138
# idx: 415, curr_frame = 138
# idx: 416, curr_frame = 138
# idx: 417, curr_frame = 139
# idx: 418, curr_frame = 139
# idx: 419, curr_frame = 139
# idx: 420, curr_frame = 140
# idx: 421, curr_frame = 140
# idx: 422, curr_frame = 140
# idx: 423, curr_frame = 141
# idx: 424, curr_frame = 141
# idx: 425, curr_frame = 141
# idx: 426, curr_frame = 142
# idx: 427, curr_frame = 142
# idx: 428, curr_frame = 142
# idx: 429, curr_frame = 143
# idx: 430, curr_frame = 143
# idx: 431, curr_frame = 143
# idx: 432, curr_frame = 144
# idx: 433, curr_frame = 144
# idx: 434, curr_frame = 144
# idx: 435, curr_frame = 145
# idx: 436, curr_frame = 145
# idx: 437, curr_frame = 145
# idx: 438, curr_frame = 146
# idx: 439, curr_frame = 146
# idx: 440, curr_frame = 146
# idx: 441, curr_frame = 147
# idx: 442, curr_frame = 147
# idx: 443, curr_frame = 147
# idx: 444, curr_frame = 148
# idx: 445, curr_frame = 148
# idx: 446, curr_frame = 148
# idx: 447, curr_frame = 149
# idx: 448, curr_frame = 149
# idx: 449, curr_frame = 149
# #####################################
# Found: v0-1
# [[  0.         1.         0.       ... 381.        -1.        -1.      ]
#  [  1.         2.         0.       ... 579.        -1.        -1.      ]
#  [  2.         1.         0.       ... 743.        -1.        -1.      ]
#  ...
#  [  0.         1.       149.       ... 376.         1.         1.      ]
#  [  1.         2.       149.       ... 576.         4.472136   1.      ]
#  [  2.         1.       149.       ... 740.         2.         1.      ]]
# #####################################
# Frames: 150
# (150, 2)
# 450
# idx: 0, curr_frame = 0
# idx: 1, curr_frame = 0
# idx: 2, curr_frame = 0
# idx: 3, curr_frame = 1
# idx: 4, curr_frame = 1
# idx: 5, curr_frame = 1
# idx: 6, curr_frame = 2
# idx: 7, curr_frame = 2
# idx: 8, curr_frame = 2
# idx: 9, curr_frame = 3
# idx: 10, curr_frame = 3
# idx: 11, curr_frame = 3
# idx: 12, curr_frame = 4
# idx: 13, curr_frame = 4
# idx: 14, curr_frame = 4
# idx: 15, curr_frame = 5
# idx: 16, curr_frame = 5
# idx: 17, curr_frame = 5
# idx: 18, curr_frame = 6
# idx: 19, curr_frame = 6
# idx: 20, curr_frame = 6
# idx: 21, curr_frame = 7
# idx: 22, curr_frame = 7
# idx: 23, curr_frame = 7
# idx: 24, curr_frame = 8
# idx: 25, curr_frame = 8
# idx: 26, curr_frame = 8
# idx: 27, curr_frame = 9
# idx: 28, curr_frame = 9
# idx: 29, curr_frame = 9
# idx: 30, curr_frame = 10
# idx: 31, curr_frame = 10
# idx: 32, curr_frame = 10
# idx: 33, curr_frame = 11
# idx: 34, curr_frame = 11
# idx: 35, curr_frame = 11
# idx: 36, curr_frame = 12
# idx: 37, curr_frame = 12
# idx: 38, curr_frame = 12
# idx: 39, curr_frame = 13
# idx: 40, curr_frame = 13
# idx: 41, curr_frame = 13
# idx: 42, curr_frame = 14
# idx: 43, curr_frame = 14
# idx: 44, curr_frame = 14
# idx: 45, curr_frame = 15
# idx: 46, curr_frame = 15
# idx: 47, curr_frame = 15
# idx: 48, curr_frame = 16
# idx: 49, curr_frame = 16
# idx: 50, curr_frame = 16
# idx: 51, curr_frame = 17
# idx: 52, curr_frame = 17
# idx: 53, curr_frame = 17
# idx: 54, curr_frame = 18
# idx: 55, curr_frame = 18
# idx: 56, curr_frame = 18
# idx: 57, curr_frame = 19
# idx: 58, curr_frame = 19
# idx: 59, curr_frame = 19
# idx: 60, curr_frame = 20
# idx: 61, curr_frame = 20
# idx: 62, curr_frame = 20
# idx: 63, curr_frame = 21
# idx: 64, curr_frame = 21
# idx: 65, curr_frame = 21
# idx: 66, curr_frame = 22
# idx: 67, curr_frame = 22
# idx: 68, curr_frame = 22
# idx: 69, curr_frame = 23
# idx: 70, curr_frame = 23
# idx: 71, curr_frame = 23
# idx: 72, curr_frame = 24
# idx: 73, curr_frame = 24
# idx: 74, curr_frame = 24
# idx: 75, curr_frame = 25
# idx: 76, curr_frame = 25
# idx: 77, curr_frame = 25
# idx: 78, curr_frame = 26
# idx: 79, curr_frame = 26
# idx: 80, curr_frame = 26
# idx: 81, curr_frame = 27
# idx: 82, curr_frame = 27
# idx: 83, curr_frame = 27
# idx: 84, curr_frame = 28
# idx: 85, curr_frame = 28
# idx: 86, curr_frame = 28
# idx: 87, curr_frame = 29
# idx: 88, curr_frame = 29
# idx: 89, curr_frame = 29
# idx: 90, curr_frame = 30
# idx: 91, curr_frame = 30
# idx: 92, curr_frame = 30
# idx: 93, curr_frame = 31
# idx: 94, curr_frame = 31
# idx: 95, curr_frame = 31
# idx: 96, curr_frame = 32
# idx: 97, curr_frame = 32
# idx: 98, curr_frame = 32
# idx: 99, curr_frame = 33
# idx: 100, curr_frame = 33
# idx: 101, curr_frame = 33
# idx: 102, curr_frame = 34
# idx: 103, curr_frame = 34
# idx: 104, curr_frame = 34
# idx: 105, curr_frame = 35
# idx: 106, curr_frame = 35
# idx: 107, curr_frame = 35
# idx: 108, curr_frame = 36
# idx: 109, curr_frame = 36
# idx: 110, curr_frame = 36
# idx: 111, curr_frame = 37
# idx: 112, curr_frame = 37
# idx: 113, curr_frame = 37
# idx: 114, curr_frame = 38
# idx: 115, curr_frame = 38
# idx: 116, curr_frame = 38
# idx: 117, curr_frame = 39
# idx: 118, curr_frame = 39
# idx: 119, curr_frame = 39
# idx: 120, curr_frame = 40
# idx: 121, curr_frame = 40
# idx: 122, curr_frame = 40
# idx: 123, curr_frame = 41
# idx: 124, curr_frame = 41
# idx: 125, curr_frame = 41
# idx: 126, curr_frame = 42
# idx: 127, curr_frame = 42
# idx: 128, curr_frame = 42
# idx: 129, curr_frame = 43
# idx: 130, curr_frame = 43
# idx: 131, curr_frame = 43
# idx: 132, curr_frame = 44
# idx: 133, curr_frame = 44
# idx: 134, curr_frame = 44
# idx: 135, curr_frame = 45
# idx: 136, curr_frame = 45
# idx: 137, curr_frame = 45
# idx: 138, curr_frame = 46
# idx: 139, curr_frame = 46
# idx: 140, curr_frame = 46
# idx: 141, curr_frame = 47
# idx: 142, curr_frame = 47
# idx: 143, curr_frame = 47
# idx: 144, curr_frame = 48
# idx: 145, curr_frame = 48
# idx: 146, curr_frame = 48
# idx: 147, curr_frame = 49
# idx: 148, curr_frame = 49
# idx: 149, curr_frame = 49
# idx: 150, curr_frame = 50
# idx: 151, curr_frame = 50
# idx: 152, curr_frame = 50
# idx: 153, curr_frame = 51
# idx: 154, curr_frame = 51
# idx: 155, curr_frame = 51
# idx: 156, curr_frame = 52
# idx: 157, curr_frame = 52
# idx: 158, curr_frame = 52
# idx: 159, curr_frame = 53
# idx: 160, curr_frame = 53
# idx: 161, curr_frame = 53
# idx: 162, curr_frame = 54
# idx: 163, curr_frame = 54
# idx: 164, curr_frame = 54
# idx: 165, curr_frame = 55
# idx: 166, curr_frame = 55
# idx: 167, curr_frame = 55
# idx: 168, curr_frame = 56
# idx: 169, curr_frame = 56
# idx: 170, curr_frame = 56
# idx: 171, curr_frame = 57
# idx: 172, curr_frame = 57
# idx: 173, curr_frame = 57
# idx: 174, curr_frame = 58
# idx: 175, curr_frame = 58
# idx: 176, curr_frame = 58
# idx: 177, curr_frame = 59
# idx: 178, curr_frame = 59
# idx: 179, curr_frame = 59
# idx: 180, curr_frame = 60
# idx: 181, curr_frame = 60
# idx: 182, curr_frame = 60
# idx: 183, curr_frame = 61
# idx: 184, curr_frame = 61
# idx: 185, curr_frame = 61
# idx: 186, curr_frame = 62
# idx: 187, curr_frame = 62
# idx: 188, curr_frame = 62
# idx: 189, curr_frame = 63
# idx: 190, curr_frame = 63
# idx: 191, curr_frame = 63
# idx: 192, curr_frame = 64
# idx: 193, curr_frame = 64
# idx: 194, curr_frame = 64
# idx: 195, curr_frame = 65
# idx: 196, curr_frame = 65
# idx: 197, curr_frame = 65
# idx: 198, curr_frame = 66
# idx: 199, curr_frame = 66
# idx: 200, curr_frame = 66
# idx: 201, curr_frame = 67
# idx: 202, curr_frame = 67
# idx: 203, curr_frame = 67
# idx: 204, curr_frame = 68
# idx: 205, curr_frame = 68
# idx: 206, curr_frame = 68
# idx: 207, curr_frame = 69
# idx: 208, curr_frame = 69
# idx: 209, curr_frame = 69
# idx: 210, curr_frame = 70
# idx: 211, curr_frame = 70
# idx: 212, curr_frame = 70
# idx: 213, curr_frame = 71
# idx: 214, curr_frame = 71
# idx: 215, curr_frame = 71
# idx: 216, curr_frame = 72
# idx: 217, curr_frame = 72
# idx: 218, curr_frame = 72
# idx: 219, curr_frame = 73
# idx: 220, curr_frame = 73
# idx: 221, curr_frame = 73
# idx: 222, curr_frame = 74
# idx: 223, curr_frame = 74
# idx: 224, curr_frame = 74
# idx: 225, curr_frame = 75
# idx: 226, curr_frame = 75
# idx: 227, curr_frame = 75
# idx: 228, curr_frame = 76
# idx: 229, curr_frame = 76
# idx: 230, curr_frame = 76
# idx: 231, curr_frame = 77
# idx: 232, curr_frame = 77
# idx: 233, curr_frame = 77
# idx: 234, curr_frame = 78
# idx: 235, curr_frame = 78
# idx: 236, curr_frame = 78
# idx: 237, curr_frame = 79
# idx: 238, curr_frame = 79
# idx: 239, curr_frame = 79
# idx: 240, curr_frame = 80
# idx: 241, curr_frame = 80
# idx: 242, curr_frame = 80
# idx: 243, curr_frame = 81
# idx: 244, curr_frame = 81
# idx: 245, curr_frame = 81
# idx: 246, curr_frame = 82
# idx: 247, curr_frame = 82
# idx: 248, curr_frame = 82
# idx: 249, curr_frame = 83
# idx: 250, curr_frame = 83
# idx: 251, curr_frame = 83
# idx: 252, curr_frame = 84
# idx: 253, curr_frame = 84
# idx: 254, curr_frame = 84
# idx: 255, curr_frame = 85
# idx: 256, curr_frame = 85
# idx: 257, curr_frame = 85
# idx: 258, curr_frame = 86
# idx: 259, curr_frame = 86
# idx: 260, curr_frame = 86
# idx: 261, curr_frame = 87
# idx: 262, curr_frame = 87
# idx: 263, curr_frame = 87
# idx: 264, curr_frame = 88
# idx: 265, curr_frame = 88
# idx: 266, curr_frame = 88
# idx: 267, curr_frame = 89
# idx: 268, curr_frame = 89
# idx: 269, curr_frame = 89
# idx: 270, curr_frame = 90
# idx: 271, curr_frame = 90
# idx: 272, curr_frame = 90
# idx: 273, curr_frame = 91
# idx: 274, curr_frame = 91
# idx: 275, curr_frame = 91
# idx: 276, curr_frame = 92
# idx: 277, curr_frame = 92
# idx: 278, curr_frame = 92
# idx: 279, curr_frame = 93
# idx: 280, curr_frame = 93
# idx: 281, curr_frame = 93
# idx: 282, curr_frame = 94
# idx: 283, curr_frame = 94
# idx: 284, curr_frame = 94
# idx: 285, curr_frame = 95
# idx: 286, curr_frame = 95
# idx: 287, curr_frame = 95
# idx: 288, curr_frame = 96
# idx: 289, curr_frame = 96
# idx: 290, curr_frame = 96
# idx: 291, curr_frame = 97
# idx: 292, curr_frame = 97
# idx: 293, curr_frame = 97
# idx: 294, curr_frame = 98
# idx: 295, curr_frame = 98
# idx: 296, curr_frame = 98
# idx: 297, curr_frame = 99
# idx: 298, curr_frame = 99
# idx: 299, curr_frame = 99
# idx: 300, curr_frame = 100
# idx: 301, curr_frame = 100
# idx: 302, curr_frame = 100
# idx: 303, curr_frame = 101
# idx: 304, curr_frame = 101
# idx: 305, curr_frame = 101
# idx: 306, curr_frame = 102
# idx: 307, curr_frame = 102
# idx: 308, curr_frame = 102
# idx: 309, curr_frame = 103
# idx: 310, curr_frame = 103
# idx: 311, curr_frame = 103
# idx: 312, curr_frame = 104
# idx: 313, curr_frame = 104
# idx: 314, curr_frame = 104
# idx: 315, curr_frame = 105
# idx: 316, curr_frame = 105
# idx: 317, curr_frame = 105
# idx: 318, curr_frame = 106
# idx: 319, curr_frame = 106
# idx: 320, curr_frame = 106
# idx: 321, curr_frame = 107
# idx: 322, curr_frame = 107
# idx: 323, curr_frame = 107
# idx: 324, curr_frame = 108
# idx: 325, curr_frame = 108
# idx: 326, curr_frame = 108
# idx: 327, curr_frame = 109
# idx: 328, curr_frame = 109
# idx: 329, curr_frame = 109
# idx: 330, curr_frame = 110
# idx: 331, curr_frame = 110
# idx: 332, curr_frame = 110
# idx: 333, curr_frame = 111
# idx: 334, curr_frame = 111
# idx: 335, curr_frame = 111
# idx: 336, curr_frame = 112
# idx: 337, curr_frame = 112
# idx: 338, curr_frame = 112
# idx: 339, curr_frame = 113
# idx: 340, curr_frame = 113
# idx: 341, curr_frame = 113
# idx: 342, curr_frame = 114
# idx: 343, curr_frame = 114
# idx: 344, curr_frame = 114
# idx: 345, curr_frame = 115
# idx: 346, curr_frame = 115
# idx: 347, curr_frame = 115
# idx: 348, curr_frame = 116
# idx: 349, curr_frame = 116
# idx: 350, curr_frame = 116
# idx: 351, curr_frame = 117
# idx: 352, curr_frame = 117
# idx: 353, curr_frame = 117
# idx: 354, curr_frame = 118
# idx: 355, curr_frame = 118
# idx: 356, curr_frame = 118
# idx: 357, curr_frame = 119
# idx: 358, curr_frame = 119
# idx: 359, curr_frame = 119
# idx: 360, curr_frame = 120
# idx: 361, curr_frame = 120
# idx: 362, curr_frame = 120
# idx: 363, curr_frame = 121
# idx: 364, curr_frame = 121
# idx: 365, curr_frame = 121
# idx: 366, curr_frame = 122
# idx: 367, curr_frame = 122
# idx: 368, curr_frame = 122
# idx: 369, curr_frame = 123
# idx: 370, curr_frame = 123
# idx: 371, curr_frame = 123
# idx: 372, curr_frame = 124
# idx: 373, curr_frame = 124
# idx: 374, curr_frame = 124
# idx: 375, curr_frame = 125
# idx: 376, curr_frame = 125
# idx: 377, curr_frame = 125
# idx: 378, curr_frame = 126
# idx: 379, curr_frame = 126
# idx: 380, curr_frame = 126
# idx: 381, curr_frame = 127
# idx: 382, curr_frame = 127
# idx: 383, curr_frame = 127
# idx: 384, curr_frame = 128
# idx: 385, curr_frame = 128
# idx: 386, curr_frame = 128
# idx: 387, curr_frame = 129
# idx: 388, curr_frame = 129
# idx: 389, curr_frame = 129
# idx: 390, curr_frame = 130
# idx: 391, curr_frame = 130
# idx: 392, curr_frame = 130
# idx: 393, curr_frame = 131
# idx: 394, curr_frame = 131
# idx: 395, curr_frame = 131
# idx: 396, curr_frame = 132
# idx: 397, curr_frame = 132
# idx: 398, curr_frame = 132
# idx: 399, curr_frame = 133
# idx: 400, curr_frame = 133
# idx: 401, curr_frame = 133
# idx: 402, curr_frame = 134
# idx: 403, curr_frame = 134
# idx: 404, curr_frame = 134
# idx: 405, curr_frame = 135
# idx: 406, curr_frame = 135
# idx: 407, curr_frame = 135
# idx: 408, curr_frame = 136
# idx: 409, curr_frame = 136
# idx: 410, curr_frame = 136
# idx: 411, curr_frame = 137
# idx: 412, curr_frame = 137
# idx: 413, curr_frame = 137
# idx: 414, curr_frame = 138
# idx: 415, curr_frame = 138
# idx: 416, curr_frame = 138
# idx: 417, curr_frame = 139
# idx: 418, curr_frame = 139
# idx: 419, curr_frame = 139
# idx: 420, curr_frame = 140
# idx: 421, curr_frame = 140
# idx: 422, curr_frame = 140
# idx: 423, curr_frame = 141
# idx: 424, curr_frame = 141
# idx: 425, curr_frame = 141
# idx: 426, curr_frame = 142
# idx: 427, curr_frame = 142
# idx: 428, curr_frame = 142
# idx: 429, curr_frame = 143
# idx: 430, curr_frame = 143
# idx: 431, curr_frame = 143
# idx: 432, curr_frame = 144
# idx: 433, curr_frame = 144
# idx: 434, curr_frame = 144
# idx: 435, curr_frame = 145
# idx: 436, curr_frame = 145
# idx: 437, curr_frame = 145
# idx: 438, curr_frame = 146
# idx: 439, curr_frame = 146
# idx: 440, curr_frame = 146
# idx: 441, curr_frame = 147
# idx: 442, curr_frame = 147
# idx: 443, curr_frame = 147
# idx: 444, curr_frame = 148
# idx: 445, curr_frame = 148
# idx: 446, curr_frame = 148
# idx: 447, curr_frame = 149
# idx: 448, curr_frame = 149
# idx: 449, curr_frame = 149
# #####################################
# Found: v1-0
# [[  1.          2.         33.        ... 651.         -1.
#    -1.       ]
#  [  1.          2.         34.        ... 648.         10.440307
#     1.       ]
#  [  1.          2.         35.        ... 646.         11.18034
#     1.       ]
#  ...
#  [  0.          1.        149.        ... 327.          5.8309517
#     1.       ]
#  [  1.          2.        149.        ... 653.          5.656854
#     1.       ]
#  [  2.          1.        149.        ... 866.          3.6055512
#     1.       ]]
# #####################################
# Frames: 150
# (150, 2)
# 343
# idx: 0, curr_frame = 33
# idx: 1, curr_frame = 34
# idx: 2, curr_frame = 35
# idx: 3, curr_frame = 36
# idx: 4, curr_frame = 36
# idx: 5, curr_frame = 37
# idx: 6, curr_frame = 37
# idx: 7, curr_frame = 38
# idx: 8, curr_frame = 38
# idx: 9, curr_frame = 38
# idx: 10, curr_frame = 39
# idx: 11, curr_frame = 39
# idx: 12, curr_frame = 39
# idx: 13, curr_frame = 40
# idx: 14, curr_frame = 40
# idx: 15, curr_frame = 40
# idx: 16, curr_frame = 41
# idx: 17, curr_frame = 41
# idx: 18, curr_frame = 41
# idx: 19, curr_frame = 42
# idx: 20, curr_frame = 42
# idx: 21, curr_frame = 42
# idx: 22, curr_frame = 43
# idx: 23, curr_frame = 43
# idx: 24, curr_frame = 43
# idx: 25, curr_frame = 44
# idx: 26, curr_frame = 44
# idx: 27, curr_frame = 44
# idx: 28, curr_frame = 45
# idx: 29, curr_frame = 45
# idx: 30, curr_frame = 45
# idx: 31, curr_frame = 46
# idx: 32, curr_frame = 46
# idx: 33, curr_frame = 46
# idx: 34, curr_frame = 47
# idx: 35, curr_frame = 47
# idx: 36, curr_frame = 47
# idx: 37, curr_frame = 48
# idx: 38, curr_frame = 48
# idx: 39, curr_frame = 48
# idx: 40, curr_frame = 49
# idx: 41, curr_frame = 49
# idx: 42, curr_frame = 49
# idx: 43, curr_frame = 50
# idx: 44, curr_frame = 50
# idx: 45, curr_frame = 50
# idx: 46, curr_frame = 51
# idx: 47, curr_frame = 51
# idx: 48, curr_frame = 51
# idx: 49, curr_frame = 52
# idx: 50, curr_frame = 52
# idx: 51, curr_frame = 52
# idx: 52, curr_frame = 53
# idx: 53, curr_frame = 53
# idx: 54, curr_frame = 53
# idx: 55, curr_frame = 54
# idx: 56, curr_frame = 54
# idx: 57, curr_frame = 54
# idx: 58, curr_frame = 55
# idx: 59, curr_frame = 55
# idx: 60, curr_frame = 55
# idx: 61, curr_frame = 56
# idx: 62, curr_frame = 56
# idx: 63, curr_frame = 56
# idx: 64, curr_frame = 57
# idx: 65, curr_frame = 57
# idx: 66, curr_frame = 57
# idx: 67, curr_frame = 58
# idx: 68, curr_frame = 58
# idx: 69, curr_frame = 58
# idx: 70, curr_frame = 59
# idx: 71, curr_frame = 59
# idx: 72, curr_frame = 59
# idx: 73, curr_frame = 60
# idx: 74, curr_frame = 60
# idx: 75, curr_frame = 60
# idx: 76, curr_frame = 61
# idx: 77, curr_frame = 61
# idx: 78, curr_frame = 61
# idx: 79, curr_frame = 62
# idx: 80, curr_frame = 62
# idx: 81, curr_frame = 62
# idx: 82, curr_frame = 63
# idx: 83, curr_frame = 63
# idx: 84, curr_frame = 63
# idx: 85, curr_frame = 64
# idx: 86, curr_frame = 64
# idx: 87, curr_frame = 64
# idx: 88, curr_frame = 65
# idx: 89, curr_frame = 65
# idx: 90, curr_frame = 65
# idx: 91, curr_frame = 66
# idx: 92, curr_frame = 66
# idx: 93, curr_frame = 66
# idx: 94, curr_frame = 67
# idx: 95, curr_frame = 67
# idx: 96, curr_frame = 67
# idx: 97, curr_frame = 68
# idx: 98, curr_frame = 68
# idx: 99, curr_frame = 68
# idx: 100, curr_frame = 69
# idx: 101, curr_frame = 69
# idx: 102, curr_frame = 69
# idx: 103, curr_frame = 70
# idx: 104, curr_frame = 70
# idx: 105, curr_frame = 70
# idx: 106, curr_frame = 71
# idx: 107, curr_frame = 71
# idx: 108, curr_frame = 71
# idx: 109, curr_frame = 72
# idx: 110, curr_frame = 72
# idx: 111, curr_frame = 72
# idx: 112, curr_frame = 73
# idx: 113, curr_frame = 73
# idx: 114, curr_frame = 73
# idx: 115, curr_frame = 74
# idx: 116, curr_frame = 74
# idx: 117, curr_frame = 74
# idx: 118, curr_frame = 75
# idx: 119, curr_frame = 75
# idx: 120, curr_frame = 75
# idx: 121, curr_frame = 76
# idx: 122, curr_frame = 76
# idx: 123, curr_frame = 76
# idx: 124, curr_frame = 77
# idx: 125, curr_frame = 77
# idx: 126, curr_frame = 77
# idx: 127, curr_frame = 78
# idx: 128, curr_frame = 78
# idx: 129, curr_frame = 78
# idx: 130, curr_frame = 79
# idx: 131, curr_frame = 79
# idx: 132, curr_frame = 79
# idx: 133, curr_frame = 80
# idx: 134, curr_frame = 80
# idx: 135, curr_frame = 80
# idx: 136, curr_frame = 81
# idx: 137, curr_frame = 81
# idx: 138, curr_frame = 81
# idx: 139, curr_frame = 82
# idx: 140, curr_frame = 82
# idx: 141, curr_frame = 82
# idx: 142, curr_frame = 83
# idx: 143, curr_frame = 83
# idx: 144, curr_frame = 83
# idx: 145, curr_frame = 84
# idx: 146, curr_frame = 84
# idx: 147, curr_frame = 84
# idx: 148, curr_frame = 85
# idx: 149, curr_frame = 85
# idx: 150, curr_frame = 85
# idx: 151, curr_frame = 86
# idx: 152, curr_frame = 86
# idx: 153, curr_frame = 86
# idx: 154, curr_frame = 87
# idx: 155, curr_frame = 87
# idx: 156, curr_frame = 87
# idx: 157, curr_frame = 88
# idx: 158, curr_frame = 88
# idx: 159, curr_frame = 88
# idx: 160, curr_frame = 89
# idx: 161, curr_frame = 89
# idx: 162, curr_frame = 89
# idx: 163, curr_frame = 90
# idx: 164, curr_frame = 90
# idx: 165, curr_frame = 90
# idx: 166, curr_frame = 91
# idx: 167, curr_frame = 91
# idx: 168, curr_frame = 91
# idx: 169, curr_frame = 92
# idx: 170, curr_frame = 92
# idx: 171, curr_frame = 92
# idx: 172, curr_frame = 93
# idx: 173, curr_frame = 93
# idx: 174, curr_frame = 93
# idx: 175, curr_frame = 94
# idx: 176, curr_frame = 94
# idx: 177, curr_frame = 94
# idx: 178, curr_frame = 95
# idx: 179, curr_frame = 95
# idx: 180, curr_frame = 95
# idx: 181, curr_frame = 96
# idx: 182, curr_frame = 96
# idx: 183, curr_frame = 96
# idx: 184, curr_frame = 97
# idx: 185, curr_frame = 97
# idx: 186, curr_frame = 97
# idx: 187, curr_frame = 98
# idx: 188, curr_frame = 98
# idx: 189, curr_frame = 98
# idx: 190, curr_frame = 99
# idx: 191, curr_frame = 99
# idx: 192, curr_frame = 99
# idx: 193, curr_frame = 100
# idx: 194, curr_frame = 100
# idx: 195, curr_frame = 100
# idx: 196, curr_frame = 101
# idx: 197, curr_frame = 101
# idx: 198, curr_frame = 101
# idx: 199, curr_frame = 102
# idx: 200, curr_frame = 102
# idx: 201, curr_frame = 102
# idx: 202, curr_frame = 103
# idx: 203, curr_frame = 103
# idx: 204, curr_frame = 103
# idx: 205, curr_frame = 104
# idx: 206, curr_frame = 104
# idx: 207, curr_frame = 104
# idx: 208, curr_frame = 105
# idx: 209, curr_frame = 105
# idx: 210, curr_frame = 105
# idx: 211, curr_frame = 106
# idx: 212, curr_frame = 106
# idx: 213, curr_frame = 106
# idx: 214, curr_frame = 107
# idx: 215, curr_frame = 107
# idx: 216, curr_frame = 107
# idx: 217, curr_frame = 108
# idx: 218, curr_frame = 108
# idx: 219, curr_frame = 108
# idx: 220, curr_frame = 109
# idx: 221, curr_frame = 109
# idx: 222, curr_frame = 109
# idx: 223, curr_frame = 110
# idx: 224, curr_frame = 110
# idx: 225, curr_frame = 110
# idx: 226, curr_frame = 111
# idx: 227, curr_frame = 111
# idx: 228, curr_frame = 111
# idx: 229, curr_frame = 112
# idx: 230, curr_frame = 112
# idx: 231, curr_frame = 112
# idx: 232, curr_frame = 113
# idx: 233, curr_frame = 113
# idx: 234, curr_frame = 113
# idx: 235, curr_frame = 114
# idx: 236, curr_frame = 114
# idx: 237, curr_frame = 114
# idx: 238, curr_frame = 115
# idx: 239, curr_frame = 115
# idx: 240, curr_frame = 115
# idx: 241, curr_frame = 116
# idx: 242, curr_frame = 116
# idx: 243, curr_frame = 116
# idx: 244, curr_frame = 117
# idx: 245, curr_frame = 117
# idx: 246, curr_frame = 117
# idx: 247, curr_frame = 118
# idx: 248, curr_frame = 118
# idx: 249, curr_frame = 118
# idx: 250, curr_frame = 119
# idx: 251, curr_frame = 119
# idx: 252, curr_frame = 119
# idx: 253, curr_frame = 120
# idx: 254, curr_frame = 120
# idx: 255, curr_frame = 120
# idx: 256, curr_frame = 121
# idx: 257, curr_frame = 121
# idx: 258, curr_frame = 121
# idx: 259, curr_frame = 122
# idx: 260, curr_frame = 122
# idx: 261, curr_frame = 122
# idx: 262, curr_frame = 123
# idx: 263, curr_frame = 123
# idx: 264, curr_frame = 123
# idx: 265, curr_frame = 124
# idx: 266, curr_frame = 124
# idx: 267, curr_frame = 124
# idx: 268, curr_frame = 125
# idx: 269, curr_frame = 125
# idx: 270, curr_frame = 125
# idx: 271, curr_frame = 126
# idx: 272, curr_frame = 126
# idx: 273, curr_frame = 126
# idx: 274, curr_frame = 127
# idx: 275, curr_frame = 127
# idx: 276, curr_frame = 127
# idx: 277, curr_frame = 128
# idx: 278, curr_frame = 128
# idx: 279, curr_frame = 128
# idx: 280, curr_frame = 129
# idx: 281, curr_frame = 129
# idx: 282, curr_frame = 129
# idx: 283, curr_frame = 130
# idx: 284, curr_frame = 130
# idx: 285, curr_frame = 130
# idx: 286, curr_frame = 131
# idx: 287, curr_frame = 131
# idx: 288, curr_frame = 131
# idx: 289, curr_frame = 132
# idx: 290, curr_frame = 132
# idx: 291, curr_frame = 132
# idx: 292, curr_frame = 133
# idx: 293, curr_frame = 133
# idx: 294, curr_frame = 133
# idx: 295, curr_frame = 134
# idx: 296, curr_frame = 134
# idx: 297, curr_frame = 134
# idx: 298, curr_frame = 135
# idx: 299, curr_frame = 135
# idx: 300, curr_frame = 135
# idx: 301, curr_frame = 136
# idx: 302, curr_frame = 136
# idx: 303, curr_frame = 136
# idx: 304, curr_frame = 137
# idx: 305, curr_frame = 137
# idx: 306, curr_frame = 137
# idx: 307, curr_frame = 138
# idx: 308, curr_frame = 138
# idx: 309, curr_frame = 138
# idx: 310, curr_frame = 139
# idx: 311, curr_frame = 139
# idx: 312, curr_frame = 139
# idx: 313, curr_frame = 140
# idx: 314, curr_frame = 140
# idx: 315, curr_frame = 140
# idx: 316, curr_frame = 141
# idx: 317, curr_frame = 141
# idx: 318, curr_frame = 141
# idx: 319, curr_frame = 142
# idx: 320, curr_frame = 142
# idx: 321, curr_frame = 142
# idx: 322, curr_frame = 143
# idx: 323, curr_frame = 143
# idx: 324, curr_frame = 143
# idx: 325, curr_frame = 144
# idx: 326, curr_frame = 144
# idx: 327, curr_frame = 144
# idx: 328, curr_frame = 145
# idx: 329, curr_frame = 145
# idx: 330, curr_frame = 145
# idx: 331, curr_frame = 146
# idx: 332, curr_frame = 146
# idx: 333, curr_frame = 146
# idx: 334, curr_frame = 147
# idx: 335, curr_frame = 147
# idx: 336, curr_frame = 147
# idx: 337, curr_frame = 148
# idx: 338, curr_frame = 148
# idx: 339, curr_frame = 148
# idx: 340, curr_frame = 149
# idx: 341, curr_frame = 149
# idx: 342, curr_frame = 149
# #####################################
# Found: v1-1
# [[  0.          1.          0.        ... 139.         -1.
#    -1.       ]
#  [  1.          2.          0.        ... 432.         -1.
#    -1.       ]
#  [  0.          1.          1.        ... 140.          1.
#     1.       ]
#  ...
#  [  0.          1.        149.        ... 238.          6.4031243
#     1.       ]
#  [  1.          2.        149.        ... 598.          5.
#     1.       ]
#  [  2.          1.        149.        ... 816.          2.828427
#     1.       ]]
# #####################################
# Frames: 150
# (150, 2)
# 415
# idx: 0, curr_frame = 0
# idx: 1, curr_frame = 0
# idx: 2, curr_frame = 1
# idx: 3, curr_frame = 1
# idx: 4, curr_frame = 2
# idx: 5, curr_frame = 2
# idx: 6, curr_frame = 3
# idx: 7, curr_frame = 3
# idx: 8, curr_frame = 4
# idx: 9, curr_frame = 4
# idx: 10, curr_frame = 5
# idx: 11, curr_frame = 5
# idx: 12, curr_frame = 6
# idx: 13, curr_frame = 6
# idx: 14, curr_frame = 7
# idx: 15, curr_frame = 7
# idx: 16, curr_frame = 8
# idx: 17, curr_frame = 8
# idx: 18, curr_frame = 9
# idx: 19, curr_frame = 9
# idx: 20, curr_frame = 10
# idx: 21, curr_frame = 10
# idx: 22, curr_frame = 11
# idx: 23, curr_frame = 11
# idx: 24, curr_frame = 12
# idx: 25, curr_frame = 12
# idx: 26, curr_frame = 13
# idx: 27, curr_frame = 13
# idx: 28, curr_frame = 14
# idx: 29, curr_frame = 14
# idx: 30, curr_frame = 15
# idx: 31, curr_frame = 15
# idx: 32, curr_frame = 16
# idx: 33, curr_frame = 16
# idx: 34, curr_frame = 17
# idx: 35, curr_frame = 17
# idx: 36, curr_frame = 18
# idx: 37, curr_frame = 18
# idx: 38, curr_frame = 19
# idx: 39, curr_frame = 19
# idx: 40, curr_frame = 20
# idx: 41, curr_frame = 20
# idx: 42, curr_frame = 21
# idx: 43, curr_frame = 21
# idx: 44, curr_frame = 22
# idx: 45, curr_frame = 22
# idx: 46, curr_frame = 23
# idx: 47, curr_frame = 23
# idx: 48, curr_frame = 24
# idx: 49, curr_frame = 24
# idx: 50, curr_frame = 25
# idx: 51, curr_frame = 25
# idx: 52, curr_frame = 26
# idx: 53, curr_frame = 26
# idx: 54, curr_frame = 27
# idx: 55, curr_frame = 27
# idx: 56, curr_frame = 28
# idx: 57, curr_frame = 28
# idx: 58, curr_frame = 29
# idx: 59, curr_frame = 29
# idx: 60, curr_frame = 30
# idx: 61, curr_frame = 30
# idx: 62, curr_frame = 31
# idx: 63, curr_frame = 31
# idx: 64, curr_frame = 32
# idx: 65, curr_frame = 32
# idx: 66, curr_frame = 33
# idx: 67, curr_frame = 33
# idx: 68, curr_frame = 34
# idx: 69, curr_frame = 34
# idx: 70, curr_frame = 35
# idx: 71, curr_frame = 35
# idx: 72, curr_frame = 35
# idx: 73, curr_frame = 36
# idx: 74, curr_frame = 36
# idx: 75, curr_frame = 36
# idx: 76, curr_frame = 37
# idx: 77, curr_frame = 37
# idx: 78, curr_frame = 37
# idx: 79, curr_frame = 38
# idx: 80, curr_frame = 38
# idx: 81, curr_frame = 38
# idx: 82, curr_frame = 39
# idx: 83, curr_frame = 39
# idx: 84, curr_frame = 39
# idx: 85, curr_frame = 40
# idx: 86, curr_frame = 40
# idx: 87, curr_frame = 40
# idx: 88, curr_frame = 41
# idx: 89, curr_frame = 41
# idx: 90, curr_frame = 41
# idx: 91, curr_frame = 42
# idx: 92, curr_frame = 42
# idx: 93, curr_frame = 42
# idx: 94, curr_frame = 43
# idx: 95, curr_frame = 43
# idx: 96, curr_frame = 43
# idx: 97, curr_frame = 44
# idx: 98, curr_frame = 44
# idx: 99, curr_frame = 44
# idx: 100, curr_frame = 45
# idx: 101, curr_frame = 45
# idx: 102, curr_frame = 45
# idx: 103, curr_frame = 46
# idx: 104, curr_frame = 46
# idx: 105, curr_frame = 46
# idx: 106, curr_frame = 47
# idx: 107, curr_frame = 47
# idx: 108, curr_frame = 47
# idx: 109, curr_frame = 48
# idx: 110, curr_frame = 48
# idx: 111, curr_frame = 48
# idx: 112, curr_frame = 49
# idx: 113, curr_frame = 49
# idx: 114, curr_frame = 49
# idx: 115, curr_frame = 50
# idx: 116, curr_frame = 50
# idx: 117, curr_frame = 50
# idx: 118, curr_frame = 51
# idx: 119, curr_frame = 51
# idx: 120, curr_frame = 51
# idx: 121, curr_frame = 52
# idx: 122, curr_frame = 52
# idx: 123, curr_frame = 52
# idx: 124, curr_frame = 53
# idx: 125, curr_frame = 53
# idx: 126, curr_frame = 53
# idx: 127, curr_frame = 54
# idx: 128, curr_frame = 54
# idx: 129, curr_frame = 54
# idx: 130, curr_frame = 55
# idx: 131, curr_frame = 55
# idx: 132, curr_frame = 55
# idx: 133, curr_frame = 56
# idx: 134, curr_frame = 56
# idx: 135, curr_frame = 56
# idx: 136, curr_frame = 57
# idx: 137, curr_frame = 57
# idx: 138, curr_frame = 57
# idx: 139, curr_frame = 58
# idx: 140, curr_frame = 58
# idx: 141, curr_frame = 58
# idx: 142, curr_frame = 59
# idx: 143, curr_frame = 59
# idx: 144, curr_frame = 59
# idx: 145, curr_frame = 60
# idx: 146, curr_frame = 60
# idx: 147, curr_frame = 60
# idx: 148, curr_frame = 61
# idx: 149, curr_frame = 61
# idx: 150, curr_frame = 61
# idx: 151, curr_frame = 62
# idx: 152, curr_frame = 62
# idx: 153, curr_frame = 62
# idx: 154, curr_frame = 63
# idx: 155, curr_frame = 63
# idx: 156, curr_frame = 63
# idx: 157, curr_frame = 64
# idx: 158, curr_frame = 64
# idx: 159, curr_frame = 64
# idx: 160, curr_frame = 65
# idx: 161, curr_frame = 65
# idx: 162, curr_frame = 65
# idx: 163, curr_frame = 66
# idx: 164, curr_frame = 66
# idx: 165, curr_frame = 66
# idx: 166, curr_frame = 67
# idx: 167, curr_frame = 67
# idx: 168, curr_frame = 67
# idx: 169, curr_frame = 68
# idx: 170, curr_frame = 68
# idx: 171, curr_frame = 68
# idx: 172, curr_frame = 69
# idx: 173, curr_frame = 69
# idx: 174, curr_frame = 69
# idx: 175, curr_frame = 70
# idx: 176, curr_frame = 70
# idx: 177, curr_frame = 70
# idx: 178, curr_frame = 71
# idx: 179, curr_frame = 71
# idx: 180, curr_frame = 71
# idx: 181, curr_frame = 72
# idx: 182, curr_frame = 72
# idx: 183, curr_frame = 72
# idx: 184, curr_frame = 73
# idx: 185, curr_frame = 73
# idx: 186, curr_frame = 73
# idx: 187, curr_frame = 74
# idx: 188, curr_frame = 74
# idx: 189, curr_frame = 74
# idx: 190, curr_frame = 75
# idx: 191, curr_frame = 75
# idx: 192, curr_frame = 75
# idx: 193, curr_frame = 76
# idx: 194, curr_frame = 76
# idx: 195, curr_frame = 76
# idx: 196, curr_frame = 77
# idx: 197, curr_frame = 77
# idx: 198, curr_frame = 77
# idx: 199, curr_frame = 78
# idx: 200, curr_frame = 78
# idx: 201, curr_frame = 78
# idx: 202, curr_frame = 79
# idx: 203, curr_frame = 79
# idx: 204, curr_frame = 79
# idx: 205, curr_frame = 80
# idx: 206, curr_frame = 80
# idx: 207, curr_frame = 80
# idx: 208, curr_frame = 81
# idx: 209, curr_frame = 81
# idx: 210, curr_frame = 81
# idx: 211, curr_frame = 82
# idx: 212, curr_frame = 82
# idx: 213, curr_frame = 82
# idx: 214, curr_frame = 83
# idx: 215, curr_frame = 83
# idx: 216, curr_frame = 83
# idx: 217, curr_frame = 84
# idx: 218, curr_frame = 84
# idx: 219, curr_frame = 84
# idx: 220, curr_frame = 85
# idx: 221, curr_frame = 85
# idx: 222, curr_frame = 85
# idx: 223, curr_frame = 86
# idx: 224, curr_frame = 86
# idx: 225, curr_frame = 86
# idx: 226, curr_frame = 87
# idx: 227, curr_frame = 87
# idx: 228, curr_frame = 87
# idx: 229, curr_frame = 88
# idx: 230, curr_frame = 88
# idx: 231, curr_frame = 88
# idx: 232, curr_frame = 89
# idx: 233, curr_frame = 89
# idx: 234, curr_frame = 89
# idx: 235, curr_frame = 90
# idx: 236, curr_frame = 90
# idx: 237, curr_frame = 90
# idx: 238, curr_frame = 91
# idx: 239, curr_frame = 91
# idx: 240, curr_frame = 91
# idx: 241, curr_frame = 92
# idx: 242, curr_frame = 92
# idx: 243, curr_frame = 92
# idx: 244, curr_frame = 93
# idx: 245, curr_frame = 93
# idx: 246, curr_frame = 93
# idx: 247, curr_frame = 94
# idx: 248, curr_frame = 94
# idx: 249, curr_frame = 94
# idx: 250, curr_frame = 95
# idx: 251, curr_frame = 95
# idx: 252, curr_frame = 95
# idx: 253, curr_frame = 96
# idx: 254, curr_frame = 96
# idx: 255, curr_frame = 96
# idx: 256, curr_frame = 97
# idx: 257, curr_frame = 97
# idx: 258, curr_frame = 97
# idx: 259, curr_frame = 98
# idx: 260, curr_frame = 98
# idx: 261, curr_frame = 98
# idx: 262, curr_frame = 99
# idx: 263, curr_frame = 99
# idx: 264, curr_frame = 99
# idx: 265, curr_frame = 100
# idx: 266, curr_frame = 100
# idx: 267, curr_frame = 100
# idx: 268, curr_frame = 101
# idx: 269, curr_frame = 101
# idx: 270, curr_frame = 101
# idx: 271, curr_frame = 102
# idx: 272, curr_frame = 102
# idx: 273, curr_frame = 102
# idx: 274, curr_frame = 103
# idx: 275, curr_frame = 103
# idx: 276, curr_frame = 103
# idx: 277, curr_frame = 104
# idx: 278, curr_frame = 104
# idx: 279, curr_frame = 104
# idx: 280, curr_frame = 105
# idx: 281, curr_frame = 105
# idx: 282, curr_frame = 105
# idx: 283, curr_frame = 106
# idx: 284, curr_frame = 106
# idx: 285, curr_frame = 106
# idx: 286, curr_frame = 107
# idx: 287, curr_frame = 107
# idx: 288, curr_frame = 107
# idx: 289, curr_frame = 108
# idx: 290, curr_frame = 108
# idx: 291, curr_frame = 108
# idx: 292, curr_frame = 109
# idx: 293, curr_frame = 109
# idx: 294, curr_frame = 109
# idx: 295, curr_frame = 110
# idx: 296, curr_frame = 110
# idx: 297, curr_frame = 110
# idx: 298, curr_frame = 111
# idx: 299, curr_frame = 111
# idx: 300, curr_frame = 111
# idx: 301, curr_frame = 112
# idx: 302, curr_frame = 112
# idx: 303, curr_frame = 112
# idx: 304, curr_frame = 113
# idx: 305, curr_frame = 113
# idx: 306, curr_frame = 113
# idx: 307, curr_frame = 114
# idx: 308, curr_frame = 114
# idx: 309, curr_frame = 114
# idx: 310, curr_frame = 115
# idx: 311, curr_frame = 115
# idx: 312, curr_frame = 115
# idx: 313, curr_frame = 116
# idx: 314, curr_frame = 116
# idx: 315, curr_frame = 116
# idx: 316, curr_frame = 117
# idx: 317, curr_frame = 117
# idx: 318, curr_frame = 117
# idx: 319, curr_frame = 118
# idx: 320, curr_frame = 118
# idx: 321, curr_frame = 118
# idx: 322, curr_frame = 119
# idx: 323, curr_frame = 119
# idx: 324, curr_frame = 119
# idx: 325, curr_frame = 120
# idx: 326, curr_frame = 120
# idx: 327, curr_frame = 120
# idx: 328, curr_frame = 121
# idx: 329, curr_frame = 121
# idx: 330, curr_frame = 121
# idx: 331, curr_frame = 122
# idx: 332, curr_frame = 122
# idx: 333, curr_frame = 122
# idx: 334, curr_frame = 123
# idx: 335, curr_frame = 123
# idx: 336, curr_frame = 123
# idx: 337, curr_frame = 124
# idx: 338, curr_frame = 124
# idx: 339, curr_frame = 124
# idx: 340, curr_frame = 125
# idx: 341, curr_frame = 125
# idx: 342, curr_frame = 125
# idx: 343, curr_frame = 126
# idx: 344, curr_frame = 126
# idx: 345, curr_frame = 126
# idx: 346, curr_frame = 127
# idx: 347, curr_frame = 127
# idx: 348, curr_frame = 127
# idx: 349, curr_frame = 128
# idx: 350, curr_frame = 128
# idx: 351, curr_frame = 128
# idx: 352, curr_frame = 129
# idx: 353, curr_frame = 129
# idx: 354, curr_frame = 129
# idx: 355, curr_frame = 130
# idx: 356, curr_frame = 130
# idx: 357, curr_frame = 130
# idx: 358, curr_frame = 131
# idx: 359, curr_frame = 131
# idx: 360, curr_frame = 131
# idx: 361, curr_frame = 132
# idx: 362, curr_frame = 132
# idx: 363, curr_frame = 132
# idx: 364, curr_frame = 133
# idx: 365, curr_frame = 133
# idx: 366, curr_frame = 133
# idx: 367, curr_frame = 134
# idx: 368, curr_frame = 134
# idx: 369, curr_frame = 134
# idx: 370, curr_frame = 135
# idx: 371, curr_frame = 135
# idx: 372, curr_frame = 135
# idx: 373, curr_frame = 136
# idx: 374, curr_frame = 136
# idx: 375, curr_frame = 136
# idx: 376, curr_frame = 137
# idx: 377, curr_frame = 137
# idx: 378, curr_frame = 137
# idx: 379, curr_frame = 138
# idx: 380, curr_frame = 138
# idx: 381, curr_frame = 138
# idx: 382, curr_frame = 139
# idx: 383, curr_frame = 139
# idx: 384, curr_frame = 139
# idx: 385, curr_frame = 140
# idx: 386, curr_frame = 140
# idx: 387, curr_frame = 140
# idx: 388, curr_frame = 141
# idx: 389, curr_frame = 141
# idx: 390, curr_frame = 141
# idx: 391, curr_frame = 142
# idx: 392, curr_frame = 142
# idx: 393, curr_frame = 142
# idx: 394, curr_frame = 143
# idx: 395, curr_frame = 143
# idx: 396, curr_frame = 143
# idx: 397, curr_frame = 144
# idx: 398, curr_frame = 144
# idx: 399, curr_frame = 144
# idx: 400, curr_frame = 145
# idx: 401, curr_frame = 145
# idx: 402, curr_frame = 145
# idx: 403, curr_frame = 146
# idx: 404, curr_frame = 146
# idx: 405, curr_frame = 146
# idx: 406, curr_frame = 147
# idx: 407, curr_frame = 147
# idx: 408, curr_frame = 147
# idx: 409, curr_frame = 148
# idx: 410, curr_frame = 148
# idx: 411, curr_frame = 148
# idx: 412, curr_frame = 149
# idx: 413, curr_frame = 149
# idx: 414, curr_frame = 149
# #####################################
# Found: v2-0
# [[ 2.0000000e+00  2.0000000e+00  0.0000000e+00 ...  3.2700000e+02
#   -1.0000000e+00 -1.0000000e+00]
#  [ 2.0000000e+00  2.0000000e+00  6.4000000e+01 ...  5.0500000e+02
#    1.4023427e+03  6.4000000e+01]
#  [ 3.0000000e+00  2.0000000e+00  6.4000000e+01 ...  7.9000000e+02
#   -1.0000000e+00 -1.0000000e+00]
#  ...
#  [ 3.0000000e+00  2.0000000e+00  1.2400000e+02 ...  7.4400000e+02
#    2.7018513e+01  1.0000000e+00]
#  [ 3.0000000e+00  2.0000000e+00  1.2500000e+02 ...  7.4800000e+02
#    3.6221542e+01  1.0000000e+00]
#  [ 3.0000000e+00  2.0000000e+00  1.2600000e+02 ...  7.5100000e+02
#    4.0112343e+01  1.0000000e+00]]
# #####################################
# Frames: 150
# (150, 2)
# 176
# idx: 0, curr_frame = 0
# idx: 1, curr_frame = 64
# idx: 2, curr_frame = 64
# idx: 3, curr_frame = 65
# idx: 4, curr_frame = 65
# idx: 5, curr_frame = 66
# idx: 6, curr_frame = 66
# idx: 7, curr_frame = 67
# idx: 8, curr_frame = 67
# idx: 9, curr_frame = 68
# idx: 10, curr_frame = 68
# idx: 11, curr_frame = 69
# idx: 12, curr_frame = 69
# idx: 13, curr_frame = 70
# idx: 14, curr_frame = 70
# idx: 15, curr_frame = 70
# idx: 16, curr_frame = 71
# idx: 17, curr_frame = 71
# idx: 18, curr_frame = 71
# idx: 19, curr_frame = 72
# idx: 20, curr_frame = 72
# idx: 21, curr_frame = 73
# idx: 22, curr_frame = 73
# idx: 23, curr_frame = 74
# idx: 24, curr_frame = 74
# idx: 25, curr_frame = 75
# idx: 26, curr_frame = 75
# idx: 27, curr_frame = 76
# idx: 28, curr_frame = 76
# idx: 29, curr_frame = 76
# idx: 30, curr_frame = 77
# idx: 31, curr_frame = 77
# idx: 32, curr_frame = 77
# idx: 33, curr_frame = 78
# idx: 34, curr_frame = 78
# idx: 35, curr_frame = 78
# idx: 36, curr_frame = 79
# idx: 37, curr_frame = 79
# idx: 38, curr_frame = 79
# idx: 39, curr_frame = 80
# idx: 40, curr_frame = 80
# idx: 41, curr_frame = 80
# idx: 42, curr_frame = 81
# idx: 43, curr_frame = 81
# idx: 44, curr_frame = 81
# idx: 45, curr_frame = 82
# idx: 46, curr_frame = 82
# idx: 47, curr_frame = 82
# idx: 48, curr_frame = 83
# idx: 49, curr_frame = 83
# idx: 50, curr_frame = 83
# idx: 51, curr_frame = 84
# idx: 52, curr_frame = 84
# idx: 53, curr_frame = 84
# idx: 54, curr_frame = 85
# idx: 55, curr_frame = 85
# idx: 56, curr_frame = 85
# idx: 57, curr_frame = 86
# idx: 58, curr_frame = 86
# idx: 59, curr_frame = 86
# idx: 60, curr_frame = 87
# idx: 61, curr_frame = 87
# idx: 62, curr_frame = 87
# idx: 63, curr_frame = 88
# idx: 64, curr_frame = 88
# idx: 65, curr_frame = 88
# idx: 66, curr_frame = 89
# idx: 67, curr_frame = 89
# idx: 68, curr_frame = 89
# idx: 69, curr_frame = 90
# idx: 70, curr_frame = 90
# ...
# idx: 3, curr_frame = 68
# idx: 4, curr_frame = 68
# idx: 5, curr_frame = 69
# idx: 6, curr_frame = 69
# idx: 7, curr_frame = 70
# idx: 8, curr_frame = 70
# idx: 9, curr_frame = 71
# idx: 10, curr_frame = 71
# idx: 11, curr_frame = 72
# idx: 12, curr_frame = 72
# idx: 13, curr_frame = 73
# idx: 14, curr_frame = 73
# idx: 15, curr_frame = 73
# idx: 16, curr_frame = 74
# idx: 17, curr_frame = 74
# idx: 18, curr_frame = 74
# idx: 19, curr_frame = 75
# idx: 20, curr_frame = 75
# idx: 21, curr_frame = 75
# idx: 22, curr_frame = 76
# idx: 23, curr_frame = 76
# idx: 24, curr_frame = 76
# idx: 25, curr_frame = 77
# idx: 26, curr_frame = 77
# idx: 27, curr_frame = 77
# idx: 28, curr_frame = 77
# idx: 29, curr_frame = 78
# idx: 30, curr_frame = 78
# idx: 31, curr_frame = 78
# idx: 32, curr_frame = 78
# idx: 33, curr_frame = 79
# idx: 34, curr_frame = 79
# idx: 35, curr_frame = 79
# idx: 36, curr_frame = 79
# idx: 37, curr_frame = 80
# idx: 38, curr_frame = 80
# idx: 39, curr_frame = 80
# idx: 40, curr_frame = 80
# idx: 41, curr_frame = 81
# idx: 42, curr_frame = 81
# idx: 43, curr_frame = 81
# idx: 44, curr_frame = 81
# idx: 45, curr_frame = 82
# idx: 46, curr_frame = 82
# idx: 47, curr_frame = 82
# idx: 48, curr_frame = 82
# idx: 49, curr_frame = 83
# idx: 50, curr_frame = 83
# idx: 51, curr_frame = 83
# idx: 52, curr_frame = 84
# idx: 53, curr_frame = 84
# idx: 54, curr_frame = 84
# idx: 55, curr_frame = 85
# idx: 56, curr_frame = 85
# idx: 57, curr_frame = 85
# idx: 58, curr_frame = 85
# idx: 59, curr_frame = 86
# idx: 60, curr_frame = 86
# idx: 61, curr_frame = 86
# idx: 62, curr_frame = 86
# idx: 63, curr_frame = 86
# idx: 64, curr_frame = 87
# idx: 65, curr_frame = 87
# idx: 66, curr_frame = 87
# idx: 67, curr_frame = 87
# idx: 68, curr_frame = 87
# idx: 69, curr_frame = 88
# idx: 70, curr_frame = 88
# idx: 71, curr_frame = 88
# idx: 72, curr_frame = 88
# idx: 73, curr_frame = 88
# idx: 74, curr_frame = 89
# idx: 75, curr_frame = 89
# idx: 76, curr_frame = 89
# idx: 77, curr_frame = 89
# idx: 78, curr_frame = 89
# idx: 79, curr_frame = 90
# idx: 80, curr_frame = 90
# idx: 81, curr_frame = 90
# idx: 82, curr_frame = 90
# idx: 83, curr_frame = 90
# idx: 84, curr_frame = 91
# idx: 85, curr_frame = 91
# idx: 86, curr_frame = 91
# idx: 87, curr_frame = 91
# idx: 88, curr_frame = 91
# idx: 89, curr_frame = 92
# idx: 90, curr_frame = 92
# idx: 91, curr_frame = 92
# idx: 92, curr_frame = 92
# idx: 93, curr_frame = 92
# idx: 94, curr_frame = 93
# idx: 95, curr_frame = 93
# idx: 96, curr_frame = 93
# idx: 97, curr_frame = 93
# idx: 98, curr_frame = 94
# idx: 99, curr_frame = 94
# idx: 100, curr_frame = 94
# idx: 101, curr_frame = 94
# idx: 102, curr_frame = 95
# idx: 103, curr_frame = 95
# idx: 104, curr_frame = 95
# idx: 105, curr_frame = 95
# idx: 106, curr_frame = 96
# idx: 107, curr_frame = 96
# idx: 108, curr_frame = 96
# idx: 109, curr_frame = 96
# idx: 110, curr_frame = 97
# idx: 111, curr_frame = 97
# idx: 112, curr_frame = 97
# idx: 113, curr_frame = 97
# idx: 114, curr_frame = 98
# idx: 115, curr_frame = 98
# idx: 116, curr_frame = 98
# idx: 117, curr_frame = 98
# idx: 118, curr_frame = 98
# idx: 119, curr_frame = 99
# idx: 120, curr_frame = 99
# idx: 121, curr_frame = 99
# idx: 122, curr_frame = 99
# idx: 123, curr_frame = 99
# idx: 124, curr_frame = 100
# idx: 125, curr_frame = 100
# idx: 126, curr_frame = 100
# idx: 127, curr_frame = 100
# idx: 128, curr_frame = 100
# idx: 129, curr_frame = 101
# idx: 130, curr_frame = 101
# idx: 131, curr_frame = 101
# idx: 132, curr_frame = 101
# idx: 133, curr_frame = 101
# idx: 134, curr_frame = 102
# idx: 135, curr_frame = 102
# idx: 136, curr_frame = 102
# idx: 137, curr_frame = 102
# idx: 138, curr_frame = 102
# idx: 139, curr_frame = 103
# idx: 140, curr_frame = 103
# idx: 141, curr_frame = 103
# idx: 142, curr_frame = 103
# idx: 143, curr_frame = 103
# idx: 144, curr_frame = 104
# idx: 145, curr_frame = 104
# idx: 146, curr_frame = 104
# idx: 147, curr_frame = 104
# idx: 148, curr_frame = 104
# idx: 149, curr_frame = 105
# idx: 150, curr_frame = 105
# idx: 151, curr_frame = 105
# idx: 152, curr_frame = 105
# idx: 153, curr_frame = 105
# idx: 154, curr_frame = 106
# idx: 155, curr_frame = 106
# idx: 156, curr_frame = 106
# idx: 157, curr_frame = 106
# idx: 158, curr_frame = 106
# idx: 159, curr_frame = 107
# idx: 160, curr_frame = 107
# idx: 161, curr_frame = 107
# idx: 162, curr_frame = 107
# idx: 163, curr_frame = 107
# idx: 164, curr_frame = 108
# idx: 165, curr_frame = 108
# idx: 166, curr_frame = 108
# idx: 167, curr_frame = 108
# idx: 168, curr_frame = 108
# idx: 169, curr_frame = 109
# idx: 170, curr_frame = 109
# idx: 171, curr_frame = 109
# idx: 172, curr_frame = 109
# idx: 173, curr_frame = 109
# idx: 174, curr_frame = 110
# idx: 175, curr_frame = 110
# idx: 176, curr_frame = 110
# idx: 177, curr_frame = 110
# idx: 178, curr_frame = 110
# idx: 179, curr_frame = 111
# idx: 180, curr_frame = 111
# idx: 181, curr_frame = 111
# idx: 182, curr_frame = 111
# idx: 183, curr_frame = 111
# idx: 184, curr_frame = 112
# idx: 185, curr_frame = 112
# idx: 186, curr_frame = 112
# idx: 187, curr_frame = 112
# idx: 188, curr_frame = 112
# idx: 189, curr_frame = 113
# idx: 190, curr_frame = 113
# idx: 191, curr_frame = 113
# idx: 192, curr_frame = 113
# idx: 193, curr_frame = 113
# idx: 194, curr_frame = 114
# idx: 195, curr_frame = 114
# idx: 196, curr_frame = 114
# idx: 197, curr_frame = 114
# idx: 198, curr_frame = 114
# idx: 199, curr_frame = 115
# idx: 200, curr_frame = 115
# idx: 201, curr_frame = 115
# idx: 202, curr_frame = 115
# idx: 203, curr_frame = 115
# idx: 204, curr_frame = 116
# idx: 205, curr_frame = 116
# idx: 206, curr_frame = 116
# idx: 207, curr_frame = 116
# idx: 208, curr_frame = 116
# idx: 209, curr_frame = 117
# idx: 210, curr_frame = 117
# idx: 211, curr_frame = 117
# idx: 212, curr_frame = 117
# idx: 213, curr_frame = 117
# idx: 214, curr_frame = 118
# idx: 215, curr_frame = 118
# idx: 216, curr_frame = 118
# idx: 217, curr_frame = 118
# idx: 218, curr_frame = 118
# idx: 219, curr_frame = 119
# idx: 220, curr_frame = 119
# idx: 221, curr_frame = 119
# idx: 222, curr_frame = 119
# idx: 223, curr_frame = 119
# idx: 224, curr_frame = 120
# idx: 225, curr_frame = 120
# idx: 226, curr_frame = 120
# idx: 227, curr_frame = 120
# idx: 228, curr_frame = 120
# idx: 229, curr_frame = 121
# idx: 230, curr_frame = 121
# idx: 231, curr_frame = 121
# idx: 232, curr_frame = 121
# idx: 233, curr_frame = 122
# idx: 234, curr_frame = 122
# idx: 235, curr_frame = 122
# idx: 236, curr_frame = 123
# idx: 237, curr_frame = 123
# idx: 238, curr_frame = 123
# idx: 239, curr_frame = 124
# idx: 240, curr_frame = 124
# idx: 241, curr_frame = 125
# idx: 242, curr_frame = 125
# idx: 243, curr_frame = 126
# idx: 244, curr_frame = 127
# idx: 245, curr_frame = 128
# idx: 246, curr_frame = 129
# idx: 247, curr_frame = 130
# #####################################
# Found: v5-0
# [[  0.   2.   0. ...  30.  -1.  -1.]
#  [  1.   2.   0. ...  32.  -1.  -1.]
#  [  0.   2.   1. ...  30.   0.   1.]
#  ...
#  [  0.   2. 147. ...  32.   0.   1.]
#  [  0.   2. 148. ...  32.   0.   1.]
#  [  0.   2. 149. ...  32.   0.   1.]]
# #####################################
# Frames: 150
# (150, 2)
# 346
# idx: 0, curr_frame = 0
# idx: 1, curr_frame = 0
# idx: 2, curr_frame = 1
# idx: 3, curr_frame = 2
# idx: 4, curr_frame = 3
# idx: 5, curr_frame = 4
# idx: 6, curr_frame = 5
# idx: 7, curr_frame = 6
# idx: 8, curr_frame = 7
# idx: 9, curr_frame = 8
# idx: 10, curr_frame = 9
# idx: 11, curr_frame = 10
# idx: 12, curr_frame = 11
# idx: 13, curr_frame = 12
# idx: 14, curr_frame = 13
# idx: 15, curr_frame = 14
# idx: 16, curr_frame = 15
# idx: 17, curr_frame = 16
# idx: 18, curr_frame = 17
# idx: 19, curr_frame = 18
# idx: 20, curr_frame = 19
# idx: 21, curr_frame = 20
# idx: 22, curr_frame = 21
# idx: 23, curr_frame = 22
# idx: 24, curr_frame = 23
# idx: 25, curr_frame = 24
# idx: 26, curr_frame = 25
# idx: 27, curr_frame = 26
# idx: 28, curr_frame = 27
# idx: 29, curr_frame = 28
# idx: 30, curr_frame = 29
# idx: 31, curr_frame = 30
# idx: 32, curr_frame = 31
# idx: 33, curr_frame = 32
# idx: 34, curr_frame = 33
# idx: 35, curr_frame = 34
# idx: 36, curr_frame = 35
# idx: 37, curr_frame = 36
# idx: 38, curr_frame = 37
# idx: 39, curr_frame = 38
# idx: 40, curr_frame = 39
# idx: 41, curr_frame = 40
# idx: 42, curr_frame = 41
# idx: 43, curr_frame = 42
# idx: 44, curr_frame = 43
# idx: 45, curr_frame = 44
# idx: 46, curr_frame = 45
# idx: 47, curr_frame = 46
# idx: 48, curr_frame = 47
# idx: 49, curr_frame = 48
# idx: 50, curr_frame = 49
# idx: 51, curr_frame = 50
# idx: 52, curr_frame = 50
# idx: 53, curr_frame = 51
# idx: 54, curr_frame = 51
# idx: 55, curr_frame = 51
# idx: 56, curr_frame = 52
# idx: 57, curr_frame = 52
# idx: 58, curr_frame = 53
# idx: 59, curr_frame = 53
# idx: 60, curr_frame = 54
# idx: 61, curr_frame = 54
# idx: 62, curr_frame = 54
# idx: 63, curr_frame = 55
# idx: 64, curr_frame = 55
# idx: 65, curr_frame = 55
# idx: 66, curr_frame = 56
# idx: 67, curr_frame = 56
# idx: 68, curr_frame = 56
# idx: 69, curr_frame = 57
# idx: 70, curr_frame = 57
# idx: 71, curr_frame = 57
# idx: 72, curr_frame = 57
# idx: 73, curr_frame = 58
# idx: 74, curr_frame = 58
# idx: 75, curr_frame = 58
# idx: 76, curr_frame = 59
# idx: 77, curr_frame = 59
# idx: 78, curr_frame = 59
# idx: 79, curr_frame = 60
# idx: 80, curr_frame = 60
# idx: 81, curr_frame = 60
# idx: 82, curr_frame = 61
# idx: 83, curr_frame = 61
# idx: 84, curr_frame = 61
# idx: 85, curr_frame = 62
# idx: 86, curr_frame = 62
# idx: 87, curr_frame = 62
# idx: 88, curr_frame = 63
# idx: 89, curr_frame = 63
# idx: 90, curr_frame = 63
# idx: 91, curr_frame = 64
# idx: 92, curr_frame = 64
# idx: 93, curr_frame = 64
# idx: 94, curr_frame = 64
# idx: 95, curr_frame = 65
# idx: 96, curr_frame = 65
# idx: 97, curr_frame = 65
# idx: 98, curr_frame = 65
# idx: 99, curr_frame = 66
# idx: 100, curr_frame = 66
# idx: 101, curr_frame = 66
# idx: 102, curr_frame = 66
# idx: 103, curr_frame = 67
# idx: 104, curr_frame = 67
# idx: 105, curr_frame = 67
# idx: 106, curr_frame = 67
# idx: 107, curr_frame = 68
# idx: 108, curr_frame = 68
# idx: 109, curr_frame = 68
# idx: 110, curr_frame = 68
# idx: 111, curr_frame = 69
# idx: 112, curr_frame = 69
# idx: 113, curr_frame = 69
# idx: 114, curr_frame = 69
# idx: 115, curr_frame = 70
# idx: 116, curr_frame = 70
# idx: 117, curr_frame = 70
# idx: 118, curr_frame = 70
# idx: 119, curr_frame = 70
# idx: 120, curr_frame = 71
# idx: 121, curr_frame = 71
# idx: 122, curr_frame = 71
# idx: 123, curr_frame = 71
# idx: 124, curr_frame = 71
# idx: 125, curr_frame = 72
# idx: 126, curr_frame = 72
# idx: 127, curr_frame = 72
# idx: 128, curr_frame = 72
# idx: 129, curr_frame = 72
# idx: 130, curr_frame = 73
# idx: 131, curr_frame = 73
# idx: 132, curr_frame = 73
# idx: 133, curr_frame = 73
# idx: 134, curr_frame = 73
# idx: 135, curr_frame = 74
# idx: 136, curr_frame = 74
# idx: 137, curr_frame = 74
# idx: 138, curr_frame = 74
# idx: 139, curr_frame = 74
# idx: 140, curr_frame = 75
# idx: 141, curr_frame = 75
# idx: 142, curr_frame = 75
# idx: 143, curr_frame = 75
# idx: 144, curr_frame = 75
# idx: 145, curr_frame = 76
# idx: 146, curr_frame = 76
# idx: 147, curr_frame = 76
# idx: 148, curr_frame = 76
# idx: 149, curr_frame = 76
# idx: 150, curr_frame = 77
# idx: 151, curr_frame = 77
# idx: 152, curr_frame = 77
# idx: 153, curr_frame = 77
# idx: 154, curr_frame = 78
# idx: 155, curr_frame = 78
# idx: 156, curr_frame = 78
# idx: 157, curr_frame = 78
# idx: 158, curr_frame = 78
# idx: 159, curr_frame = 79
# idx: 160, curr_frame = 79
# idx: 161, curr_frame = 79
# idx: 162, curr_frame = 79
# idx: 163, curr_frame = 79
# idx: 164, curr_frame = 80
# idx: 165, curr_frame = 80
# idx: 166, curr_frame = 80
# idx: 167, curr_frame = 80
# idx: 168, curr_frame = 80
# idx: 169, curr_frame = 81
# idx: 170, curr_frame = 81
# idx: 171, curr_frame = 81
# idx: 172, curr_frame = 81
# idx: 173, curr_frame = 81
# idx: 174, curr_frame = 82
# idx: 175, curr_frame = 82
# idx: 176, curr_frame = 82
# idx: 177, curr_frame = 82
# idx: 178, curr_frame = 83
# idx: 179, curr_frame = 83
# idx: 180, curr_frame = 83
# idx: 181, curr_frame = 83
# idx: 182, curr_frame = 84
# idx: 183, curr_frame = 84
# idx: 184, curr_frame = 84
# idx: 185, curr_frame = 84
# idx: 186, curr_frame = 85
# idx: 187, curr_frame = 85
# idx: 188, curr_frame = 85
# idx: 189, curr_frame = 85
# idx: 190, curr_frame = 86
# idx: 191, curr_frame = 86
# idx: 192, curr_frame = 86
# idx: 193, curr_frame = 86
# idx: 194, curr_frame = 86
# idx: 195, curr_frame = 87
# idx: 196, curr_frame = 87
# idx: 197, curr_frame = 87
# idx: 198, curr_frame = 87
# idx: 199, curr_frame = 87
# idx: 200, curr_frame = 88
# idx: 201, curr_frame = 88
# idx: 202, curr_frame = 88
# idx: 203, curr_frame = 88
# idx: 204, curr_frame = 89
# idx: 205, curr_frame = 89
# idx: 206, curr_frame = 89
# idx: 207, curr_frame = 89
# idx: 208, curr_frame = 90
# idx: 209, curr_frame = 90
# idx: 210, curr_frame = 90
# idx: 211, curr_frame = 90
# idx: 212, curr_frame = 90
# idx: 213, curr_frame = 91
# idx: 214, curr_frame = 91
# idx: 215, curr_frame = 91
# idx: 216, curr_frame = 91
# idx: 217, curr_frame = 91
# idx: 218, curr_frame = 92
# idx: 219, curr_frame = 92
# idx: 220, curr_frame = 92
# idx: 221, curr_frame = 92
# idx: 222, curr_frame = 92
# idx: 223, curr_frame = 93
# idx: 224, curr_frame = 93
# idx: 225, curr_frame = 93
# idx: 226, curr_frame = 93
# idx: 227, curr_frame = 93
# idx: 228, curr_frame = 94
# idx: 229, curr_frame = 94
# idx: 230, curr_frame = 94
# idx: 231, curr_frame = 94
# idx: 232, curr_frame = 95
# idx: 233, curr_frame = 95
# idx: 234, curr_frame = 95
# idx: 235, curr_frame = 95
# idx: 236, curr_frame = 95
# idx: 237, curr_frame = 96
# idx: 238, curr_frame = 96
# idx: 239, curr_frame = 96
# idx: 240, curr_frame = 96
# idx: 241, curr_frame = 96
# idx: 242, curr_frame = 97
# idx: 243, curr_frame = 97
# idx: 244, curr_frame = 97
# idx: 245, curr_frame = 97
# idx: 246, curr_frame = 97
# idx: 247, curr_frame = 98
# idx: 248, curr_frame = 98
# idx: 249, curr_frame = 98
# idx: 250, curr_frame = 98
# idx: 251, curr_frame = 98
# idx: 252, curr_frame = 99
# idx: 253, curr_frame = 99
# idx: 254, curr_frame = 99
# idx: 255, curr_frame = 99
# idx: 256, curr_frame = 99
# idx: 257, curr_frame = 100
# idx: 258, curr_frame = 100
# idx: 259, curr_frame = 100
# idx: 260, curr_frame = 100
# idx: 261, curr_frame = 100
# idx: 262, curr_frame = 101
# idx: 263, curr_frame = 101
# idx: 264, curr_frame = 101
# idx: 265, curr_frame = 101
# idx: 266, curr_frame = 101
# idx: 267, curr_frame = 102
# idx: 268, curr_frame = 102
# idx: 269, curr_frame = 102
# idx: 270, curr_frame = 102
# idx: 271, curr_frame = 102
# idx: 272, curr_frame = 103
# idx: 273, curr_frame = 103
# idx: 274, curr_frame = 103
# idx: 275, curr_frame = 103
# idx: 276, curr_frame = 103
# idx: 277, curr_frame = 104
# idx: 278, curr_frame = 104
# idx: 279, curr_frame = 104
# idx: 280, curr_frame = 104
# idx: 281, curr_frame = 105
# idx: 282, curr_frame = 105
# idx: 283, curr_frame = 105
# idx: 284, curr_frame = 105
# idx: 285, curr_frame = 106
# idx: 286, curr_frame = 106
# idx: 287, curr_frame = 106
# idx: 288, curr_frame = 106
# idx: 289, curr_frame = 107
# idx: 290, curr_frame = 107
# idx: 291, curr_frame = 107
# idx: 292, curr_frame = 107
# idx: 293, curr_frame = 108
# idx: 294, curr_frame = 108
# idx: 295, curr_frame = 108
# idx: 296, curr_frame = 108
# idx: 297, curr_frame = 109
# idx: 298, curr_frame = 109
# idx: 299, curr_frame = 109
# idx: 300, curr_frame = 109
# idx: 301, curr_frame = 110
# idx: 302, curr_frame = 110
# idx: 303, curr_frame = 111
# idx: 304, curr_frame = 111
# idx: 305, curr_frame = 112
# idx: 306, curr_frame = 112
# idx: 307, curr_frame = 113
# idx: 308, curr_frame = 113
# idx: 309, curr_frame = 114
# idx: 310, curr_frame = 114
# idx: 311, curr_frame = 115
# idx: 312, curr_frame = 116
# idx: 313, curr_frame = 117
# idx: 314, curr_frame = 118
# idx: 315, curr_frame = 119
# idx: 316, curr_frame = 120
# idx: 317, curr_frame = 121
# idx: 318, curr_frame = 122
# idx: 319, curr_frame = 123
# idx: 320, curr_frame = 124
# idx: 321, curr_frame = 125
# idx: 322, curr_frame = 126
# idx: 323, curr_frame = 127
# idx: 324, curr_frame = 128
# idx: 325, curr_frame = 129
# idx: 326, curr_frame = 130
# idx: 327, curr_frame = 131
# idx: 328, curr_frame = 132
# idx: 329, curr_frame = 133
# idx: 330, curr_frame = 134
# idx: 331, curr_frame = 135
# idx: 332, curr_frame = 136
# idx: 333, curr_frame = 137
# idx: 334, curr_frame = 138
# idx: 335, curr_frame = 139
# idx: 336, curr_frame = 140
# idx: 337, curr_frame = 141
# idx: 338, curr_frame = 142
# idx: 339, curr_frame = 143
# idx: 340, curr_frame = 144
# idx: 341, curr_frame = 145
# idx: 342, curr_frame = 146
# idx: 343, curr_frame = 147
# idx: 344, curr_frame = 148
# idx: 345, curr_frame = 149
# Search Complete
# Frames in video 0: 150
# Frames in video 1: 150
# Frames in video 2: 118
# Frames in video 3: 150
# Frames in video 4: 63
# Frames in video 5: 116
# Frames in video 6: 66
# Frames in video 7: 149
# x_img shape: (962, 720, 1280, 3), x_diff shape: (962, 16, 2), y_values shape: (962, 16, 2)

# %%
# need to normalise y values
# need to build a model that includes distance and frame diff
# model predicting x and y values

# going to build model that predicts coords from image

# %%
def normalise_img(x_values):
    return x_values / 255

# %%
def cnn_prepare(x_value, y_value):
    #x_val = np.reshape(x_value,(x_value.shape[0] * x_value.shape[1], 
    #                            x_value.shape[2], 
    #                            x_value.shape[3], 
    #                            x_value.shape[4]))
    x_val = normalise_img(x_value)
    y_val = np.reshape(y_value,(y_value.shape[0],
                                y_value.shape[1] * y_value.shape[2]))
    return x_val, y_val

# %%
def random_np(x_np, y_np):
    prng = RandomState(0)
    randomise = prng.permutation(x_np.shape[0])
    x_np = x_np[randomise]
    y_np = y_np[randomise]
    return x_np, y_np

# %%
def split_np(x_data, y_data, percent):
    """ splits a numpy array into testing and training """
    position = int(len(x_data) * (1-percent))
    x_train, x_test = x_data[:position], x_data[position:]
    y_train, y_test = y_data[:position], y_data[position:]
    print('x_train shape: {}, x_test shape: {}'.format(x_train.shape,x_test.shape))
    print('y_train shape: {}, y_test shape: {}'.format(y_train.shape,y_test.shape))
    return x_train, y_train, x_test, y_test

# %%
x_img, y = random_np(x_img, y)

x_cnn, y_cnn = cnn_prepare(x_img, y)
#x_cnn, y_cnn = x_img, y
x_train, y_train, x_test, y_test = split_np(x_cnn, y_cnn, 0.2)

## remove useless variables
x_img, x_diff, y, x_cnn, y_cnn = None, None, None, None, None

# %%
## prepare data to pickle
import pickle

data = [x_train, y_train, x_test, y_test]
pickle.dump(data, open("./aws/data_rand.p","wb"))
print("Finished")

# %%
input_shape = x_train.shape[1:]
output_shape = y_train.shape[1]

model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3),
                activation='relu',
                input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, (3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3, 3),activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(output_shape))
model.compile(loss='mean_squared_error', 
              optimizer='adam',
              metrics=['accuracy'])

# %%
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
checkpointer = ModelCheckpoint(filepath="dnn/tmp_best_weights.hdf5", verbose=0, save_best_only=True) # save best model

batch_size = 4
epochs = 1000
import time
start_time = time.time()

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=[monitor,checkpointer])
model.load_weights('dnn/tmp_best_weights.hdf5') # load weights from best model


save_dir = join(os.getcwd(),"dnn")
save_path = join(save_dir,str(int(start_time)) + "_cnn.h5")
model.save(save_path)

score = model.evaluate(x_test, y_test, verbose=2)
print('Test loss: {}'.format(score[0]))
print('Test accuracy: {}'.format(score[1]))

elapsed_time = time.time() - start_time
print("Elapsed time: {}".format(hms_string(elapsed_time)))
