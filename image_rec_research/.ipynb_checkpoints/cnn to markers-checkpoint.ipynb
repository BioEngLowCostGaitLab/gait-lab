# %%
import os
from os.path import join
import sys
import cv2 as cv
import numpy as np
from numpy.random import RandomState
import pickle
import matplotlib.pyplot as plt

import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# c:\users\joear\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
def load_labels(specific_video=None):
    """ Loads in image data as numpy arrays """
    sequence = []
    none_count = 0 
    filedir = join(os.getcwd(),"labels")
    for file in os.listdir(filedir):
        ## change current seq when video_id change or marker number changes
        if file.endswith(".jpg"):
            file = file.split(".")[0]
            file = file.split("_")
            if specific_video == None:
                video_id, marker_num, marker_type, frame_num, x_pos, y_pos = file[0], int(file[1]), int(file[2]), int(file[3]), int(file[4]), int(file[5])
                current_seq = [video_id, marker_num, marker_type, frame_num, x_pos, y_pos]
                sequence.append(current_seq)
            else:
                if file[0] == video_id:
                    video_id, marker_num, marker_type, frame_num, x_pos, y_pos = file[0], int(file[1]), int(file[2]), int(file[3]), int(file[4]), int(file[5])
                    current_seq = [video_id, marker_num, marker_type, frame_num, x_pos, y_pos]
                    sequence.append(current_seq)
    return sequence

# %%
def sort_labels(sequence):
    sequence.sort(key=lambda x: x[3]) ## Sort by frame number
    sequence.sort(key=lambda x: x[1]) ## Sort by marker_num
    sequence.sort(key=lambda x: x[0]) ## Sort by video_name
    return sequence

# %%
def assign_labels(sequence):
    ##  ball change or vid change
    prev_vid_id, prev_marker_num = sequence[0][0][0], sequence[0][0][1]
    for idx, seq in enumerate(sequence):
        vid_id, marker_num = seq[0], seq[1]
        if (vid_id != prev_vid_id) or (marker_num != prev_marker_num):
            prev_vid_id, prev_marker_num = vid_id, marker_num
            prev_coords, prev_frame_num = np.array([-1,-1]), -1
        frame_num, x_pos, y_pos = seq[3], seq[4], seq[5]
        current_coords = np.array([x_pos, y_pos])
        if (prev_coords[0] == -1) & (prev_coords[1] == -1):
            dist = -1
        else:
            dist = np.linalg.norm(current_coords - prev_coords)
        if (prev_frame_num == -1):
            frame_diff = -1
        else:
            frame_diff = frame_num - prev_frame_num
        prev_coords = current_coords
        prev_frame_num = frame_num
        sequence[idx].append(dist)
        sequence[idx].append(frame_diff)
    return sequence

# %%
def load_video(video_path, video_name, flip, display = False): ## Convert 3rd element in video name into flip
    width, height = 960, 540
    cap = cv.VideoCapture(join(video_path,video_name))
    ret, frame = cap.read()
    if (flip):
        frame = cv.flip(frame, 0)
    clone = cv.resize(frame, (width,height))
    if (display):
        cv.namedWindow("Video")
    frame_num = 0
    frames = []
    while (ret):
        if (display):
            cv.imshow("Video", clone)
        frames.append( [frame, frame_num] )
        if (display):
            key = cv.waitKey(0)
            if key == 113:
                break
        ret, frame = cap.read()
        if (ret):
            frame_num += 1
            if (flip):
                frame = cv.flip(frame, 0)
            clone = cv.resize(frame, (width, height))
    print("Frames: {}".format(frames[-1][1] + 1))
    cap.release()
    if (display):
        cv.destroyAllWindows()
    return frames

# %%
def load_data_and_labels(sequence, vid_format=".avi"):
    print("Loading videos")
    filedir = join(os.getcwd(),"resources")
    video_recorded = []
    for file in os.listdir(filedir):
        video_id = file.split(".")[0]
        video_recorded.append(video_id)
    video_annotated = list(sorted(set([i[0] for i in sequence])))
    video_data = []
    """ Checking the videos annotated is in the video recorded """
    for rec in video_recorded:
        if rec in video_annotated:
            data = []
            print("Found: {}".format(rec))
            labels = [i for i in sequence if i[0] == rec]
            labels.sort(key=lambda x: x[3]) ## Sort by frame number
            labels = np.asarray(labels)[:,1:].astype('float32')
            frames = load_video(filedir, rec + vid_format, False)
            frames = np.asarray(frames)
            print(frames.shape)
            prev_frame = 0
            frame_labels = []
            print(len(labels))
            for idx, label in enumerate(labels):
                print("idx: {}, label: {}, curr_frame = {}".format(idx, label, int(label[2])))
                curr_frame = int(label[2])
                if (curr_frame != prev_frame):
                    data.append([frames[prev_frame][0], frame_labels])                    
                    frame_labels = [label]
                elif idx == len(labels) - 1:
                    frame_labels.append(label)
                    data.append([frames[curr_frame][0],frame_labels])
                else:
                    frame_labels.append(label)
                prev_frame = int(curr_frame)
            video_data.append(data)
    print("Search Complete")
    return video_data

# %%
def data_to_np(data):
    data_np = np.asarray(data)
    x_values = []
    y_values = []
    
    for i in range(len(data_np)):
        print("Frames in video {}: {}".format(i,len(data_np[i])))            
    
    for vid_pos in range(len(data_np)):
        ##print("vid: {}".format(vid_pos))
        for frame_pos in range(len(data_np[vid_pos])):
            ##print("frame num: {}".format(frame_pos))
            x_np = data_np[vid_pos][frame_pos][0]
            x_shape = list(x_np[0].shape)
            x_shape[:0] = [len(x_np)]
            x_np = np.concatenate(x_np).reshape(x_shape)
            x_values.append(x_np)

            y_np = data_np[vid_pos][frame_pos][1]
            y_np = np.asarray(y_np)
            zero_np = np.zeros((16,7))
            if y_np.shape != (0,):
                zero_np[:y_np.shape[0],:y_np.shape[1]] = y_np
            y_values.append(zero_np)
        
    x_img = np.asarray(x_values)
    y_values = np.asarray(y_values)
    x_diff = y_values[:, :, 5:]
    y_cords = y_values[:, :, 3:5]
    print("x_img shape: {}, x_diff shape: {}, y_values shape: {}".format(x_img.shape, x_diff.shape, y_cords.shape))
    return x_img, x_diff, y_cords

# %%
def load_data():
    seq = load_labels()
    seq = sort_labels(seq)
    seq = assign_labels(seq)
    data = load_data_and_labels(seq)
    x_img, x_diff, y = data_to_np(data)
    return x_img, x_diff, y

# %%
x_img, x_diff, y = load_data()
# Out:
# Loading videos
# Found: v0-0
# Frames: 150
# (150, 2)
# 450
# idx: 0, label: [  0.   1.   0. 645. 531.  -1.  -1.], curr_frame = 0
# idx: 1, label: [  1.   2.   0. 735. 719.  -1.  -1.], curr_frame = 0
# idx: 2, label: [  2.   1.   0. 778. 883.  -1.  -1.], curr_frame = 0
# idx: 3, label: [  0.   1.   1. 645. 531.   0.   1.], curr_frame = 1
# idx: 4, label: [  1.   2.   1. 735. 720.   1.   1.], curr_frame = 1
# idx: 5, label: [  2.   1.   1. 776. 883.   2.   1.], curr_frame = 1
# idx: 6, label: [  0.          1.          2.        646.        532.          1.4142135
#    1.       ], curr_frame = 2
# idx: 7, label: [  1.   2.   2. 735. 720.   0.   1.], curr_frame = 2
# idx: 8, label: [  2.   1.   2. 779. 883.   3.   1.], curr_frame = 2
# idx: 9, label: [  0.   1.   3. 646. 532.   0.   1.], curr_frame = 3
# idx: 10, label: [  1.   2.   3. 735. 720.   0.   1.], curr_frame = 3
# idx: 11, label: [  2.   1.   3. 779. 882.   1.   1.], curr_frame = 3
# idx: 12, label: [  0.   1.   4. 646. 532.   0.   1.], curr_frame = 4
# idx: 13, label: [  1.   2.   4. 735. 719.   1.   1.], curr_frame = 4
# idx: 14, label: [  2.   1.   4. 777. 882.   2.   1.], curr_frame = 4
# idx: 15, label: [  0.   1.   5. 646. 532.   0.   1.], curr_frame = 5
# idx: 16, label: [  1.   2.   5. 735. 720.   1.   1.], curr_frame = 5
# idx: 17, label: [  2.   1.   5. 777. 882.   0.   1.], curr_frame = 5
# idx: 18, label: [  0.   1.   6. 646. 532.   0.   1.], curr_frame = 6
# idx: 19, label: [  1.   2.   6. 735. 720.   0.   1.], curr_frame = 6
# idx: 20, label: [  2.   1.   6. 777. 882.   0.   1.], curr_frame = 6
# idx: 21, label: [  0.   1.   7. 646. 532.   0.   1.], curr_frame = 7
# idx: 22, label: [  1.   2.   7. 735. 720.   0.   1.], curr_frame = 7
# idx: 23, label: [  2.   1.   7. 778. 882.   1.   1.], curr_frame = 7
# idx: 24, label: [  0.   1.   8. 646. 532.   0.   1.], curr_frame = 8
# idx: 25, label: [  1.   2.   8. 735. 720.   0.   1.], curr_frame = 8
# idx: 26, label: [  2.   1.   8. 778. 882.   0.   1.], curr_frame = 8
# idx: 27, label: [  0.   1.   9. 646. 531.   1.   1.], curr_frame = 9
# idx: 28, label: [  1.   2.   9. 735. 720.   0.   1.], curr_frame = 9
# idx: 29, label: [  2.   1.   9. 778. 882.   0.   1.], curr_frame = 9
# idx: 30, label: [  0.   1.  10. 646. 531.   0.   1.], curr_frame = 10
# idx: 31, label: [  1.   2.  10. 735. 720.   0.   1.], curr_frame = 10
# idx: 32, label: [  2.   1.  10. 778. 882.   0.   1.], curr_frame = 10
# idx: 33, label: [  0.   1.  11. 646. 531.   0.   1.], curr_frame = 11
# idx: 34, label: [  1.   2.  11. 735. 720.   0.   1.], curr_frame = 11
# idx: 35, label: [  2.   1.  11. 778. 882.   0.   1.], curr_frame = 11
# idx: 36, label: [  0.   1.  12. 646. 531.   0.   1.], curr_frame = 12
# idx: 37, label: [  1.   2.  12. 735. 720.   0.   1.], curr_frame = 12
# idx: 38, label: [  2.   1.  12. 778. 882.   0.   1.], curr_frame = 12
# idx: 39, label: [  0.   1.  13. 646. 531.   0.   1.], curr_frame = 13
# idx: 40, label: [  1.   2.  13. 735. 720.   0.   1.], curr_frame = 13
# idx: 41, label: [  2.   1.  13. 780. 882.   2.   1.], curr_frame = 13
# idx: 42, label: [  0.   1.  14. 646. 531.   0.   1.], curr_frame = 14
# idx: 43, label: [  1.   2.  14. 735. 720.   0.   1.], curr_frame = 14
# idx: 44, label: [  2.   1.  14. 776. 882.   4.   1.], curr_frame = 14
# idx: 45, label: [  0.   1.  15. 646. 531.   0.   1.], curr_frame = 15
# idx: 46, label: [  1.   2.  15. 735. 720.   0.   1.], curr_frame = 15
# idx: 47, label: [  2.   1.  15. 777. 882.   1.   1.], curr_frame = 15
# idx: 48, label: [  0.   1.  16. 646. 531.   0.   1.], curr_frame = 16
# idx: 49, label: [  1.   2.  16. 737. 720.   2.   1.], curr_frame = 16
# idx: 50, label: [  2.   1.  16. 779. 882.   2.   1.], curr_frame = 16
# idx: 51, label: [  0.          1.         17.        645.        532.          1.4142135
#    1.       ], curr_frame = 17
# idx: 52, label: [  1.   2.  17. 734. 720.   3.   1.], curr_frame = 17
# idx: 53, label: [  2.   1.  17. 779. 883.   1.   1.], curr_frame = 17
# idx: 54, label: [  0.         1.        18.       647.       531.         2.236068
#    1.      ], curr_frame = 18
# idx: 55, label: [  1.          2.         18.        733.        719.          1.4142135
#    1.       ], curr_frame = 18
# idx: 56, label: [  2.   1.  18. 779. 883.   0.   1.], curr_frame = 18
# idx: 57, label: [  0.         1.        19.       645.       532.         2.236068
#    1.      ], curr_frame = 19
# idx: 58, label: [  1.   2.  19. 735. 719.   2.   1.], curr_frame = 19
# idx: 59, label: [  2.   1.  19. 778. 883.   1.   1.], curr_frame = 19
# idx: 60, label: [  0.   1.  20. 645. 532.   0.   1.], curr_frame = 20
# idx: 61, label: [  1.   2.  20. 737. 719.   2.   1.], curr_frame = 20
# idx: 62, label: [  2.   1.  20. 778. 883.   0.   1.], curr_frame = 20
# idx: 63, label: [  0.   1.  21. 647. 532.   2.   1.], curr_frame = 21
# idx: 64, label: [  1.   2.  21. 737. 719.   0.   1.], curr_frame = 21
# idx: 65, label: [  2.   1.  21. 778. 883.   0.   1.], curr_frame = 21
# idx: 66, label: [  0.   1.  22. 647. 532.   0.   1.], curr_frame = 22
# idx: 67, label: [  1.   2.  22. 736. 719.   1.   1.], curr_frame = 22
# idx: 68, label: [  2.   1.  22. 778. 883.   0.   1.], curr_frame = 22
# idx: 69, label: [  0.         1.        23.       645.       530.         2.828427
#    1.      ], curr_frame = 23
# idx: 70, label: [  1.   2.  23. 736. 719.   0.   1.], curr_frame = 23
# idx: 71, label: [  2.   1.  23. 778. 883.   0.   1.], curr_frame = 23
# idx: 72, label: [  0.   1.  24. 647. 530.   2.   1.], curr_frame = 24
# idx: 73, label: [  1.   2.  24. 736. 719.   0.   1.], curr_frame = 24
# idx: 74, label: [  2.          1.         24.        779.        882.          1.4142135
#    1.       ], curr_frame = 24
# idx: 75, label: [  0.   1.  25. 647. 532.   2.   1.], curr_frame = 25
# idx: 76, label: [  1.   2.  25. 736. 719.   0.   1.], curr_frame = 25
# idx: 77, label: [  2.   1.  25. 779. 882.   0.   1.], curr_frame = 25
# idx: 78, label: [  0.   1.  26. 647. 532.   0.   1.], curr_frame = 26
# idx: 79, label: [  1.   2.  26. 736. 719.   0.   1.], curr_frame = 26
# idx: 80, label: [  2.   1.  26. 779. 881.   1.   1.], curr_frame = 26
# idx: 81, label: [  0.   1.  27. 647. 532.   0.   1.], curr_frame = 27
# idx: 82, label: [  1.   2.  27. 739. 719.   3.   1.], curr_frame = 27
# idx: 83, label: [  2.   1.  27. 781. 881.   2.   1.], curr_frame = 27
# idx: 84, label: [  0.   1.  28. 647. 532.   0.   1.], curr_frame = 28
# idx: 85, label: [  1.         2.        28.       743.       717.         4.472136
#    1.      ], curr_frame = 28
# idx: 86, label: [  2.   1.  28. 784. 881.   3.   1.], curr_frame = 28
# idx: 87, label: [  0.   1.  29. 647. 532.   0.   1.], curr_frame = 29
# idx: 88, label: [  1.          2.         29.        748.        714.          5.8309517
#    1.       ], curr_frame = 29
# idx: 89, label: [  2.          1.         29.        785.        880.          1.4142135
#    1.       ], curr_frame = 29
# idx: 90, label: [  0.   1.  30. 647. 532.   0.   1.], curr_frame = 30
# idx: 91, label: [  1.   2.  30. 752. 711.   5.   1.], curr_frame = 30
# idx: 92, label: [  2.   1.  30. 788. 880.   3.   1.], curr_frame = 30
# idx: 93, label: [  0.          1.         31.        652.        528.          6.4031243
#    1.       ], curr_frame = 31
# idx: 94, label: [  1.         2.        31.       760.       707.         8.944272
#    1.      ], curr_frame = 31
# idx: 95, label: [  2.         1.        31.       792.       878.         4.472136
#    1.      ], curr_frame = 31
# idx: 96, label: [  0.   1.  32. 656. 528.   4.   1.], curr_frame = 32
# idx: 97, label: [  1.        2.       32.      767.      705.        7.28011   1.     ], curr_frame = 32
# idx: 98, label: [  2.   1.  32. 794. 878.   2.   1.], curr_frame = 32
# idx: 99, label: [  0.   1.  33. 659. 528.   3.   1.], curr_frame = 33
# idx: 100, label: [  1.        2.       33.      774.      703.        7.28011   1.     ], curr_frame = 33
# idx: 101, label: [  2.          1.         33.        800.        877.          6.0827627
#    1.       ], curr_frame = 33
# idx: 102, label: [  0.   1.  34. 662. 528.   3.   1.], curr_frame = 34
# idx: 103, label: [  1.         2.        34.       781.       699.         8.062258
#    1.      ], curr_frame = 34
# idx: 104, label: [  2.   1.  34. 803. 877.   3.   1.], curr_frame = 34
# idx: 105, label: [  0.          1.         35.        665.        530.          3.6055512
#    1.       ], curr_frame = 35
# idx: 106, label: [  1.         2.        35.       785.       701.         4.472136
#    1.      ], curr_frame = 35
# idx: 107, label: [  2.          1.         35.        807.        876.          4.1231055
#    1.       ], curr_frame = 35
# idx: 108, label: [  0.         1.        36.       667.       531.         2.236068
#    1.      ], curr_frame = 36
# idx: 109, label: [  1.          2.         36.        790.        698.          5.8309517
#    1.       ], curr_frame = 36
# idx: 110, label: [  2.   1.  36. 808. 876.   1.   1.], curr_frame = 36
# idx: 111, label: [  0.         1.        37.       668.       533.         2.236068
#    1.      ], curr_frame = 37
# idx: 112, label: [  1.   2.  37. 795. 698.   5.   1.], curr_frame = 37
# idx: 113, label: [  2.   1.  37. 811. 876.   3.   1.], curr_frame = 37
# idx: 114, label: [  0.   1.  38. 668. 535.   2.   1.], curr_frame = 38
# idx: 115, label: [  1.   2.  38. 800. 698.   5.   1.], curr_frame = 38
# idx: 116, label: [  2.          1.         38.        816.        877.          5.0990195
#    1.       ], curr_frame = 38
# idx: 117, label: [  0.         1.        39.       670.       539.         4.472136
#    1.      ], curr_frame = 39
# idx: 118, label: [  1.          2.         39.        805.        696.          5.3851647
#    1.       ], curr_frame = 39
# idx: 119, label: [  2.         1.        39.       818.       875.         2.828427
#    1.      ], curr_frame = 39
# idx: 120, label: [  0.   1.  40. 670. 542.   3.   1.], curr_frame = 40
# idx: 121, label: [  1.   2.  40. 813. 696.   8.   1.], curr_frame = 40
# idx: 122, label: [  2.   1.  40. 821. 875.   3.   1.], curr_frame = 40
# idx: 123, label: [  0.         1.        41.       672.       546.         4.472136
#    1.      ], curr_frame = 41
# idx: 124, label: [  1.          2.         41.        818.        695.          5.0990195
#    1.       ], curr_frame = 41
# idx: 125, label: [  2.   1.  41. 826. 875.   5.   1.], curr_frame = 41
# idx: 126, label: [  0.          1.         42.        673.        550.          4.1231055
#    1.       ], curr_frame = 42
# idx: 127, label: [  1.   2.  42. 823. 695.   5.   1.], curr_frame = 42
# idx: 128, label: [  2.   1.  42. 830. 875.   4.   1.], curr_frame = 42
# idx: 129, label: [  0.          1.         43.        672.        556.          6.0827627
#    1.       ], curr_frame = 43
# idx: 130, label: [  1.   2.  43. 826. 695.   3.   1.], curr_frame = 43
# idx: 131, label: [  2.   1.  43. 830. 875.   0.   1.], curr_frame = 43
# idx: 132, label: [  0.          1.         44.        673.        559.          3.1622777
#    1.       ], curr_frame = 44
# idx: 133, label: [  1.   2.  44. 831. 695.   5.   1.], curr_frame = 44
# idx: 134, label: [  2.          1.         44.        834.        876.          4.1231055
#    1.       ], curr_frame = 44
# idx: 135, label: [  0.          1.         45.        674.        563.          4.1231055
#    1.       ], curr_frame = 45
# idx: 136, label: [  1.          2.         45.        836.        697.          5.3851647
#    1.       ], curr_frame = 45
# idx: 137, label: [  2.   1.  45. 837. 876.   3.   1.], curr_frame = 45
# idx: 138, label: [  0.   1.  46. 674. 568.   5.   1.], curr_frame = 46
# idx: 139, label: [  1.   2.  46. 841. 697.   5.   1.], curr_frame = 46
# idx: 140, label: [  2.         1.        46.       841.       874.         4.472136
#    1.      ], curr_frame = 46
# idx: 141, label: [  0.          1.         47.        675.        572.          4.1231055
#    1.       ], curr_frame = 47
# idx: 142, label: [  1.   2.  47. 842. 697.   1.   1.], curr_frame = 47
# idx: 143, label: [  2.   1.  47. 842. 874.   1.   1.], curr_frame = 47
# idx: 144, label: [  0.   1.  48. 675. 576.   4.   1.], curr_frame = 48
# idx: 145, label: [  1.   2.  48. 845. 697.   3.   1.], curr_frame = 48
# idx: 146, label: [  2.   1.  48. 844. 874.   2.   1.], curr_frame = 48
# idx: 147, label: [  0.          1.         49.        676.        580.          4.1231055
#    1.       ], curr_frame = 49
# idx: 148, label: [  1.          2.         49.        850.        698.          5.0990195
#    1.       ], curr_frame = 49
# idx: 149, label: [  2.          1.         49.        848.        875.          4.1231055
#    1.       ], curr_frame = 49
# idx: 150, label: [  0.          1.         50.        678.        583.          3.6055512
#    1.       ], curr_frame = 50
# idx: 151, label: [  1.   2.  50. 852. 698.   2.   1.], curr_frame = 50
# idx: 152, label: [  2.         1.        50.       850.       874.         2.236068
#    1.      ], curr_frame = 50
# idx: 153, label: [  0.         1.        51.       680.       585.         2.828427
#    1.      ], curr_frame = 51
# idx: 154, label: [  1.          2.         51.        855.        696.          3.6055512
#    1.       ], curr_frame = 51
# idx: 155, label: [  2.         1.        51.       852.       872.         2.828427
#    1.      ], curr_frame = 51
# idx: 156, label: [  0.          1.         52.        681.        591.          6.0827627
#    1.       ], curr_frame = 52
# idx: 157, label: [  1.   2.  52. 860. 696.   5.   1.], curr_frame = 52
# idx: 158, label: [  2.   1.  52. 854. 872.   2.   1.], curr_frame = 52
# idx: 159, label: [  0.          1.         53.        684.        593.          3.6055512
#    1.       ], curr_frame = 53
# idx: 160, label: [  1.   2.  53. 862. 696.   2.   1.], curr_frame = 53
# idx: 161, label: [  2.   1.  53. 855. 872.   1.   1.], curr_frame = 53
# idx: 162, label: [  0.   1.  54. 684. 596.   3.   1.], curr_frame = 54
# idx: 163, label: [  1.   2.  54. 866. 696.   4.   1.], curr_frame = 54
# idx: 164, label: [  2.   1.  54. 856. 872.   1.   1.], curr_frame = 54
# idx: 165, label: [  0.   1.  55. 684. 599.   3.   1.], curr_frame = 55
# idx: 166, label: [  1.   2.  55. 867. 696.   1.   1.], curr_frame = 55
# idx: 167, label: [  2.         1.        55.       858.       870.         2.828427
#    1.      ], curr_frame = 55
# idx: 168, label: [  0.   1.  56. 684. 602.   3.   1.], curr_frame = 56
# idx: 169, label: [  1.   2.  56. 867. 696.   0.   1.], curr_frame = 56
# idx: 170, label: [  2.   1.  56. 858. 870.   0.   1.], curr_frame = 56
# idx: 171, label: [  0.   1.  57. 684. 604.   2.   1.], curr_frame = 57
# idx: 172, label: [  1.   2.  57. 867. 696.   0.   1.], curr_frame = 57
# idx: 173, label: [  2.   1.  57. 859. 870.   1.   1.], curr_frame = 57
# idx: 174, label: [  0.   1.  58. 684. 606.   2.   1.], curr_frame = 58
# idx: 175, label: [  1.   2.  58. 869. 696.   2.   1.], curr_frame = 58
# idx: 176, label: [  2.   1.  58. 860. 870.   1.   1.], curr_frame = 58
# idx: 177, label: [  0.   1.  59. 684. 609.   3.   1.], curr_frame = 59
# idx: 178, label: [  1.   2.  59. 869. 696.   0.   1.], curr_frame = 59
# idx: 179, label: [  2.   1.  59. 860. 870.   0.   1.], curr_frame = 59
# idx: 180, label: [  0.          1.         60.        681.        612.          4.2426405
#    1.       ], curr_frame = 60
# idx: 181, label: [  1.   2.  60. 870. 696.   1.   1.], curr_frame = 60
# idx: 182, label: [  2.   1.  60. 862. 870.   2.   1.], curr_frame = 60
# idx: 183, label: [  0.   1.  61. 681. 614.   2.   1.], curr_frame = 61
# idx: 184, label: [  1.   2.  61. 871. 696.   1.   1.], curr_frame = 61
# idx: 185, label: [  2.   1.  61. 862. 868.   2.   1.], curr_frame = 61
# idx: 186, label: [  0.   1.  62. 681. 619.   5.   1.], curr_frame = 62
# idx: 187, label: [  1.   2.  62. 871. 696.   0.   1.], curr_frame = 62
# idx: 188, label: [  2.   1.  62. 862. 868.   0.   1.], curr_frame = 62
# idx: 189, label: [  0.          1.         63.        678.        622.          4.2426405
#    1.       ], curr_frame = 63
# idx: 190, label: [  1.   2.  63. 871. 696.   0.   1.], curr_frame = 63
# idx: 191, label: [  2.   1.  63. 862. 868.   0.   1.], curr_frame = 63
# idx: 192, label: [  0.   1.  64. 678. 624.   2.   1.], curr_frame = 64
# idx: 193, label: [  1.   2.  64. 871. 696.   0.   1.], curr_frame = 64
# idx: 194, label: [  2.   1.  64. 862. 868.   0.   1.], curr_frame = 64
# idx: 195, label: [  0.   1.  65. 678. 628.   4.   1.], curr_frame = 65
# idx: 196, label: [  1.          2.         65.        872.        697.          1.4142135
#    1.       ], curr_frame = 65
# idx: 197, label: [  2.   1.  65. 862. 868.   0.   1.], curr_frame = 65
# idx: 198, label: [  0.   1.  66. 678. 631.   3.   1.], curr_frame = 66
# idx: 199, label: [  1.   2.  66. 872. 697.   0.   1.], curr_frame = 66
# idx: 200, label: [  2.   1.  66. 864. 868.   2.   1.], curr_frame = 66
# idx: 201, label: [  0.   1.  67. 678. 632.   1.   1.], curr_frame = 67
# idx: 202, label: [  1.         2.        67.       874.       698.         2.236068
#    1.      ], curr_frame = 67
# idx: 203, label: [  2.   1.  67. 866. 868.   2.   1.], curr_frame = 67
# idx: 204, label: [  0.          1.         68.        677.        636.          4.1231055
#    1.       ], curr_frame = 68
# idx: 205, label: [  1.   2.  68. 874. 698.   0.   1.], curr_frame = 68
# idx: 206, label: [  2.   1.  68. 866. 868.   0.   1.], curr_frame = 68
# idx: 207, label: [  0.          1.         69.        678.        639.          3.1622777
#    1.       ], curr_frame = 69
# idx: 208, label: [  1.   2.  69. 875. 698.   1.   1.], curr_frame = 69
# idx: 209, label: [  2.   1.  69. 866. 868.   0.   1.], curr_frame = 69
# idx: 210, label: [  0.   1.  70. 678. 645.   6.   1.], curr_frame = 70
# idx: 211, label: [  1.   2.  70. 875. 698.   0.   1.], curr_frame = 70
# idx: 212, label: [  2.   1.  70. 868. 868.   2.   1.], curr_frame = 70
# idx: 213, label: [  0.          1.         71.        677.        646.          1.4142135
#    1.       ], curr_frame = 71
# idx: 214, label: [  1.   2.  71. 875. 698.   0.   1.], curr_frame = 71
# idx: 215, label: [  2.         1.        71.       867.       866.         2.236068
#    1.      ], curr_frame = 71
# idx: 216, label: [  0.   1.  72. 677. 649.   3.   1.], curr_frame = 72
# idx: 217, label: [  1.   2.  72. 875. 698.   0.   1.], curr_frame = 72
# idx: 218, label: [  2.   1.  72. 866. 866.   1.   1.], curr_frame = 72
# idx: 219, label: [  0.         1.        73.       675.       653.         4.472136
#    1.      ], curr_frame = 73
# idx: 220, label: [  1.          2.         73.        874.        699.          1.4142135
#    1.       ], curr_frame = 73
# idx: 221, label: [  2.   1.  73. 866. 867.   1.   1.], curr_frame = 73
# idx: 222, label: [  0.          1.         74.        674.        656.          3.1622777
#    1.       ], curr_frame = 74
# idx: 223, label: [  1.   2.  74. 874. 699.   0.   1.], curr_frame = 74
# idx: 224, label: [  2.   1.  74. 866. 867.   0.   1.], curr_frame = 74
# idx: 225, label: [  0.          1.         75.        672.        659.          3.6055512
#    1.       ], curr_frame = 75
# idx: 226, label: [  1.   2.  75. 874. 699.   0.   1.], curr_frame = 75
# idx: 227, label: [  2.   1.  75. 866. 867.   0.   1.], curr_frame = 75
# idx: 228, label: [  0.   1.  76. 672. 664.   5.   1.], curr_frame = 76
# idx: 229, label: [  1.          2.         76.        875.        700.          1.4142135
#    1.       ], curr_frame = 76
# idx: 230, label: [  2.   1.  76. 867. 867.   1.   1.], curr_frame = 76
# idx: 231, label: [  0.          1.         77.        671.        667.          3.1622777
#    1.       ], curr_frame = 77
# idx: 232, label: [  1.   2.  77. 875. 700.   0.   1.], curr_frame = 77
# idx: 233, label: [  2.   1.  77. 868. 867.   1.   1.], curr_frame = 77
# idx: 234, label: [  0.          1.         78.        674.        668.          3.1622777
#    1.       ], curr_frame = 78
# idx: 235, label: [  1.   2.  78. 877. 700.   2.   1.], curr_frame = 78
# idx: 236, label: [  2.   1.  78. 868. 867.   0.   1.], curr_frame = 78
# idx: 237, label: [  0.   1.  79. 674. 670.   2.   1.], curr_frame = 79
# idx: 238, label: [  1.   2.  79. 877. 700.   0.   1.], curr_frame = 79
# idx: 239, label: [  2.   1.  79. 868. 867.   0.   1.], curr_frame = 79
# idx: 240, label: [  0.   1.  80. 674. 673.   3.   1.], curr_frame = 80
# idx: 241, label: [  1.   2.  80. 878. 700.   1.   1.], curr_frame = 80
# idx: 242, label: [  2.   1.  80. 871. 867.   3.   1.], curr_frame = 80
# idx: 243, label: [  0.          1.         81.        675.        677.          4.1231055
#    1.       ], curr_frame = 81
# idx: 244, label: [  1.   2.  81. 879. 700.   1.   1.], curr_frame = 81
# idx: 245, label: [  2.   1.  81. 871. 867.   0.   1.], curr_frame = 81
# idx: 246, label: [  0.   1.  82. 675. 680.   3.   1.], curr_frame = 82
# idx: 247, label: [  1.   2.  82. 881. 700.   2.   1.], curr_frame = 82
# idx: 248, label: [  2.   1.  82. 871. 867.   0.   1.], curr_frame = 82
# idx: 249, label: [  0.         1.        83.       676.       682.         2.236068
#    1.      ], curr_frame = 83
# idx: 250, label: [  1.   2.  83. 881. 701.   1.   1.], curr_frame = 83
# idx: 251, label: [  2.   1.  83. 871. 867.   0.   1.], curr_frame = 83
# idx: 252, label: [  0.   1.  84. 677. 682.   1.   1.], curr_frame = 84
# idx: 253, label: [  1.   2.  84. 881. 701.   0.   1.], curr_frame = 84
# idx: 254, label: [  2.          1.         84.        872.        866.          1.4142135
#    1.       ], curr_frame = 84
# idx: 255, label: [  0.   1.  85. 677. 684.   2.   1.], curr_frame = 85
# idx: 256, label: [  1.   2.  85. 881. 701.   0.   1.], curr_frame = 85
# idx: 257, label: [  2.   1.  85. 872. 866.   0.   1.], curr_frame = 85
# idx: 258, label: [  0.   1.  86. 676. 684.   1.   1.], curr_frame = 86
# idx: 259, label: [  1.   2.  86. 881. 701.   0.   1.], curr_frame = 86
# idx: 260, label: [  2.   1.  86. 872. 866.   0.   1.], curr_frame = 86
# idx: 261, label: [  0.          1.         87.        679.        682.          3.6055512
#    1.       ], curr_frame = 87
# idx: 262, label: [  1.   2.  87. 881. 701.   0.   1.], curr_frame = 87
# idx: 263, label: [  2.   1.  87. 871. 866.   1.   1.], curr_frame = 87
# idx: 264, label: [  0.   1.  88. 679. 682.   0.   1.], curr_frame = 88
# idx: 265, label: [  1.   2.  88. 882. 701.   1.   1.], curr_frame = 88
# idx: 266, label: [  2.         1.        88.       872.       864.         2.236068
#    1.      ], curr_frame = 88
# idx: 267, label: [  0.   1.  89. 679. 680.   2.   1.], curr_frame = 89
# idx: 268, label: [  1.   2.  89. 882. 701.   0.   1.], curr_frame = 89
# idx: 269, label: [  2.   1.  89. 872. 864.   0.   1.], curr_frame = 89
# idx: 270, label: [  0.   1.  90. 680. 680.   1.   1.], curr_frame = 90
# idx: 271, label: [  1.   2.  90. 884. 701.   2.   1.], curr_frame = 90
# idx: 272, label: [  2.   1.  90. 874. 864.   2.   1.], curr_frame = 90
# idx: 273, label: [  0.          1.         91.        682.        677.          3.6055512
#    1.       ], curr_frame = 91
# idx: 274, label: [  1.   2.  91. 886. 701.   2.   1.], curr_frame = 91
# idx: 275, label: [  2.   1.  91. 874. 864.   0.   1.], curr_frame = 91
# idx: 276, label: [  0.          1.         92.        683.        676.          1.4142135
#    1.       ], curr_frame = 92
# idx: 277, label: [  1.   2.  92. 887. 701.   1.   1.], curr_frame = 92
# idx: 278, label: [  2.   1.  92. 874. 864.   0.   1.], curr_frame = 92
# idx: 279, label: [  0.   1.  93. 686. 672.   5.   1.], curr_frame = 93
# idx: 280, label: [  1.   2.  93. 887. 701.   0.   1.], curr_frame = 93
# idx: 281, label: [  2.   1.  93. 874. 864.   0.   1.], curr_frame = 93
# idx: 282, label: [  0.   1.  94. 686. 668.   4.   1.], curr_frame = 94
# idx: 283, label: [  1.   2.  94. 887. 701.   0.   1.], curr_frame = 94
# idx: 284, label: [  2.   1.  94. 874. 864.   0.   1.], curr_frame = 94
# idx: 285, label: [  0.   1.  95. 686. 664.   4.   1.], curr_frame = 95
# idx: 286, label: [  1.   2.  95. 888. 701.   1.   1.], curr_frame = 95
# idx: 287, label: [  2.   1.  95. 874. 864.   0.   1.], curr_frame = 95
# idx: 288, label: [  0.         1.        96.       688.       660.         4.472136
#    1.      ], curr_frame = 96
# idx: 289, label: [  1.   2.  96. 889. 701.   1.   1.], curr_frame = 96
# idx: 290, label: [  2.   1.  96. 874. 864.   0.   1.], curr_frame = 96
# idx: 291, label: [  0.         1.        97.       691.       654.         6.708204
#    1.      ], curr_frame = 97
# idx: 292, label: [  1.          2.         97.        890.        700.          1.4142135
#    1.       ], curr_frame = 97
# idx: 293, label: [  2.         1.        97.       872.       865.         2.236068
#    1.      ], curr_frame = 97
# idx: 294, label: [  0.   1.  98. 691. 650.   4.   1.], curr_frame = 98
# idx: 295, label: [  1.   2.  98. 889. 700.   1.   1.], curr_frame = 98
# idx: 296, label: [  2.   1.  98. 875. 865.   3.   1.], curr_frame = 98
# idx: 297, label: [  0.          1.         99.        692.        645.          5.0990195
#    1.       ], curr_frame = 99
# idx: 298, label: [  1.   2.  99. 889. 699.   1.   1.], curr_frame = 99
# idx: 299, label: [  2.   1.  99. 872. 865.   3.   1.], curr_frame = 99
# idx: 300, label: [  0.         1.       100.       694.       641.         4.472136
#    1.      ], curr_frame = 100
# idx: 301, label: [  1.   2. 100. 889. 699.   0.   1.], curr_frame = 100
# idx: 302, label: [  2.   1. 100. 872. 865.   0.   1.], curr_frame = 100
# idx: 303, label: [  0.          1.        101.        695.        635.          6.0827627
#    1.       ], curr_frame = 101
# idx: 304, label: [  1.   2. 101. 889. 699.   0.   1.], curr_frame = 101
# idx: 305, label: [  2.   1. 101. 870. 865.   2.   1.], curr_frame = 101
# idx: 306, label: [  0.          1.        102.        698.        630.          5.8309517
#    1.       ], curr_frame = 102
# idx: 307, label: [  1.   2. 102. 889. 699.   0.   1.], curr_frame = 102
# idx: 308, label: [  2.   1. 102. 868. 865.   2.   1.], curr_frame = 102
# idx: 309, label: [  0.          1.        103.        700.        625.          5.3851647
#    1.       ], curr_frame = 103
# idx: 310, label: [  1.          2.        103.        888.        696.          3.1622777
#    1.       ], curr_frame = 103
# idx: 311, label: [  2.   1. 103. 868. 865.   0.   1.], curr_frame = 103
# idx: 312, label: [  0.          1.        104.        701.        620.          5.0990195
#    1.       ], curr_frame = 104
# idx: 313, label: [  1.   2. 104. 888. 696.   0.   1.], curr_frame = 104
# idx: 314, label: [  2.   1. 104. 868. 865.   0.   1.], curr_frame = 104
# idx: 315, label: [  0.          1.        105.        705.        615.          6.4031243
#    1.       ], curr_frame = 105
# idx: 316, label: [  1.   2. 105. 888. 697.   1.   1.], curr_frame = 105
# idx: 317, label: [  2.   1. 105. 868. 865.   0.   1.], curr_frame = 105
# idx: 318, label: [  0.   1. 106. 705. 612.   3.   1.], curr_frame = 106
# idx: 319, label: [  1.   2. 106. 888. 697.   0.   1.], curr_frame = 106
# idx: 320, label: [  2.   1. 106. 867. 865.   1.   1.], curr_frame = 106
# idx: 321, label: [  0.          1.        107.        706.        606.          6.0827627
#    1.       ], curr_frame = 107
# idx: 322, label: [  1.          2.        107.        887.        696.          1.4142135
#    1.       ], curr_frame = 107
# idx: 323, label: [  2.   1. 107. 867. 865.   0.   1.], curr_frame = 107
# idx: 324, label: [  0.         1.       108.       708.       602.         4.472136
#    1.      ], curr_frame = 108
# idx: 325, label: [  1.         2.       108.       885.       695.         2.236068
#    1.      ], curr_frame = 108
# idx: 326, label: [  2.   1. 108. 865. 865.   2.   1.], curr_frame = 108
# idx: 327, label: [  0.          1.        109.        710.        597.          5.3851647
#    1.       ], curr_frame = 109
# idx: 328, label: [  1.          2.        109.        886.        696.          1.4142135
#    1.       ], curr_frame = 109
# idx: 329, label: [  2.   1. 109. 864. 865.   1.   1.], curr_frame = 109
# idx: 330, label: [  0.   1. 110. 710. 594.   3.   1.], curr_frame = 110
# idx: 331, label: [  1.         2.       110.       885.       694.         2.236068
#    1.      ], curr_frame = 110
# idx: 332, label: [  2.   1. 110. 864. 865.   0.   1.], curr_frame = 110
# idx: 333, label: [  0.          1.        111.        711.        588.          6.0827627
#    1.       ], curr_frame = 111
# idx: 334, label: [  1.   2. 111. 885. 694.   0.   1.], curr_frame = 111
# idx: 335, label: [  2.   1. 111. 862. 865.   2.   1.], curr_frame = 111
# idx: 336, label: [  0.         1.       112.       712.       586.         2.236068
#    1.      ], curr_frame = 112
# idx: 337, label: [  1.   2. 112. 882. 694.   3.   1.], curr_frame = 112
# idx: 338, label: [  2.   1. 112. 860. 865.   2.   1.], curr_frame = 112
# idx: 339, label: [  0.          1.        113.        713.        581.          5.0990195
#    1.       ], curr_frame = 113
# idx: 340, label: [  1.   2. 113. 882. 694.   0.   1.], curr_frame = 113
# idx: 341, label: [  2.   1. 113. 860. 865.   0.   1.], curr_frame = 113
# idx: 342, label: [  0.          1.        114.        715.        575.          6.3245554
#    1.       ], curr_frame = 114
# idx: 343, label: [  1.   2. 114. 877. 694.   5.   1.], curr_frame = 114
# idx: 344, label: [  2.   1. 114. 858. 865.   2.   1.], curr_frame = 114
# idx: 345, label: [  0.          1.        115.        714.        571.          4.1231055
#    1.       ], curr_frame = 115
# idx: 346, label: [  1.   2. 115. 876. 694.   1.   1.], curr_frame = 115
# idx: 347, label: [  2.   1. 115. 857. 865.   1.   1.], curr_frame = 115
# idx: 348, label: [  0.   1. 116. 714. 569.   2.   1.], curr_frame = 116
# idx: 349, label: [  1.   2. 116. 873. 694.   3.   1.], curr_frame = 116
# idx: 350, label: [  2.         1.       116.       855.       863.         2.828427
#    1.      ], curr_frame = 116
# idx: 351, label: [  0.   1. 117. 714. 563.   6.   1.], curr_frame = 117
# idx: 352, label: [  1.          2.        117.        872.        691.          3.1622777
#    1.       ], curr_frame = 117
# idx: 353, label: [  2.          1.        117.        852.        864.          3.1622777
#    1.       ], curr_frame = 117
# idx: 354, label: [  0.   1. 118. 714. 562.   1.   1.], curr_frame = 118
# idx: 355, label: [  1.   2. 118. 868. 691.   4.   1.], curr_frame = 118
# idx: 356, label: [  2.         1.       118.       850.       865.         2.236068
#    1.      ], curr_frame = 118
# idx: 357, label: [  0.          1.        119.        712.        556.          6.3245554
#    1.       ], curr_frame = 119
# idx: 358, label: [  1.   2. 119. 863. 691.   5.   1.], curr_frame = 119
# idx: 359, label: [  2.   1. 119. 847. 865.   3.   1.], curr_frame = 119
# idx: 360, label: [  0.         1.       120.       710.       554.         2.828427
#    1.      ], curr_frame = 120
# idx: 361, label: [  1.   2. 120. 860. 691.   3.   1.], curr_frame = 120
# idx: 362, label: [  2.   1. 120. 847. 865.   0.   1.], curr_frame = 120
# idx: 363, label: [  0.   1. 121. 707. 550.   5.   1.], curr_frame = 121
# idx: 364, label: [  1.   2. 121. 855. 691.   5.   1.], curr_frame = 121
# idx: 365, label: [  2.   1. 121. 842. 865.   5.   1.], curr_frame = 121
# idx: 366, label: [  0.          1.        122.        706.        546.          4.1231055
#    1.       ], curr_frame = 122
# idx: 367, label: [  1.          2.        122.        850.        690.          5.0990195
#    1.       ], curr_frame = 122
# idx: 368, label: [  2.         1.       122.       840.       866.         2.236068
#    1.      ], curr_frame = 122
# idx: 369, label: [  0.          1.        123.        703.        545.          3.1622777
#    1.       ], curr_frame = 123
# idx: 370, label: [  1.   2. 123. 847. 690.   3.   1.], curr_frame = 123
# idx: 371, label: [  2.          1.        123.        839.        867.          1.4142135
#    1.       ], curr_frame = 123
# idx: 372, label: [  0.          1.        124.        701.        542.          3.6055512
#    1.       ], curr_frame = 124
# idx: 373, label: [  1.   2. 124. 843. 690.   4.   1.], curr_frame = 124
# idx: 374, label: [  2.          1.        124.        833.        866.          6.0827627
#    1.       ], curr_frame = 124
# idx: 375, label: [  0.          1.        125.        698.        540.          3.6055512
#    1.       ], curr_frame = 125
# idx: 376, label: [  1.   2. 125. 838. 690.   5.   1.], curr_frame = 125
# idx: 377, label: [  2.   1. 125. 833. 866.   0.   1.], curr_frame = 125
# idx: 378, label: [  0.         1.       126.       697.       538.         2.236068
#    1.      ], curr_frame = 126
# idx: 379, label: [  1.   2. 126. 833. 690.   5.   1.], curr_frame = 126
# idx: 380, label: [  2.   1. 126. 829. 866.   4.   1.], curr_frame = 126
# idx: 381, label: [  0.          1.        127.        694.        533.          5.8309517
#    1.       ], curr_frame = 127
# idx: 382, label: [  1.         2.       127.       826.       691.         7.071068
#    1.      ], curr_frame = 127
# idx: 383, label: [  2.   1. 127. 828. 866.   1.   1.], curr_frame = 127
# idx: 384, label: [  0.          1.        128.        689.        530.          5.8309517
#    1.       ], curr_frame = 128
# idx: 385, label: [  1.         2.       128.       818.       693.         8.246211
#    1.      ], curr_frame = 128
# idx: 386, label: [  2.          1.        128.        823.        868.          5.3851647
#    1.       ], curr_frame = 128
# idx: 387, label: [  0.         1.       129.       687.       529.         2.236068
#    1.      ], curr_frame = 129
# idx: 388, label: [  1.   2. 129. 811. 693.   7.   1.], curr_frame = 129
# idx: 389, label: [  2.   1. 129. 820. 868.   3.   1.], curr_frame = 129
# idx: 390, label: [  0.          1.        130.        684.        528.          3.1622777
#    1.       ], curr_frame = 130
# idx: 391, label: [  1.   2. 130. 805. 693.   6.   1.], curr_frame = 130
# idx: 392, label: [  2.   1. 130. 817. 868.   3.   1.], curr_frame = 130
# idx: 393, label: [  0.          1.        131.        681.        526.          3.6055512
#    1.       ], curr_frame = 131
# idx: 394, label: [  1.         2.       131.       801.       695.         4.472136
#    1.      ], curr_frame = 131
# idx: 395, label: [  2.   1. 131. 815. 868.   2.   1.], curr_frame = 131
# idx: 396, label: [  0.   1. 132. 681. 524.   2.   1.], curr_frame = 132
# idx: 397, label: [  1.   2. 132. 797. 695.   4.   1.], curr_frame = 132
# idx: 398, label: [  2.          1.        132.        812.        869.          3.1622777
#    1.       ], curr_frame = 132
# idx: 399, label: [  0.   1. 133. 678. 524.   3.   1.], curr_frame = 133
# idx: 400, label: [  1.         2.       133.       789.       696.         8.062258
#    1.      ], curr_frame = 133
# idx: 401, label: [  2.   1. 133. 810. 869.   2.   1.], curr_frame = 133
# idx: 402, label: [  0.         1.       134.       676.       522.         2.828427
#    1.      ], curr_frame = 134
# idx: 403, label: [  1.   2. 134. 787. 696.   2.   1.], curr_frame = 134
# idx: 404, label: [  2.   1. 134. 808. 869.   2.   1.], curr_frame = 134
# idx: 405, label: [  0.   1. 135. 675. 522.   1.   1.], curr_frame = 135
# idx: 406, label: [  1.         2.       135.       785.       698.         2.828427
#    1.      ], curr_frame = 135
# idx: 407, label: [  2.          1.        135.        805.        871.          3.6055512
#    1.       ], curr_frame = 135
# idx: 408, label: [  0.   1. 136. 673. 522.   2.   1.], curr_frame = 136
# idx: 409, label: [  1.          2.        136.        780.        699.          5.0990195
#    1.       ], curr_frame = 136
# idx: 410, label: [  2.   1. 136. 804. 871.   1.   1.], curr_frame = 136
# idx: 411, label: [  0.         1.       137.       671.       523.         2.236068
#    1.      ], curr_frame = 137
# idx: 412, label: [  1.         2.       137.       774.       702.         6.708204
#    1.      ], curr_frame = 137
# idx: 413, label: [  2.   1. 137. 801. 871.   3.   1.], curr_frame = 137
# idx: 414, label: [  0.   1. 138. 670. 523.   1.   1.], curr_frame = 138
# idx: 415, label: [  1.   2. 138. 770. 702.   4.   1.], curr_frame = 138
# idx: 416, label: [  2.   1. 138. 798. 871.   3.   1.], curr_frame = 138
# idx: 417, label: [  0.   1. 139. 667. 523.   3.   1.], curr_frame = 139
# idx: 418, label: [  1.          2.        139.        764.        703.          6.0827627
#    1.       ], curr_frame = 139
# idx: 419, label: [  2.          1.        139.        795.        873.          3.6055512
#    1.       ], curr_frame = 139
# idx: 420, label: [  0.   1. 140. 667. 523.   0.   1.], curr_frame = 140
# idx: 421, label: [  1.         2.       140.       763.       705.         2.236068
#    1.      ], curr_frame = 140
# idx: 422, label: [  2.   1. 140. 793. 873.   2.   1.], curr_frame = 140
# idx: 423, label: [  0.   1. 141. 664. 523.   3.   1.], curr_frame = 141
# idx: 424, label: [  1.   2. 141. 759. 705.   4.   1.], curr_frame = 141
# idx: 425, label: [  2.   1. 141. 791. 873.   2.   1.], curr_frame = 141
# idx: 426, label: [  0.   1. 142. 661. 523.   3.   1.], curr_frame = 142
# idx: 427, label: [  1.          2.        142.        754.        708.          5.8309517
#    1.       ], curr_frame = 142
# idx: 428, label: [  2.   1. 142. 790. 873.   1.   1.], curr_frame = 142
# idx: 429, label: [  0.   1. 143. 659. 523.   2.   1.], curr_frame = 143
# idx: 430, label: [  1.   2. 143. 752. 708.   2.   1.], curr_frame = 143
# idx: 431, label: [  2.          1.        143.        787.        875.          3.6055512
#    1.       ], curr_frame = 143
# idx: 432, label: [  0.         1.       144.       657.       525.         2.828427
#    1.      ], curr_frame = 144
# idx: 433, label: [  1.          2.        144.        746.        710.          6.3245554
#    1.       ], curr_frame = 144
# idx: 434, label: [  2.   1. 144. 783. 875.   4.   1.], curr_frame = 144
# idx: 435, label: [  0.   1. 145. 655. 525.   2.   1.], curr_frame = 145
# idx: 436, label: [  1.         2.       145.       742.       714.         5.656854
#    1.      ], curr_frame = 145
# idx: 437, label: [  2.         1.       145.       781.       876.         2.236068
#    1.      ], curr_frame = 145
# idx: 438, label: [  0.   1. 146. 652. 525.   3.   1.], curr_frame = 146
# idx: 439, label: [  1.   2. 146. 738. 714.   4.   1.], curr_frame = 146
# idx: 440, label: [  2.          1.        146.        780.        879.          3.1622777
#    1.       ], curr_frame = 146
# idx: 441, label: [  0.          1.        147.        649.        528.          4.2426405
#    1.       ], curr_frame = 147
# idx: 442, label: [  1.   2. 147. 734. 717.   5.   1.], curr_frame = 147
# idx: 443, label: [  2.         1.       147.       778.       878.         2.236068
#    1.      ], curr_frame = 147
# idx: 444, label: [  0.   1. 148. 647. 528.   2.   1.], curr_frame = 148
# idx: 445, label: [  1.          2.        148.        729.        719.          5.3851647
#    1.       ], curr_frame = 148
# idx: 446, label: [  2.   1. 148. 775. 878.   3.   1.], curr_frame = 148
# idx: 447, label: [  0.   1. 149. 643. 528.   4.   1.], curr_frame = 149
# idx: 448, label: [  1.          2.        149.        724.        721.          5.3851647
#    1.       ], curr_frame = 149
# idx: 449, label: [  2.   1. 149. 773. 878.   2.   1.], curr_frame = 149
# Found: v0-1
# Frames: 150
# (150, 2)
# 450
# idx: 0, label: [  0.   1.   0. 580. 381.  -1.  -1.], curr_frame = 0
# idx: 1, label: [  1.   2.   0. 659. 579.  -1.  -1.], curr_frame = 0
# idx: 2, label: [  2.   1.   0. 686. 743.  -1.  -1.], curr_frame = 0
# idx: 3, label: [  0.   1.   1. 580. 381.   0.   1.], curr_frame = 1
# idx: 4, label: [  1.   2.   1. 659. 579.   0.   1.], curr_frame = 1
# idx: 5, label: [  2.          1.          1.        687.        744.          1.4142135
#    1.       ], curr_frame = 1
# idx: 6, label: [  0.   1.   2. 580. 381.   0.   1.], curr_frame = 2
# idx: 7, label: [  1.   2.   2. 659. 578.   1.   1.], curr_frame = 2
# idx: 8, label: [  2.   1.   2. 687. 744.   0.   1.], curr_frame = 2
# idx: 9, label: [  0.   1.   3. 580. 381.   0.   1.], curr_frame = 3
# idx: 10, label: [  1.   2.   3. 659. 578.   0.   1.], curr_frame = 3
# idx: 11, label: [  2.   1.   3. 687. 744.   0.   1.], curr_frame = 3
# idx: 12, label: [  0.   1.   4. 580. 381.   0.   1.], curr_frame = 4
# idx: 13, label: [  1.   2.   4. 659. 578.   0.   1.], curr_frame = 4
# idx: 14, label: [  2.   1.   4. 687. 744.   0.   1.], curr_frame = 4
# idx: 15, label: [  0.   1.   5. 580. 381.   0.   1.], curr_frame = 5
# idx: 16, label: [  1.   2.   5. 659. 577.   1.   1.], curr_frame = 5
# idx: 17, label: [  2.   1.   5. 688. 744.   1.   1.], curr_frame = 5
# idx: 18, label: [  0.   1.   6. 580. 381.   0.   1.], curr_frame = 6
# idx: 19, label: [  1.   2.   6. 659. 580.   3.   1.], curr_frame = 6
# idx: 20, label: [  2.   1.   6. 687. 744.   1.   1.], curr_frame = 6
# idx: 21, label: [  0.   1.   7. 580. 381.   0.   1.], curr_frame = 7
# idx: 22, label: [  1.         2.         7.       657.       579.         2.236068
#    1.      ], curr_frame = 7
# idx: 23, label: [  2.   1.   7. 687. 744.   0.   1.], curr_frame = 7
# idx: 24, label: [  0.   1.   8. 581. 381.   1.   1.], curr_frame = 8
# idx: 25, label: [  1.   2.   8. 657. 577.   2.   1.], curr_frame = 8
# idx: 26, label: [  2.   1.   8. 687. 744.   0.   1.], curr_frame = 8
# idx: 27, label: [  0.   1.   9. 581. 381.   0.   1.], curr_frame = 9
# idx: 28, label: [  1.   2.   9. 657. 579.   2.   1.], curr_frame = 9
# idx: 29, label: [  2.   1.   9. 687. 744.   0.   1.], curr_frame = 9
# idx: 30, label: [  0.   1.  10. 581. 381.   0.   1.], curr_frame = 10
# idx: 31, label: [  1.   2.  10. 659. 579.   2.   1.], curr_frame = 10
# idx: 32, label: [  2.   1.  10. 687. 744.   0.   1.], curr_frame = 10
# idx: 33, label: [  0.   1.  11. 581. 381.   0.   1.], curr_frame = 11
# idx: 34, label: [  1.   2.  11. 659. 578.   1.   1.], curr_frame = 11
# idx: 35, label: [  2.   1.  11. 687. 744.   0.   1.], curr_frame = 11
# idx: 36, label: [  0.   1.  12. 581. 381.   0.   1.], curr_frame = 12
# idx: 37, label: [  1.   2.  12. 659. 578.   0.   1.], curr_frame = 12
# idx: 38, label: [  2.   1.  12. 687. 744.   0.   1.], curr_frame = 12
# idx: 39, label: [  0.   1.  13. 580. 381.   1.   1.], curr_frame = 13
# idx: 40, label: [  1.   2.  13. 659. 578.   0.   1.], curr_frame = 13
# idx: 41, label: [  2.   1.  13. 687. 744.   0.   1.], curr_frame = 13
# idx: 42, label: [  0.   1.  14. 580. 381.   0.   1.], curr_frame = 14
# idx: 43, label: [  1.   2.  14. 659. 578.   0.   1.], curr_frame = 14
# idx: 44, label: [  2.   1.  14. 687. 744.   0.   1.], curr_frame = 14
# idx: 45, label: [  0.   1.  15. 581. 381.   1.   1.], curr_frame = 15
# idx: 46, label: [  1.   2.  15. 659. 578.   0.   1.], curr_frame = 15
# idx: 47, label: [  2.   1.  15. 687. 744.   0.   1.], curr_frame = 15
# idx: 48, label: [  0.   1.  16. 581. 381.   0.   1.], curr_frame = 16
# idx: 49, label: [  1.   2.  16. 659. 578.   0.   1.], curr_frame = 16
# idx: 50, label: [  2.   1.  16. 687. 744.   0.   1.], curr_frame = 16
# idx: 51, label: [  0.   1.  17. 581. 381.   0.   1.], curr_frame = 17
# idx: 52, label: [  1.   2.  17. 659. 578.   0.   1.], curr_frame = 17
# idx: 53, label: [  2.   1.  17. 687. 744.   0.   1.], curr_frame = 17
# idx: 54, label: [  0.   1.  18. 581. 381.   0.   1.], curr_frame = 18
# idx: 55, label: [  1.   2.  18. 659. 578.   0.   1.], curr_frame = 18
# idx: 56, label: [  2.   1.  18. 688. 744.   1.   1.], curr_frame = 18
# idx: 57, label: [  0.   1.  19. 581. 381.   0.   1.], curr_frame = 19
# idx: 58, label: [  1.   2.  19. 659. 578.   0.   1.], curr_frame = 19
# idx: 59, label: [  2.   1.  19. 688. 744.   0.   1.], curr_frame = 19
# idx: 60, label: [  0.   1.  20. 581. 381.   0.   1.], curr_frame = 20
# idx: 61, label: [  1.   2.  20. 659. 578.   0.   1.], curr_frame = 20
# idx: 62, label: [  2.   1.  20. 688. 744.   0.   1.], curr_frame = 20
# idx: 63, label: [  0.   1.  21. 581. 381.   0.   1.], curr_frame = 21
# idx: 64, label: [  1.          2.         21.        660.        577.          1.4142135
#    1.       ], curr_frame = 21
# idx: 65, label: [  2.   1.  21. 688. 744.   0.   1.], curr_frame = 21
# idx: 66, label: [  0.   1.  22. 579. 381.   2.   1.], curr_frame = 22
# idx: 67, label: [  1.   2.  22. 660. 577.   0.   1.], curr_frame = 22
# idx: 68, label: [  2.   1.  22. 688. 744.   0.   1.], curr_frame = 22
# idx: 69, label: [  0.   1.  23. 582. 381.   3.   1.], curr_frame = 23
# idx: 70, label: [  1.   2.  23. 660. 577.   0.   1.], curr_frame = 23
# idx: 71, label: [  2.   1.  23. 689. 744.   1.   1.], curr_frame = 23
# idx: 72, label: [  0.   1.  24. 581. 381.   1.   1.], curr_frame = 24
# idx: 73, label: [  1.   2.  24. 660. 577.   0.   1.], curr_frame = 24
# idx: 74, label: [  2.   1.  24. 689. 742.   2.   1.], curr_frame = 24
# idx: 75, label: [  0.   1.  25. 581. 381.   0.   1.], curr_frame = 25
# idx: 76, label: [  1.   2.  25. 660. 578.   1.   1.], curr_frame = 25
# idx: 77, label: [  2.   1.  25. 689. 743.   1.   1.], curr_frame = 25
# idx: 78, label: [  0.   1.  26. 581. 381.   0.   1.], curr_frame = 26
# idx: 79, label: [  1.   2.  26. 660. 578.   0.   1.], curr_frame = 26
# idx: 80, label: [  2.   1.  26. 688. 743.   1.   1.], curr_frame = 26
# idx: 81, label: [  0.   1.  27. 581. 381.   0.   1.], curr_frame = 27
# idx: 82, label: [  1.   2.  27. 660. 578.   0.   1.], curr_frame = 27
# idx: 83, label: [  2.          1.         27.        689.        744.          1.4142135
#    1.       ], curr_frame = 27
# idx: 84, label: [  0.   1.  28. 581. 381.   0.   1.], curr_frame = 28
# idx: 85, label: [  1.          2.         28.        663.        577.          3.1622777
#    1.       ], curr_frame = 28
# idx: 86, label: [  2.          1.         28.        692.        743.          3.1622777
#    1.       ], curr_frame = 28
# idx: 87, label: [  0.   1.  29. 582. 381.   1.   1.], curr_frame = 29
# idx: 88, label: [  1.          2.         29.        666.        575.          3.6055512
#    1.       ], curr_frame = 29
# idx: 89, label: [  2.   1.  29. 692. 743.   0.   1.], curr_frame = 29
# idx: 90, label: [  0.         1.        30.       583.       379.         2.236068
#    1.      ], curr_frame = 30
# idx: 91, label: [  1.          2.         30.        671.        573.          5.3851647
#    1.       ], curr_frame = 30
# idx: 92, label: [  2.   1.  30. 694. 743.   2.   1.], curr_frame = 30
# idx: 93, label: [  0.   1.  31. 584. 379.   1.   1.], curr_frame = 31
# idx: 94, label: [  1.          2.         31.        676.        570.          5.8309517
#    1.       ], curr_frame = 31
# idx: 95, label: [  2.   1.  31. 696. 743.   2.   1.], curr_frame = 31
# idx: 96, label: [  0.          1.         32.        587.        377.          3.6055512
#    1.       ], curr_frame = 32
# idx: 97, label: [  1.          2.         32.        681.        567.          5.8309517
#    1.       ], curr_frame = 32
# idx: 98, label: [  2.          1.         32.        700.        742.          4.1231055
#    1.       ], curr_frame = 32
# idx: 99, label: [  0.   1.  33. 588. 377.   1.   1.], curr_frame = 33
# idx: 100, label: [  1.          2.         33.        687.        566.          6.0827627
#    1.       ], curr_frame = 33
# idx: 101, label: [  2.   1.  33. 704. 742.   4.   1.], curr_frame = 33
# idx: 102, label: [  0.   1.  34. 592. 380.   5.   1.], curr_frame = 34
# idx: 103, label: [  1.   2.  34. 696. 566.   9.   1.], curr_frame = 34
# idx: 104, label: [  2.   1.  34. 705. 742.   1.   1.], curr_frame = 34
# idx: 105, label: [  0.   1.  35. 595. 380.   3.   1.], curr_frame = 35
# idx: 106, label: [  1.          2.         35.        699.        565.          3.1622777
#    1.       ], curr_frame = 35
# idx: 107, label: [  2.   1.  35. 710. 742.   5.   1.], curr_frame = 35
# idx: 108, label: [  0.         1.        36.       597.       381.         2.236068
#    1.      ], curr_frame = 36
# idx: 109, label: [  1.   2.  36. 707. 565.   8.   1.], curr_frame = 36
# idx: 110, label: [  2.   1.  36. 714. 742.   4.   1.], curr_frame = 36
# idx: 111, label: [  0.         1.        37.       596.       383.         2.236068
#    1.      ], curr_frame = 37
# idx: 112, label: [  1.         2.        37.       709.       564.         2.236068
#    1.      ], curr_frame = 37
# idx: 113, label: [  2.         1.        37.       716.       743.         2.236068
#    1.      ], curr_frame = 37
# idx: 114, label: [  0.         1.        38.       597.       385.         2.236068
#    1.      ], curr_frame = 38
# idx: 115, label: [  1.   2.  38. 713. 564.   4.   1.], curr_frame = 38
# idx: 116, label: [  2.   1.  38. 720. 743.   4.   1.], curr_frame = 38
# idx: 117, label: [  0.   1.  39. 597. 387.   2.   1.], curr_frame = 39
# idx: 118, label: [  1.          2.         39.        718.        562.          5.3851647
#    1.       ], curr_frame = 39
# ...
# idx: 203, label: [5.000000e+00 1.000000e+00 8.800000e+01 1.270000e+03 5.990000e+02
#  4.104875e+01 1.000000e+00], curr_frame = 88
# idx: 204, label: [  0.   2.  89. 211.  32.   0.   1.], curr_frame = 89
# idx: 205, label: [2.0000000e+00 1.0000000e+00 8.9000000e+01 1.2920000e+03 1.8800000e+02
#  4.3185646e+01 1.0000000e+00], curr_frame = 89
# idx: 206, label: [4.0000000e+00 1.0000000e+00 8.9000000e+01 1.3030000e+03 9.4500000e+02
#  1.0630146e+01 1.0000000e+00], curr_frame = 89
# idx: 207, label: [5.0000000e+00 1.0000000e+00 8.9000000e+01 1.3100000e+03 6.0400000e+02
#  4.0311287e+01 1.0000000e+00], curr_frame = 89
# idx: 208, label: [  0.   2.  90. 211.  32.   0.   1.], curr_frame = 90
# idx: 209, label: [1.0000000e+00 2.0000000e+00 9.0000000e+01 1.1320000e+03 2.1700000e+02
#  3.7909497e+02 9.0000000e+00], curr_frame = 90
# idx: 210, label: [2.000000e+00 1.000000e+00 9.000000e+01 1.339000e+03 1.940000e+02
#  4.738143e+01 1.000000e+00], curr_frame = 90
# idx: 211, label: [4.0000000e+00 1.0000000e+00 9.0000000e+01 1.3230000e+03 9.4900000e+02
#  2.0396078e+01 1.0000000e+00], curr_frame = 90
# idx: 212, label: [5.000000e+00 1.000000e+00 9.000000e+01 1.343000e+03 6.090000e+02
#  3.337664e+01 1.000000e+00], curr_frame = 90
# idx: 213, label: [  0.   2.  91. 211.  32.   0.   1.], curr_frame = 91
# idx: 214, label: [1.0000000e+00 2.0000000e+00 9.1000000e+01 1.1780000e+03 2.1800000e+02
#  4.6010868e+01 1.0000000e+00], curr_frame = 91
# idx: 215, label: [2.0000000e+00 1.0000000e+00 9.1000000e+01 1.3800000e+03 1.9900000e+02
#  4.1303753e+01 1.0000000e+00], curr_frame = 91
# idx: 216, label: [4.0000000e+00 1.0000000e+00 9.1000000e+01 1.3360000e+03 9.5100000e+02
#  1.3152946e+01 1.0000000e+00], curr_frame = 91
# idx: 217, label: [5.000e+00 1.000e+00 9.100e+01 1.374e+03 6.090e+02 3.100e+01 1.000e+00], curr_frame = 91
# idx: 218, label: [  0.   2.  92. 211.  32.   0.   1.], curr_frame = 92
# idx: 219, label: [1.000000e+00 2.000000e+00 9.200000e+01 1.217000e+03 2.120000e+02
#  3.945884e+01 1.000000e+00], curr_frame = 92
# idx: 220, label: [2.00000e+00 1.00000e+00 9.20000e+01 1.42000e+03 1.95000e+02 4.01995e+01
#  1.00000e+00], curr_frame = 92
# idx: 221, label: [4.0000000e+00 1.0000000e+00 9.2000000e+01 1.3400000e+03 9.5000000e+02
#  4.1231055e+00 1.0000000e+00], curr_frame = 92
# idx: 222, label: [5.0000000e+00 1.0000000e+00 9.2000000e+01 1.4010000e+03 6.1000000e+02
#  2.7018513e+01 1.0000000e+00], curr_frame = 92
# idx: 223, label: [  0.   2.  93. 211.  32.   0.   1.], curr_frame = 93
# idx: 224, label: [1.0000000e+00 2.0000000e+00 9.3000000e+01 1.2510000e+03 2.0900000e+02
#  3.4132095e+01 1.0000000e+00], curr_frame = 93
# idx: 225, label: [2.0000000e+00 1.0000000e+00 9.3000000e+01 1.4540000e+03 1.9100000e+02
#  3.4234486e+01 1.0000000e+00], curr_frame = 93
# idx: 226, label: [4.0000000e+00 1.0000000e+00 9.3000000e+01 1.3440000e+03 9.5100000e+02
#  4.1231055e+00 1.0000000e+00], curr_frame = 93
# idx: 227, label: [5.0000000e+00 1.0000000e+00 9.3000000e+01 1.4150000e+03 6.1200000e+02
#  1.4142136e+01 1.0000000e+00], curr_frame = 93
# idx: 228, label: [  0.   2.  94. 211.  32.   0.   1.], curr_frame = 94
# idx: 229, label: [1.000000e+00 2.000000e+00 9.400000e+01 1.284000e+03 2.070000e+02
#  3.306055e+01 1.000000e+00], curr_frame = 94
# idx: 230, label: [4.000e+00 1.000e+00 9.400e+01 1.344e+03 9.510e+02 0.000e+00 1.000e+00], curr_frame = 94
# idx: 231, label: [5.0000000e+00 1.0000000e+00 9.4000000e+01 1.4330000e+03 6.1100000e+02
#  1.8027756e+01 1.0000000e+00], curr_frame = 94
# idx: 232, label: [  0.   2.  95. 211.  32.   0.   1.], curr_frame = 95
# idx: 233, label: [1.0000000e+00 2.0000000e+00 9.5000000e+01 1.3140000e+03 2.0600000e+02
#  3.0016663e+01 1.0000000e+00], curr_frame = 95
# idx: 234, label: [2.000000e+00 1.000000e+00 9.500000e+01 1.516000e+03 1.980000e+02
#  6.239391e+01 2.000000e+00], curr_frame = 95
# idx: 235, label: [4.000e+00 1.000e+00 9.500e+01 1.348e+03 9.510e+02 4.000e+00 1.000e+00], curr_frame = 95
# idx: 236, label: [5.000000e+00 1.000000e+00 9.500000e+01 1.442000e+03 6.120000e+02
#  9.055386e+00 1.000000e+00], curr_frame = 95
# idx: 237, label: [  0.   2.  96. 211.  32.   0.   1.], curr_frame = 96
# idx: 238, label: [1.0000000e+00 2.0000000e+00 9.6000000e+01 1.3400000e+03 2.0300000e+02
#  2.6172504e+01 1.0000000e+00], curr_frame = 96
# idx: 239, label: [2.000e+00 1.000e+00 9.600e+01 1.544e+03 1.980e+02 2.800e+01 1.000e+00], curr_frame = 96
# idx: 240, label: [4.000000e+00 1.000000e+00 9.600000e+01 1.350000e+03 9.500000e+02
#  2.236068e+00 1.000000e+00], curr_frame = 96
# idx: 241, label: [5.000e+00 1.000e+00 9.600e+01 1.453e+03 6.120e+02 1.100e+01 1.000e+00], curr_frame = 96
# idx: 242, label: [  0.   2.  97. 211.  32.   0.   1.], curr_frame = 97
# idx: 243, label: [1.0000000e+00 2.0000000e+00 9.7000000e+01 1.3680000e+03 2.0100000e+02
#  2.8071337e+01 1.0000000e+00], curr_frame = 97
# idx: 244, label: [2.0000000e+00 1.0000000e+00 9.7000000e+01 1.5710000e+03 1.9900000e+02
#  2.7018513e+01 1.0000000e+00], curr_frame = 97
# idx: 245, label: [4.00e+00 1.00e+00 9.70e+01 1.35e+03 9.48e+02 2.00e+00 1.00e+00], curr_frame = 97
# idx: 246, label: [5.000000e+00 1.000000e+00 9.700000e+01 1.461000e+03 6.130000e+02
#  8.062258e+00 1.000000e+00], curr_frame = 97
# idx: 247, label: [  0.   2.  98. 211.  32.   0.   1.], curr_frame = 98
# idx: 248, label: [1.0000000e+00 2.0000000e+00 9.8000000e+01 1.3940000e+03 1.9700000e+02
#  2.6305893e+01 1.0000000e+00], curr_frame = 98
# idx: 249, label: [2.0000000e+00 1.0000000e+00 9.8000000e+01 1.5960000e+03 2.0100000e+02
#  2.5079872e+01 1.0000000e+00], curr_frame = 98
# idx: 250, label: [4.000e+00 1.000e+00 9.800e+01 1.352e+03 9.480e+02 2.000e+00 1.000e+00], curr_frame = 98
# idx: 251, label: [5.000e+00 1.000e+00 9.800e+01 1.473e+03 6.130e+02 1.200e+01 1.000e+00], curr_frame = 98
# idx: 252, label: [  0.   2.  99. 211.  32.   0.   1.], curr_frame = 99
# idx: 253, label: [1.0000000e+00 2.0000000e+00 9.9000000e+01 1.4180000e+03 1.9800000e+02
#  2.4020824e+01 1.0000000e+00], curr_frame = 99
# idx: 254, label: [2.000000e+00 1.000000e+00 9.900000e+01 1.620000e+03 2.050000e+02
#  2.433105e+01 1.000000e+00], curr_frame = 99
# idx: 255, label: [4.000e+00 1.000e+00 9.900e+01 1.355e+03 9.480e+02 3.000e+00 1.000e+00], curr_frame = 99
# idx: 256, label: [5.000e+00 1.000e+00 9.900e+01 1.482e+03 6.130e+02 9.000e+00 1.000e+00], curr_frame = 99
# idx: 257, label: [  0.   2. 100. 211.  32.   0.   1.], curr_frame = 100
# idx: 258, label: [1.0000000e+00 2.0000000e+00 1.0000000e+02 1.4440000e+03 1.9700000e+02
#  2.6019224e+01 1.0000000e+00], curr_frame = 100
# idx: 259, label: [2.0000000e+00 1.0000000e+00 1.0000000e+02 1.6460000e+03 2.1000000e+02
#  2.6476404e+01 1.0000000e+00], curr_frame = 100
# idx: 260, label: [4.000e+00 1.000e+00 1.000e+02 1.355e+03 9.480e+02 0.000e+00 1.000e+00], curr_frame = 100
# idx: 261, label: [5.0000000e+00 1.0000000e+00 1.0000000e+02 1.4920000e+03 6.1700000e+02
#  1.0770329e+01 1.0000000e+00], curr_frame = 100
# idx: 262, label: [  0.   2. 101. 211.  32.   0.   1.], curr_frame = 101
# idx: 263, label: [1.0000000e+00 2.0000000e+00 1.0100000e+02 1.4670000e+03 2.0100000e+02
#  2.3345236e+01 1.0000000e+00], curr_frame = 101
# idx: 264, label: [2.0000000e+00 1.0000000e+00 1.0100000e+02 1.6700000e+03 2.1600000e+02
#  2.4738634e+01 1.0000000e+00], curr_frame = 101
# idx: 265, label: [4.000000e+00 1.000000e+00 1.010000e+02 1.359000e+03 9.460000e+02
#  4.472136e+00 1.000000e+00], curr_frame = 101
# idx: 266, label: [5.000e+00 1.000e+00 1.010e+02 1.502e+03 6.170e+02 1.000e+01 1.000e+00], curr_frame = 101
# idx: 267, label: [  0.   2. 102. 211.  32.   0.   1.], curr_frame = 102
# idx: 268, label: [1.000000e+00 2.000000e+00 1.020000e+02 1.495000e+03 2.020000e+02
#  2.801785e+01 1.000000e+00], curr_frame = 102
# idx: 269, label: [2.000000e+00 1.000000e+00 1.020000e+02 1.695000e+03 2.230000e+02
#  2.596151e+01 1.000000e+00], curr_frame = 102
# idx: 270, label: [4.00e+00 1.00e+00 1.02e+02 1.36e+03 9.46e+02 1.00e+00 1.00e+00], curr_frame = 102
# idx: 271, label: [5.0000000e+00 1.0000000e+00 1.0200000e+02 1.5130000e+03 6.1600000e+02
#  1.1045361e+01 1.0000000e+00], curr_frame = 102
# idx: 272, label: [  0.   2. 103. 211.  32.   0.   1.], curr_frame = 103
# idx: 273, label: [1.0000000e+00 2.0000000e+00 1.0300000e+02 1.5200000e+03 2.0100000e+02
#  2.5019993e+01 1.0000000e+00], curr_frame = 103
# idx: 274, label: [2.0000000e+00 1.0000000e+00 1.0300000e+02 1.7180000e+03 2.2900000e+02
#  2.3769728e+01 1.0000000e+00], curr_frame = 103
# idx: 275, label: [4.000000e+00 1.000000e+00 1.030000e+02 1.362000e+03 9.450000e+02
#  2.236068e+00 1.000000e+00], curr_frame = 103
# idx: 276, label: [5.000e+00 1.000e+00 1.030e+02 1.524e+03 6.160e+02 1.100e+01 1.000e+00], curr_frame = 103
# idx: 277, label: [  0.   2. 104. 211.  32.   0.   1.], curr_frame = 104
# idx: 278, label: [1.000000e+00 2.000000e+00 1.040000e+02 1.552000e+03 2.060000e+02
#  3.238827e+01 1.000000e+00], curr_frame = 104
# idx: 279, label: [4.0000000e+00 1.0000000e+00 1.0400000e+02 1.3660000e+03 9.4400000e+02
#  4.1231055e+00 1.0000000e+00], curr_frame = 104
# idx: 280, label: [5.0000000e+00 1.0000000e+00 1.0400000e+02 1.5380000e+03 6.1800000e+02
#  1.4142136e+01 1.0000000e+00], curr_frame = 104
# idx: 281, label: [  0.   2. 105. 211.  32.   0.   1.], curr_frame = 105
# idx: 282, label: [1.0000000e+00 2.0000000e+00 1.0500000e+02 1.5800000e+03 2.1100000e+02
#  2.8442924e+01 1.0000000e+00], curr_frame = 105
# idx: 283, label: [4.000000e+00 1.000000e+00 1.050000e+02 1.368000e+03 9.400000e+02
#  4.472136e+00 1.000000e+00], curr_frame = 105
# idx: 284, label: [5.0000000e+00 1.0000000e+00 1.0500000e+02 1.5530000e+03 6.2000000e+02
#  1.5132746e+01 1.0000000e+00], curr_frame = 105
# idx: 285, label: [  0.   2. 106. 211.  32.   0.   1.], curr_frame = 106
# idx: 286, label: [1.0000000e+00 2.0000000e+00 1.0600000e+02 1.6080000e+03 2.1700000e+02
#  2.8635643e+01 1.0000000e+00], curr_frame = 106
# idx: 287, label: [4.0000000e+00 1.0000000e+00 1.0600000e+02 1.3780000e+03 9.3700000e+02
#  1.0440307e+01 1.0000000e+00], curr_frame = 106
# idx: 288, label: [5.0000000e+00 1.0000000e+00 1.0600000e+02 1.5750000e+03 6.2300000e+02
#  2.2203604e+01 1.0000000e+00], curr_frame = 106
# idx: 289, label: [  0.   2. 107. 211.  32.   0.   1.], curr_frame = 107
# idx: 290, label: [1.000000e+00 2.000000e+00 1.070000e+02 1.640000e+03 2.240000e+02
#  3.275668e+01 1.000000e+00], curr_frame = 107
# idx: 291, label: [4.000000e+00 1.000000e+00 1.070000e+02 1.388000e+03 9.320000e+02
#  1.118034e+01 1.000000e+00], curr_frame = 107
# idx: 292, label: [5.0000000e+00 1.0000000e+00 1.0700000e+02 1.5990000e+03 6.2400000e+02
#  2.4020824e+01 1.0000000e+00], curr_frame = 107
# idx: 293, label: [  0.   2. 108. 211.  32.   0.   1.], curr_frame = 108
# idx: 294, label: [1.000000e+00 2.000000e+00 1.080000e+02 1.665000e+03 2.300000e+02
#  2.570992e+01 1.000000e+00], curr_frame = 108
# idx: 295, label: [4.0000000e+00 1.0000000e+00 1.0800000e+02 1.4020000e+03 9.2000000e+02
#  1.8439089e+01 1.0000000e+00], curr_frame = 108
# idx: 296, label: [5.0000000e+00 1.0000000e+00 1.0800000e+02 1.6340000e+03 6.2700000e+02
#  3.5128338e+01 1.0000000e+00], curr_frame = 108
# idx: 297, label: [  0.   2. 109. 211.  32.   0.   1.], curr_frame = 109
# idx: 298, label: [1.000000e+00 2.000000e+00 1.090000e+02 1.697000e+03 2.360000e+02
#  3.255764e+01 1.000000e+00], curr_frame = 109
# idx: 299, label: [4.0000000e+00 1.0000000e+00 1.0900000e+02 1.4300000e+03 9.0700000e+02
#  3.0870699e+01 1.0000000e+00], curr_frame = 109
# idx: 300, label: [5.000e+00 1.000e+00 1.090e+02 1.673e+03 6.270e+02 3.900e+01 1.000e+00], curr_frame = 109
# idx: 301, label: [  0.   2. 110. 211.  32.   0.   1.], curr_frame = 110
# idx: 302, label: [4.000000e+00 1.000000e+00 1.100000e+02 1.472000e+03 8.880000e+02
#  4.609772e+01 1.000000e+00], curr_frame = 110
# idx: 303, label: [  0.   2. 111. 211.  32.   0.   1.], curr_frame = 111
# idx: 304, label: [4.00000e+00 1.00000e+00 1.11000e+02 1.52600e+03 8.74000e+02 5.57853e+01
#  1.00000e+00], curr_frame = 111
# idx: 305, label: [  0.   2. 112. 211.  32.   0.   1.], curr_frame = 112
# idx: 306, label: [4.0000000e+00 1.0000000e+00 1.1200000e+02 1.5850000e+03 8.5700000e+02
#  6.1400326e+01 1.0000000e+00], curr_frame = 112
# idx: 307, label: [  0.   2. 113. 211.  32.   0.   1.], curr_frame = 113
# idx: 308, label: [4.000000e+00 1.000000e+00 1.130000e+02 1.641000e+03 8.410000e+02
#  5.824088e+01 1.000000e+00], curr_frame = 113
# idx: 309, label: [  0.   2. 114. 211.  32.   0.   1.], curr_frame = 114
# idx: 310, label: [4.000000e+00 1.000000e+00 1.140000e+02 1.698000e+03 8.360000e+02
#  5.721888e+01 1.000000e+00], curr_frame = 114
# idx: 311, label: [  0.   2. 115. 211.  32.   0.   1.], curr_frame = 115
# idx: 312, label: [  0.   2. 116. 211.  32.   0.   1.], curr_frame = 116
# idx: 313, label: [  0.   2. 117. 211.  32.   0.   1.], curr_frame = 117
# idx: 314, label: [  0.   2. 118. 211.  32.   0.   1.], curr_frame = 118
# idx: 315, label: [  0.   2. 119. 211.  32.   0.   1.], curr_frame = 119
# idx: 316, label: [  0.   2. 120. 211.  32.   0.   1.], curr_frame = 120
# idx: 317, label: [  0.   2. 121. 211.  32.   0.   1.], curr_frame = 121
# idx: 318, label: [  0.   2. 122. 211.  32.   0.   1.], curr_frame = 122
# idx: 319, label: [  0.   2. 123. 211.  32.   0.   1.], curr_frame = 123
# idx: 320, label: [  0.   2. 124. 211.  32.   0.   1.], curr_frame = 124
# idx: 321, label: [  0.   2. 125. 211.  32.   0.   1.], curr_frame = 125
# idx: 322, label: [  0.   2. 126. 211.  32.   0.   1.], curr_frame = 126
# idx: 323, label: [  0.   2. 127. 211.  32.   0.   1.], curr_frame = 127
# idx: 324, label: [  0.   2. 128. 211.  32.   0.   1.], curr_frame = 128
# idx: 325, label: [  0.   2. 129. 211.  32.   0.   1.], curr_frame = 129
# idx: 326, label: [  0.   2. 130. 211.  32.   0.   1.], curr_frame = 130
# idx: 327, label: [  0.   2. 131. 211.  32.   0.   1.], curr_frame = 131
# idx: 328, label: [  0.   2. 132. 211.  32.   0.   1.], curr_frame = 132
# idx: 329, label: [  0.   2. 133. 211.  32.   0.   1.], curr_frame = 133
# idx: 330, label: [  0.   2. 134. 211.  32.   0.   1.], curr_frame = 134
# idx: 331, label: [  0.   2. 135. 211.  32.   0.   1.], curr_frame = 135
# idx: 332, label: [  0.   2. 136. 211.  32.   0.   1.], curr_frame = 136
# idx: 333, label: [  0.   2. 137. 211.  32.   0.   1.], curr_frame = 137
# idx: 334, label: [  0.   2. 138. 211.  32.   0.   1.], curr_frame = 138
# idx: 335, label: [  0.   2. 139. 211.  32.   0.   1.], curr_frame = 139
# idx: 336, label: [  0.   2. 140. 211.  32.   0.   1.], curr_frame = 140
# idx: 337, label: [  0.   2. 141. 211.  32.   0.   1.], curr_frame = 141
# idx: 338, label: [  0.   2. 142. 211.  32.   0.   1.], curr_frame = 142
# idx: 339, label: [  0.   2. 143. 211.  32.   0.   1.], curr_frame = 143
# idx: 340, label: [  0.   2. 144. 211.  32.   0.   1.], curr_frame = 144
# idx: 341, label: [  0.   2. 145. 211.  32.   0.   1.], curr_frame = 145
# idx: 342, label: [  0.   2. 146. 211.  32.   0.   1.], curr_frame = 146
# idx: 343, label: [  0.   2. 147. 211.  32.   0.   1.], curr_frame = 147
# idx: 344, label: [  0.   2. 148. 211.  32.   0.   1.], curr_frame = 148
# idx: 345, label: [  0.   2. 149. 211.  32.   0.   1.], curr_frame = 149
# Search Complete
# Frames in video 0: 150
# Frames in video 1: 150
# Frames in video 2: 118
# Frames in video 3: 150
# Frames in video 4: 63
# Frames in video 5: 116
# Frames in video 6: 66
# Frames in video 7: 149
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-45cc68f966b2> in <module>()
# ----> 1 x_img, x_diff, y = load_data()
#
# <ipython-input-14-0aa76abdf1cd> in load_data()
#       4     seq = assign_labels(seq)
#       5     data = load_data_and_labels(seq)
# ----> 6     x_img, x_diff, y = data_to_np(data)
#       7     return x_img, x_diff, y
#
# <ipython-input-13-b1af40301f9f> in data_to_np(data)
#      24             y_values.append(zero_np)
#      25
# ---> 26     x_img = np.asarray(x_values)
#      27     y_values = np.asarray(y_values)
#      28     x_diff = y_values[:, :, 5:]
#
# c:\users\joear\appdata\local\programs\python\python36\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     490
#     491     """
# --> 492     return array(a, dtype, copy=False, order=order)
#     493
#     494
#
# MemoryError:

# %%
# need to normalise y values
# need to build a model that includes distance and frame diff
# model predicting x and y values

# going to build model that predicts coords from image

# %%
def normalise_img(x_values):
    return x_values / 255

# %%
def cnn_prepare(x_value, y_value):
    #x_val = np.reshape(x_value,(x_value.shape[0] * x_value.shape[1], 
    #                            x_value.shape[2], 
    #                            x_value.shape[3], 
    #                            x_value.shape[4]))
    x_val = normalise_img(x_value)
    y_val = np.reshape(y_value,(y_value.shape[0],
                                y_value.shape[1] * y_value.shape[2]))
    return x_val, y_val

# %%
def random_np(x_np, y_np):
    prng = RandomState(0)
    randomise = prng.permutation(x_np.shape[0])
    x_np = x_np[randomise]
    y_np = y_np[randomise]
    return x_np, y_np

# %%
def split_np(x_data, y_data, percent):
    """ splits a numpy array into testing and training """
    position = int(len(x_data) * (1-percent))
    x_train, x_test = x_data[:position], x_data[position:]
    y_train, y_test = y_data[:position], y_data[position:]
    print('x_train shape: {}, x_test shape: {}'.format(x_train.shape,x_test.shape))
    print('y_train shape: {}, y_test shape: {}'.format(y_train.shape,y_test.shape))
    return x_train, y_train, x_test, y_test

# %%
x_img, y = random_np(x_img, y)

x_cnn, y_cnn = cnn_prepare(x_img, y)
#x_cnn, y_cnn = x_img, y
x_train, y_train, x_test, y_test = split_np(x_cnn, y_cnn, 0.2)

## remove useless variables
x_img, x_diff, y, x_cnn, y_cnn = None, None, None, None, None

# %%
## prepare data to pickle
import pickle

data = [x_train, y_train, x_test, y_test]
pickle.dump(data, open("./aws/data_rand.p","wb"))
print("Finished")

# %%
input_shape = x_train.shape[1:]
output_shape = y_train.shape[1]

model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3),
                activation='relu',
                input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(32, (3, 3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3, 3),activation='relu'))
model.add(MaxPooling2D((2,2), strides=(2,2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(output_shape))
model.compile(loss='mean_squared_error', 
              optimizer='adam',
              metrics=['accuracy'])

# %%
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, verbose=1, mode='auto')
checkpointer = ModelCheckpoint(filepath="dnn/tmp_best_weights.hdf5", verbose=0, save_best_only=True) # save best model

batch_size = 4
epochs = 1000
import time
start_time = time.time()

model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(x_test, y_test),
          callbacks=[monitor,checkpointer])
model.load_weights('dnn/tmp_best_weights.hdf5') # load weights from best model


save_dir = join(os.getcwd(),"dnn")
save_path = join(save_dir,str(int(start_time)) + "_cnn.h5")
model.save(save_path)

score = model.evaluate(x_test, y_test, verbose=2)
print('Test loss: {}'.format(score[0]))
print('Test accuracy: {}'.format(score[1]))

elapsed_time = time.time() - start_time
print("Elapsed time: {}".format(hms_string(elapsed_time)))
