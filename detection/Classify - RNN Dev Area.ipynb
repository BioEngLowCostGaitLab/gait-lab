# %%
from rnn_model import rnnClassify

# %%
predictor = rnnClassify()
predictor.rnn_load_data()
# Out:
# None count:  14
# Traing_data count:  1847
# Test_data count:  616

# %%
predictor.rnn_predict(predictor.test_data_x)
# Out:
# INFO:tensorflow:Restoring parameters from C:/Users/joear/OneDrive - Imperial College London/General/Code/Python/EDP/rnn_model/current_model.ckpt
# Model restored
# ---------------------------------------
# Progress:  0.0
# Progress:  8.116883116883116
# Progress:  16.233766233766232
# Progress:  24.350649350649352
# Progress:  32.467532467532465
# Progress:  40.58441558441558
# Progress:  48.701298701298704
# Progress:  56.81818181818182
# Progress:  64.93506493506493
# Progress:  73.05194805194806
# Progress:  81.16883116883116
# Progress:  89.28571428571429
# Progress:  97.40259740259741
# [array([[-5799113.,  8015992.]], dtype=float32),
#  array([[  9634759., -10484980.]], dtype=float32),
#  array([[ 12020812.,  -9426699.]], dtype=float32),
#  array([[-8667900. ,  7342502.5]], dtype=float32),
#  array([[-3901156.75,  3973670.5 ]], dtype=float32),
#  array([[ 22698040., -22951472.]], dtype=float32),
#  array([[ -9329556.,  10253477.]], dtype=float32),
# ...
