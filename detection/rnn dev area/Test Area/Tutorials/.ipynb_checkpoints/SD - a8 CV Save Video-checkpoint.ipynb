# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv.imread('will.jpg',cv.IMREAD_GRAYSCALE)

# %%
cv.imshow('Will',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
plt.imshow(img, cmap='gray', interpolation='bicubic')
plt.plot([50,100],[200,100],'c',linewidth=5)
plt.show()

# %%
cv.imwrite('will_test.png',img)
# Out:
# True
