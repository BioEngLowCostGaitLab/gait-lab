# %%
import tensorflow as tf
import cv2 as cv
import numpy as np
import os
from os.path import join
from functions import analyse

# %%
def play_video(file = 'resources/test_video.mp4', width = 960, height = 540, flip = True):
    root = os.getcwd()
    ssd = cv.dnn.readNetFromCaffe(join(root, 'resources', 'MobileNetSSD_deploy.prototxt'),
                                  join(root, 'resources', 'MobileNetSSD_deploy.caffemodel'))
    frozen_tf_model = None
    threshold = 2000
    
    detector = cv.xfeatures2d.SURF_create(threshold)
    print("Starting Session")
    sess=tf.Session()
    saver = tf.train.import_meta_graph('./cnn_model/current_model.meta')
    saver.restore(sess,tf.train.latest_checkpoint('./cnn_model/'))
    
    graph = tf.get_default_graph()
    
    cap = cv.VideoCapture(file)
    ret, frame = cap.read()
    clone = cv.resize(frame, (width,height))
    if(flip): clone = cv.flip(clone, 0)
        
    print("Starting Loop")
    
    count = 0
    
    while ret:
        ret, frame = cap.read()
        if(flip): frame = cv.flip(frame, 0) 
        frame = cv.resize(frame, (1280, 720))
        clone = frame
        keypoints, detector, threshold, startX, endX = analyse(frame, ssd, frozen_tf_model, detector, 0,
                                                       threshold, use_classifier=False)
        
        frame = cv.drawKeypoints(frame, keypoints, None, (0, 255, 0), 4)
        cv.imshow("output", cv.resize(frame, (640, 360)))

        if cv.waitKey(1) & 0xFF == ord('q'):
            break
        
        print("---------")
        if len(keypoints) > 0: 
            print("---------")
            for kp in keypoints:
                print('Coordinates: %d, %d' % (kp.pt[0], kp.pt[1]))
            
            kp_x = int(keypoints[0].pt[0])
            kp_y = int(keypoints[0].pt[1])
            print('First coordinate: %d, %d' % (kp_x, kp_y))
            
            roi = clone[kp_y-12:kp_y+12, kp_x-12:kp_x+12]
            cv.imshow("ROI", roi)
            cv.waitKey(0)
            cv.destroyWindow("ROI")
            count += 1
            if count > 100:
                break
        
    cap.release()
    cv.destroyAllWindows()
    sess.close()

# %%
play_video()
# Out:
# Starting Session
# INFO:tensorflow:Restoring parameters from ./cnn_model/current_model
# Starting Loop
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# Coordinates: 1085, 294
# Coordinates: 867, 482
# Coordinates: 1122, 690
# Coordinates: 971, 482
# Coordinates: 1097, 346
# Coordinates: 1119, 644
# Coordinates: 911, 482
# Coordinates: 1115, 510
# Coordinates: 1095, 429
# Coordinates: 1112, 597
# Coordinates: 1107, 460
# Coordinates: 190, 703
# First coordinate: 1085, 294
# ---------
# ---------
# Coordinates: 1077, 305
# Coordinates: 1083, 381
# Coordinates: 1121, 661
# Coordinates: 926, 482
# Coordinates: 1095, 458
# Coordinates: 1098, 497
# Coordinates: 188, 662
# Coordinates: 189, 704
# Coordinates: 1121, 614
# Coordinates: 1104, 535
# Coordinates: 959, 475
# First coordinate: 1077, 305
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# Coordinates: 1020, 288
# Coordinates: 975, 483
# Coordinates: 916, 484
# Coordinates: 1092, 693
# Coordinates: 1025, 373
# Coordinates: 1084, 652
# Coordinates: 1040, 421
# Coordinates: 941, 476
# Coordinates: 1075, 572
# Coordinates: 1056, 518
# Coordinates: 741, 700
# Coordinates: 61, 469
# First coordinate: 1020, 288
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# ---------
# Coordinates: 950, 273
# Coordinates: 605, 303
# Coordinates: 1248, 460
# Coordinates: 543, 291
# Coordinates: 1053, 695
# Coordinates: 961, 311
# Coordinates: 970, 340
# Coordinates: 872, 485
# Coordinates: 580, 296
# Coordinates: 976, 484
# Coordinates: 980, 396
# Coordinates: 930, 484
# First coordinate: 950, 273
# ---------
# ---------
# Coordinates: 944, 272
# Coordinates: 592, 316
# Coordinates: 1238, 458
# Coordinates: 964, 338
# Coordinates: 1049, 696
# Coordinates: 512, 282
# Coordinates: 956, 308
# Coordinates: 568, 309
# Coordinates: 536, 303
# Coordinates: 976, 484
# Coordinates: 974, 391
# Coordinates: 930, 485
# First coordinate: 944, 272
# ---------
# ---------
# Coordinates: 939, 271
# Coordinates: 583, 326
# Coordinates: 570, 287
# Coordinates: 959, 335
# Coordinates: 1228, 454
# Coordinates: 950, 306
# Coordinates: 985, 497
# Coordinates: 1040, 692
# Coordinates: 515, 299
# Coordinates: 872, 485
# Coordinates: 969, 387
# Coordinates: 559, 319
# First coordinate: 939, 271
# ---------
# ---------
# Coordinates: 577, 334
# Coordinates: 934, 270
# Coordinates: 569, 308
# Coordinates: 953, 334
# Coordinates: 514, 306
# Coordinates: 1217, 438
# Coordinates: 1041, 696
# Coordinates: 945, 305
# Coordinates: 982, 495
# Coordinates: 872, 485
# First coordinate: 577, 334
# ---------
# ---------
# Coordinates: 574, 341
# Coordinates: 936, 276
# Coordinates: 557, 305
# Coordinates: 948, 331
# Coordinates: 572, 272
# Coordinates: 516, 313
# Coordinates: 1207, 428
# Coordinates: 1035, 694
# Coordinates: 939, 303
# Coordinates: 980, 493
# Coordinates: 872, 485
# Coordinates: 918, 486
# First coordinate: 574, 341
# ---------
# ---------
# Coordinates: 572, 346
# Coordinates: 927, 278
# Coordinates: 559, 308
# Coordinates: 941, 328
# Coordinates: 1196, 448
# Coordinates: 975, 477
# Coordinates: 569, 281
# Coordinates: 872, 485
# Coordinates: 529, 265
# First coordinate: 572, 346
# ---------
# ---------
# Coordinates: 573, 349
# Coordinates: 915, 264
# Coordinates: 562, 309
# Coordinates: 532, 326
# Coordinates: 563, 274
# Coordinates: 972, 479
# Coordinates: 1187, 409
# Coordinates: 1036, 697
# Coordinates: 933, 341
# Coordinates: 925, 298
# Coordinates: 872, 485
# First coordinate: 573, 349
# ---------
# ---------
# Coordinates: 567, 337
# Coordinates: 914, 274
# Coordinates: 970, 492
# Coordinates: 1029, 694
# Coordinates: 1174, 442
# Coordinates: 928, 323
# Coordinates: 872, 485
# First coordinate: 567, 337
# ---------
# ---------
# Coordinates: 571, 338
# Coordinates: 908, 270
# Coordinates: 966, 492
# Coordinates: 1164, 445
# Coordinates: 610, 278
# Coordinates: 912, 295
# Coordinates: 932, 367
# First coordinate: 571, 338
# ---------
# ---------
# Coordinates: 577, 340
# Coordinates: 901, 269
# Coordinates: 963, 492
# Coordinates: 1156, 450
# Coordinates: 1031, 688
# Coordinates: 872, 485
# First coordinate: 577, 340
# ---------
# ---------
# Coordinates: 583, 317
# Coordinates: 894, 268
# Coordinates: 597, 344
# Coordinates: 558, 336
# Coordinates: 960, 492
# Coordinates: 1147, 451
# Coordinates: 562, 294
# Coordinates: 1207, 689
# Coordinates: 617, 287
# Coordinates: 1028, 683
# Coordinates: 873, 485
# First coordinate: 583, 317
# ---------
# ---------
# Coordinates: 593, 318
# Coordinates: 887, 267
# Coordinates: 598, 357
# Coordinates: 1034, 696
# Coordinates: 1223, 643
# Coordinates: 955, 492
# Coordinates: 1145, 451
# Coordinates: 570, 297
# Coordinates: 1199, 587
# Coordinates: 623, 290
# Coordinates: 873, 485
# First coordinate: 593, 318
# ---------
# ---------
# Coordinates: 603, 318
# Coordinates: 1028, 692
# Coordinates: 606, 357
# Coordinates: 881, 268
# Coordinates: 1185, 589
# Coordinates: 951, 492
# Coordinates: 1128, 449
# Coordinates: 578, 300
# Coordinates: 1192, 693
# Coordinates: 873, 485
# Coordinates: 896, 306
# Coordinates: 628, 293
# First coordinate: 603, 318
# ---------
# ---------
# Coordinates: 616, 317
# Coordinates: 1025, 689
# Coordinates: 1173, 591
# Coordinates: 612, 355
# Coordinates: 875, 268
# Coordinates: 1189, 634
# Coordinates: 947, 492
# Coordinates: 588, 303
# Coordinates: 886, 291
# Coordinates: 873, 485
# First coordinate: 616, 317
# ---------
# ---------
# Coordinates: 623, 319
# Coordinates: 1018, 688
# Coordinates: 620, 355
# Coordinates: 1163, 591
# Coordinates: 873, 283
# Coordinates: 943, 492
# Coordinates: 597, 306
# Coordinates: 1175, 627
# Coordinates: 873, 486
# First coordinate: 623, 319
# ---------
# ---------
# Coordinates: 633, 319
# Coordinates: 1014, 687
# Coordinates: 629, 356
# Coordinates: 862, 281
# Coordinates: 940, 492
# Coordinates: 606, 310
# Coordinates: 873, 485
# First coordinate: 633, 319
# ---------
# ---------
# Coordinates: 629, 340
# Coordinates: 1016, 681
# Coordinates: 937, 492
# Coordinates: 870, 295
# Coordinates: 873, 486
# Coordinates: 996, 657
# First coordinate: 629, 340
# ---------
# ---------
# Coordinates: 652, 321
# Coordinates: 626, 344
# Coordinates: 1012, 679
# Coordinates: 660, 344
# Coordinates: 865, 297
# Coordinates: 873, 486
# Coordinates: 919, 486
# Coordinates: 676, 288
# Coordinates: 994, 657
# First coordinate: 652, 321
# ---------
# ---------
# Coordinates: 635, 346
# Coordinates: 661, 323
# Coordinates: 1002, 684
# Coordinates: 668, 346
# Coordinates: 873, 486
# Coordinates: 682, 291
# Coordinates: 923, 498
# Coordinates: 1235, 340
# Coordinates: 867, 326
# First coordinate: 635, 346
# ---------
# ---------
# Coordinates: 656, 347
# Coordinates: 999, 675
# Coordinates: 924, 493
# Coordinates: 1025, 703
# Coordinates: 873, 486
# Coordinates: 861, 328
# First coordinate: 656, 347
# ---------
# ---------
# Coordinates: 664, 349
# Coordinates: 920, 493
# Coordinates: 874, 486
# Coordinates: 1165, 269
# Coordinates: 855, 331
# Coordinates: 840, 270
# First coordinate: 664, 349
# ---------
# ---------
# Coordinates: 671, 352
# Coordinates: 915, 493
# Coordinates: 1142, 268
# Coordinates: 844, 279
# Coordinates: 1155, 694
# Coordinates: 874, 486
# Coordinates: 850, 333
# First coordinate: 671, 352
# ---------
# ---------
# Coordinates: 1021, 690
# Coordinates: 677, 355
# Coordinates: 910, 493
# Coordinates: 695, 281
# Coordinates: 844, 334
# Coordinates: 1128, 274
# Coordinates: 874, 486
# Coordinates: 822, 267
# First coordinate: 1021, 690
# ---------
# ---------
# Coordinates: 1016, 686
# Coordinates: 682, 358
# Coordinates: 905, 494
# Coordinates: 698, 284
# Coordinates: 830, 282
# Coordinates: 838, 337
# Coordinates: 874, 486
# Coordinates: 1118, 268
# Coordinates: 1130, 680
# First coordinate: 1016, 686
# ---------
# ---------
# Coordinates: 1010, 681
# Coordinates: 686, 362
# Coordinates: 1131, 692
# Coordinates: 899, 494
# Coordinates: 823, 285
# Coordinates: 701, 288
# Coordinates: 833, 340
# Coordinates: 1105, 275
# Coordinates: 874, 486
# First coordinate: 1010, 681
# ---------
# ---------
# Coordinates: 1003, 678
# Coordinates: 690, 366
# Coordinates: 802, 262
# Coordinates: 893, 494
# Coordinates: 703, 292
# Coordinates: 827, 343
# Coordinates: 831, 268
# Coordinates: 1091, 281
# Coordinates: 924, 605
# Coordinates: 874, 486
# Coordinates: 921, 557
# Coordinates: 1108, 665
# First coordinate: 1003, 678
# ---------
# ---------
# ---------
# Coordinates: 988, 668
# Coordinates: 693, 375
# Coordinates: 800, 294
# Coordinates: 896, 540
# Coordinates: 881, 494
# Coordinates: 704, 301
# Coordinates: 897, 604
# Coordinates: 843, 700
# Coordinates: 1066, 285
# Coordinates: 817, 363
# Coordinates: 1086, 658
# Coordinates: 1075, 590
# First coordinate: 988, 668
# ---------
# ---------
# Coordinates: 980, 662
# Coordinates: 693, 379
# Coordinates: 892, 538
# Coordinates: 794, 296
# Coordinates: 704, 305
# Coordinates: 889, 603
# Coordinates: 875, 493
# Coordinates: 1067, 384
# Coordinates: 1055, 285
# Coordinates: 1085, 670
# Coordinates: 807, 350
# First coordinate: 980, 662
# ---------
# ---------
# Coordinates: 971, 655
# Coordinates: 693, 383
# Coordinates: 787, 296
# Coordinates: 886, 539
# Coordinates: 834, 700
# Coordinates: 703, 308
# Coordinates: 885, 604
# Coordinates: 810, 271
# Coordinates: 1057, 383
# Coordinates: 1045, 286
# Coordinates: 893, 578
# Coordinates: 851, 669
# First coordinate: 971, 655
# ---------
# ---------
# Coordinates: 961, 648
# Coordinates: 692, 386
# Coordinates: 781, 297
# Coordinates: 882, 543
# Coordinates: 702, 312
# Coordinates: 880, 602
# Coordinates: 883, 570
# Coordinates: 803, 271
# Coordinates: 1032, 298
# Coordinates: 793, 349
# First coordinate: 961, 648
# ---------
# ---------
# Coordinates: 951, 642
# Coordinates: 692, 389
# Coordinates: 775, 297
# Coordinates: 700, 315
# Coordinates: 877, 547
# Coordinates: 1034, 536
# Coordinates: 880, 570
# Coordinates: 877, 601
# Coordinates: 1026, 287
# Coordinates: 796, 271
# Coordinates: 846, 669
# Coordinates: 1035, 610
# First coordinate: 951, 642
# ---------
# ---------
# Coordinates: 942, 635
# Coordinates: 690, 392
# Coordinates: 770, 297
# Coordinates: 698, 317
# Coordinates: 877, 568
# Coordinates: 1018, 544
# Coordinates: 1034, 379
# Coordinates: 874, 600
# Coordinates: 1017, 287
# Coordinates: 799, 397
# Coordinates: 1023, 612
# Coordinates: 781, 347
# First coordinate: 942, 635
# ---------
# ---------
# Coordinates: 934, 630
# Coordinates: 688, 395
# Coordinates: 764, 297
# Coordinates: 1003, 648
# Coordinates: 695, 319
# Coordinates: 801, 408
# Coordinates: 1026, 377
# Coordinates: 871, 599
# Coordinates: 775, 346
# Coordinates: 1008, 287
# Coordinates: 1010, 551
# First coordinate: 934, 630
# ---------
# ---------
# Coordinates: 926, 624
# Coordinates: 686, 397
# Coordinates: 750, 267
# Coordinates: 759, 297
# Coordinates: 794, 406
# Coordinates: 991, 646
# Coordinates: 692, 320
# Coordinates: 769, 345
# Coordinates: 863, 609
# Coordinates: 1000, 287
# Coordinates: 776, 271
# Coordinates: 1008, 560
# First coordinate: 926, 624
