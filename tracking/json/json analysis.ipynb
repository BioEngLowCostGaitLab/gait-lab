# %%
import pandas as pd
import os
from os.path import join
import json

# %%
with open('acc_2_2.json') as f:
    data = json.load(f)
print(data['markerpts'][0]['imglist'])
# Out:
# [{'frame': 0, 'ptslist': [{'colour': '', 'coords': [nan, nan], 'id': 0}, {'colour': '', 'coords': [nan, nan], 'id': 1}, {'colour': '', 'coords': [nan, nan], 'id': 2}, {'colour': '', 'coords': [nan, nan], 'id': 3}]}, {'frame': 1, 'ptslist': [{'colour': '', 'coords': [nan, nan], 'id': 0}, {'colour': '', 'coords': [nan, nan], 'id': 1}, {'colour': '', 'coords': [nan, nan], 'id': 2}, {'colour': '', 'coords': [nan, nan], 'id': 3}]}, {'frame': 2, 'ptslist': [{'colour': '', 'coords': [nan, nan], 'id': 0}, {'colour': '', 'coords': [nan, nan], 'id': 1}, {'colour': '', 'coords': [nan, nan], 'id': 2}, {'colour': '', 'coords': [nan, nan], 'id': 3}]}, {'frame': 3, 'ptslist': [{'colour': '', 'coords': [nan, nan], 'id': 0}, {'colour': '', 'coords': [nan, nan], 'id': 1}, {'colour': '', 'coords': [nan, nan], 'id': 2}, {'colour': '', 'coords': [nan, nan], 'id': 3}]}, {'frame': 4, 'ptslist': [{'colour': '', 'coords': [nan, nan], 'id': 0}, {'colour': '', 'coords': [nan, nan], 'id': 1}, {'colour': '', 'co
# ...

# %%
camera_0 = pd.DataFrame(data['markerpts'][0]['imglist'])

# %%
camera_0
# Out:
#      frame                                            ptslist
# 0        0  [{'colour': '', 'coords': [nan, nan], 'id': 0}...
# 1        1  [{'colour': '', 'coords': [nan, nan], 'id': 0}...
# 2        2  [{'colour': '', 'coords': [nan, nan], 'id': 0}...
# 3        3  [{'colour': '', 'coords': [nan, nan], 'id': 0}...
# 4        4  [{'colour': '', 'coords': [nan, nan], 'id': 0}...
# 5        5  [{'colour': '', 'coords': [1276.0, 951.0], 'id...
# 6        6  [{'colour': '', 'coords': [1277.0, 951.0], 'id...
# 7        7  [{'colour': '', 'coords': [1277.0, 951.0], 'id...
# 8        8  [{'colour': '', 'coords': [1278.0, 951.0], 'id...
# 9        9  [{'colour': '', 'coords': [1278.0, 951.0], 'id...
# 10      10  [{'colour': '', 'coords': [1279.0, 951.0], 'id...
# 11      11  [{'colour': '', 'coords': [1280.0, 951.0], 'id...
# 12      12  [{'colour': '', 'coords': [1280.0, 951.0], 'id...
# 13      13  [{'colour': '', 'coords': [1281.0, 951.0], 'id...
# ...
